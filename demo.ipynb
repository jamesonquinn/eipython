# %% [markdown]
# # Quick intro
#
# This is a jupyter notebook for testing / coding. So far, each code block is a separate test; unlike an ordinary notebook, they are not meant to run sequentially.
#
# First, test to see jupyter is running correctly at all:

# %%
import os
import sys

print("hi!!! you")
# Out:
# hi!!! you

# %% [markdown]
# Next, running the demo.

# %%
assert 1 == 0 #Don't run this
from importlib import reload
import demoNormal #import *
reload(demoNormal)
from demoNormal import *
import cProfile as profile

if True:

    for aniter in range(1):
        for nparticles in [1,5]:
            for guidename in guides.keys():
                for eparams in [fake_effects_params,f2,f3,f4]:
                    #

                    print(aniter,nparticles,guidename,eparams)
                    result = trainGuide(guidename,nparticles,eparams,filename="testresults/demo_dummy.amortized_laplace_untransparent_.csv")
                    print(aniter,nparticles,guidename,eparams)
                    for line in range(10):
                        print()
                    
else:
    plt.plot([getMLE(.01 + x/100,1.,0,1.) for x in range(500)])
# Out:
# The time is  1559608653
# Not none.
# Fake: tensor([-1.4116,  0.3701,  1.2158, -1.4837,  3.0843,  2.5397,  2.6868, -1.2708,
#         -0.2100,  1.3792,  0.0379, -2.9612, -0.7913, -0.2127, -1.3014,  2.8660,
#         -0.7877, -2.4126, -0.0762, -3.7869, -1.0193, -0.8043,  1.1809,  0.7782,
#          2.6305,  2.0031, -0.5379,  2.1687, -1.0677, -3.2358,  1.8955,  3.2008,
#          0.2243,  3.3235, -1.8954,  1.2361,  1.6933, -1.8130, -4.7086, -1.1077,
#          0.4200, -0.7243,  0.8113, -4.3946])
# The time is  1559608653
# Not none.
# Fake: tensor([-1.4116,  0.3701,  1.2158, -1.4837,  3.0843,  2.5397,  2.6868, -1.2708,
#         -0.2100,  1.3792,  0.0379, -2.9612, -0.7913, -0.2127, -1.3014,  2.8660,
#         -0.7877, -2.4126, -0.0762, -3.7869, -1.0193, -0.8043,  1.1809,  0.7782,
#          2.6305,  2.0031, -0.5379,  2.1687, -1.0677, -3.2358,  1.8955,  3.2008,
#          0.2243,  3.3235, -1.8954,  1.2361,  1.6933, -1.8130, -4.7086, -1.1077,
# ...

# %%
(

# %%
from importlib import reload
import demo #import *
reload(demo)
from demo import *
import cProfile as profile

if True:

    for aniter in range(1):
        for nparticles in [1,5]:
            for guidename in ["amortized_laplace"]:
                for eparams in [ndom_params,gdom_params,  even_params, neggum_params]:
                    #

                    print(aniter,nparticles,guidename,eparams)
                    result = trainGuide(guidename,nparticles,eparams,filename="testresults/demo_amortized_laplace_reduced_4.csv")
                    print(aniter,nparticles,guidename,eparams)
                    for line in range(10):
                        print()
                    
else:
    plt.plot([getMLE(.01 + x/100,1.,0,1.) for x in range(500)])
# Out:
# 0 1 amortized_laplace {'modal_effect': tensor(-0.0500), 'norm_scale': tensor(2.), 'gum_scale': tensor(0.1000)}
# Not none.
# epoch 0 loss = 195.4848656654358;
# mode_hat tensor(0.0050, requires_grad=True)
# gscale_hat tensor(1.0050, requires_grad=True)
# nscale_hat tensor(1.0050, requires_grad=True)
# epoch 10 loss = 193.1856153011322;
# mode_hat tensor(0.0526, requires_grad=True)
# gscale_hat tensor(1.0534, requires_grad=True)
# nscale_hat tensor(1.0448, requires_grad=True)
# epoch 20 loss = 200.45553517341614;
# mode_hat tensor(0.0838, requires_grad=True)
# gscale_hat tensor(1.0977, requires_grad=True)
# nscale_hat tensor(1.0853, requires_grad=True)
# epoch 30 loss = 196.73672342300415;
# mode_hat tensor(0.1104, requires_grad=True)
# gscale_hat tensor(1.1380, requires_grad=True)
# nscale_hat tensor(1.0886, requires_grad=True)
# epoch 40 loss = 197.92701756954193;
# mode_hat tensor(0.1111, requires_grad=True)
# gscale_hat tensor(1.1800, requires_grad=True)
# ...

# %%
print(fake_effects)
# Out:
# tensor([-1.4116,  0.3701,  1.2158, -1.4837,  3.0843,  2.5397,  2.6868, -1.2708,
#         -0.2100,  1.3792,  0.0379, -2.9612, -0.7913, -0.2127, -1.3014,  2.8660,
#         -0.7877, -2.4126, -0.0762, -3.7869, -1.0193, -0.8043,  1.1809,  0.7782,
#          2.6305,  2.0031, -0.5379,  2.1687, -1.0677, -3.2358,  1.8955,  3.2008,
#          0.2243,  3.3235, -1.8954,  1.2361,  1.6933, -1.8130, -4.7086, -1.1077,
#          0.4200, -0.7243,  0.8113, -4.3946])

# %%
import myhessian
import torch
ts = torch.tensor
t = ts([i+.5 for i in range(5)], requires_grad=True)
l = torch.sum(t**3)
[lg] = torch.autograd.grad(l,t,create_graph=True,retain_graph=True)
[lgg] = torch.autograd.grad(lg[1],t,create_graph=True,retain_graph=True)
lgg2 = lgg.contiguous().view(-1)
print(lgg2.size())
lgg3 = torch.zeros(6,6)#,requires_grad=True)
lgg3[1,1:].add_(lgg2.type_as(lgg3))
print(lg)
h = myhessian.hessian(l,t)
l2 = torch.sum(lgg3)
l2.backward()
print(t.grad)
print(lgg3.requires_grad)
# Out:
# torch.Size([5])
# tensor([ 0.7500,  6.7500, 18.7500, 36.7500, 60.7500], grad_fn=<MulBackward0>)
# tensor([0., 6., 0., 0., 0.])
# True

# %%
from importlib import reload
import demo #import *
reload(demo)
from demo import *
import cProfile as profile

print("hi")

print(lambertw(ts([0.])),lambertw(ts([1.])),lambertw(ts([50.])))
print("hi")

testMLE()
# Out:
# Not none.
# Fake: tensor([0.7708, 0.9373, 0.3363, 0.4669, 0.7751, 1.0240, 0.9237, 1.0633, 0.5697,
#         0.2267, 0.9604, 0.3158, 0.2745, 1.3635, 1.0884, 0.3226, 0.4992, 0.4686,
#         0.3450, 0.5070, 0.8096, 0.4685, 1.2292, 0.5951, 0.8807, 0.7200, 0.0693,
#         0.0639, 0.6489, 0.4998, 0.3163, 0.3981, 1.4540, 0.7402, 0.4704, 0.4906,
#         0.2753, 0.5539, 0.4448, 0.1483, 0.6295, 0.6658, 0.4501, 0.8183])
# hi
# tensor([0.]) tensor([0.5671]) tensor([2.8609])
# hi
# tensor([0.1005]) tensor([0.0317]) tensor([-0.0180]) tensor([0.0839]) tensor([0.0165])
# getMLE seems to have failed, tensor([0.0497]) tensor([0.0317]) tensor([-0.0180]) tensor([0.1005]) tensor([0.0839]) tensor([0.0165]) 0.0001 tensor([1.4605]) tensor([1.4605])
# 0.04971396550536156
# getMLE seems to have failed, tensor([0.0497]) tensor([0.0317]) tensor([-0.0180]) tensor([0.1005]) tensor([0.0839]) tensor([0.0165]) -0.0001 tensor([1.4605]) tensor([1.4605])
# 0.04971396550536156
# ...

# %%
from torch import *

t1 = torch.tensor(1., requires_grad=True)
t1b = t1.detach().requires_grad_()
t2 = 2 * t1b
t3 = t2 * t1
print(t2.grad_fn)
temp = t2.grad_fn
#t2.grad_fn = None
t3.backward(retain_graph=True)
print(t1.grad)
t3.backward(retain_graph=True)
print(t1.grad)
#t2.requires_grad = False
t3.backward(retain_graph=True)
print(t1.grad)
#t2.requires_grad = True
t3.backward(retain_graph=True)
print(t1.grad)
t1.grad = t1.grad + t1b.grad
print(t1.grad)
t3.backward(retain_graph=True)
print(t1.grad)
t3.extra_attr = 3
print(t3.extra_attr)
# Out:
# ...
# tensor(2.)
# tensor(4.)
# tensor(6.)
# tensor(8.)
# tensor(16.)
# tensor(18.)
# 3

# %%
type(3)
# Out:
# int

# %%
import pyro
from pyro import distributions as dist
import torch

EULER_CONSTANT = 0.5772156649015328606065120900824024310421
gd = dist.Gumbel(torch.tensor(-EULER_CONSTANT),torch.tensor(1.))
print(gd.sample())
torch.mean(gd.sample([1000000]))
# Out:
# tensor(-1.3647)
# tensor(0.0003)

# %%
from importlib import reload
import demo #import *
reload(demo)
from demo import *
import cProfile as profile

if True:

    for aniter in range(1):
        for nparticles in [1]:
            for guidename in ["meanfield","laplace"]:
                for eparams in [ndom_params]:#, even_params, gdom_params, neggum_params]:
                    #

                    print(aniter,nparticles,guidename,eparams)
                    result = trainGuide(guidename,nparticles,eparams,filename="testresults/demo_other_4.csv")
                    print(aniter,nparticles,guidename,eparams)
                    for line in range(10):
                        print()
                    
else:
    plt.plot([getMLE(.01 + x/100,1.,0,1.) for x in range(500)])
# Out:
# 0 1 meanfield {'modal_effect': tensor(-0.5000), 'norm_scale': tensor(0.2000), 'gum_scale': tensor(0.0100)}
# Not none.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-99220a05f1e1> in <module>
#      14
#      15                     print(aniter,nparticles,guidename,eparams)
# ---> 16                     result = trainGuide(guidename,nparticles,eparams,filename="testresults/demo_other_4.csv")
#      17                     print(aniter,nparticles,guidename,eparams)
#      18                     for line in range(10):
#
# ~\Dropbox\eipython\eipython\demo.py in trainGuide(guidename, nparticles, trueparams, filename)
#     478                                     "norm_scale","gum_scale")]]
#     479     for i in range(3001):
# --> 480         loss = svi.step(N,effects,errors,ts(10.),ts(10.))
#     481         if len(losses)==0:
# ...

# %%
print(2 + 2)
# Out:
# 4

# %%
from importlib import reload
import twobytwo #import *
reload(twobytwo)
from twobytwo import *
import cProfile as profile

if True:

    for aniter in range(1):
        for nparticles in [1,5]:
                    #
                    print(aniter,nparticles)
                    result = trainGuide(nparticles,filename="testresults/ei_amortized_laplace_transparent_.csv")
                    print(aniter,nparticles)
                    for line in range(10):
                        print()
                    
else:
    plt.plot([getMLE(.01 + x/100,1.,0,1.) for x in range(500)])
# Out:
# Reloading cmult...
# Reloading polytopize.
# Reloading polytopize.
# Reloading polytopize.
# 0 1
# ec:tensor([0.0000, 0.5000])
# erc:tensor([[0., 1.],
#         [2., 0.]])
# y[0]:tensor([[102., 498.],
#         [  8.,   2.]])
# C:\Users\jameson\Dropbox\eipython\eipython\rank1torch.py:70: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   alpha, lu_ = torch.gesv(torch.mm(M_alpha.permute(1,0),v_d), torch.mm(M_alpha.permute(1,0),M_alpha))
# C:\Users\jameson\Dropbox\eipython\eipython\rank1torch.py:75: UserWarning: torch.gesv is deprecated in favour of torch.solve and will be removed in the next release. Please use torch.solve instead.
#   beta, lu_ = torch.gesv( torch.mm(M_beta.permute(1,0),v_d), torch.mm(M_beta.permute(1,0),M_beta))
# depolytopize fail
# 2 2 tensor([[ 7.5293e+07,  1.4797e+08],
#         [-3.4362e+07,  3.8083e+07]], grad_fn=<MulBackward0>) tensor([[108.1967, 491.8033],
# ...
