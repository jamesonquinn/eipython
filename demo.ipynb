# %% [markdown]
# # Quick intro
#
# This is a jupyter notebook for testing / coding. So far, each code block is a separate test; unlike an ordinary notebook, they are not meant to run sequentially.
#
# First, test to see jupyter is running correctly at all:

# %%
from importlib import reload
import demo #import *
reload(demo)
from demo import *
import cProfile as profile

#vals = MIDDF35
guidenames = ["laplace","meanfield","MLE"]
if True:

    for aniter in range(1):
        for nparticles in [1]:#,5]:
                for vals in [LOWDF0,LOWDF5,LOWDF15,LOWDF35,MIDDF35,HIDF0,HIDF5,HIDF15]:
                    #

                    print(aniter,nparticles,guidenames,)
                    result = trainGuides(guidenames,nparticles,vals,filename="testresults/demo_amortized_laplace_reduced_4.csv")
                    print(aniter,nparticles,guidenames)
                    for line in range(10):
                        print()
                    
else:
    plt.plot([getMLE(.01 + x/100,1.,0,1.) for x in range(500)])
# Out:
# 0 1 ['laplace', 'meanfield', 'MLE']
# laplace vals OrderedDict([('obs', tensor(0.)), ('df', tensor(3.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 11.213898420333862;
# epoch 100 loss = 1.8297195434570312;
# epoch 200 loss = 1.8767861127853394;
# epoch 300 loss = 2.249052047729492;
# epoch 400 loss = 2.201814293861389;
# epoch 500 loss = 3.2918542623519897;
# epoch 600 loss = 1.5579825639724731;
# epoch 700 loss = 0.8903040289878845;
# eff_hat:
# tensor([0.0613, 0.0004], requires_grad=True)
# meanfield vals OrderedDict([('obs', tensor(0.)), ('df', tensor(3.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 11.342654705047607;
# epoch 100 loss = 3.196123719215393;
# epoch 200 loss = 1.2947325706481934;
# epoch 300 loss = 1.0652728080749512;
# epoch 400 loss = 1.7804940342903137;
# epoch 500 loss = 3.092560350894928;
# epoch 600 loss = 1.9769319295883179;
# epoch 700 loss = 0.40944862365722656;
# epoch 800 loss = 4.3836787939071655;
# eff_hat:
# tensor([-0.0137, -0.0230], requires_grad=True)
# sig:
# tensor([0.2536, 0.3488], grad_fn=<AddBackward0>)
# MLE vals OrderedDict([('obs', tensor(0.)), ('df', tensor(3.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 5.39361709356308;
# epoch 100 loss = 2.004499137401581;
# epoch 200 loss = 2.0044254660606384;
# epoch 300 loss = 2.0044254660606384;
# epoch 400 loss = 2.0044254660606384;
# epoch 500 loss = 2.0044254660606384;
# epoch 600 loss = 2.0044254660606384;
# epoch 700 loss = 2.0044254660606384;
# epoch 800 loss = 2.0044254660606384;
# eff_hat:
# tensor([ 3.4398e-19, -3.4398e-19], requires_grad=True)
# 0 1 ['laplace', 'meanfield', 'MLE']
#
#
#
#
#
#
#
#
#
#
# 0 1 ['laplace', 'meanfield', 'MLE']
# laplace vals OrderedDict([('obs', tensor(5.)), ('df', tensor(3.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 98.6199140548706;
# epoch 100 loss = 4.8546053767204285;
# epoch 200 loss = 4.223008394241333;
# epoch 300 loss = 4.455193400382996;
# epoch 400 loss = 5.057097911834717;
# epoch 500 loss = 4.101758718490601;
# epoch 600 loss = 4.725888609886169;
# epoch 700 loss = 4.505845904350281;
# eff_hat:
# tensor([1.2700, 3.9261], requires_grad=True)
# meanfield vals OrderedDict([('obs', tensor(5.)), ('df', tensor(3.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 78.18559050559998;
# epoch 100 loss = 6.266822516918182;
# epoch 200 loss = 12.45064401626587;
# epoch 300 loss = 6.611820816993713;
# epoch 400 loss = 7.0827431082725525;
# epoch 500 loss = 7.722247421741486;
# epoch 600 loss = 7.578452885150909;
# epoch 700 loss = 3.450812339782715;
# epoch 800 loss = 6.705807447433472;
# epoch 900 loss = 7.1256528198719025;
# eff_hat:
# tensor([0.9125, 4.1053], requires_grad=True)
# sig:
# tensor([0.3040, 0.4694], grad_fn=<AddBackward0>)
# MLE vals OrderedDict([('obs', tensor(5.)), ('df', tensor(3.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 83.51860904693604;
# epoch 100 loss = 6.205829083919525;
# epoch 200 loss = 6.193792879581451;
# epoch 300 loss = 6.192484557628632;
# epoch 400 loss = 6.192387044429779;
# epoch 500 loss = 6.192382574081421;
# epoch 600 loss = 6.192382872104645;
# epoch 700 loss = 6.192382574081421;
# epoch 800 loss = 6.192382991313934;
# epoch 900 loss = 6.192382574081421;
# eff_hat:
# tensor([0.7238, 4.1447], requires_grad=True)
# 0 1 ['laplace', 'meanfield', 'MLE']
#
#
#
#
#
#
#
#
#
#
# 0 1 ['laplace', 'meanfield', 'MLE']
# laplace vals OrderedDict([('obs', tensor(12.)), ('df', tensor(3.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 433.77278900146484;
# epoch 100 loss = 8.769607305526733;
# epoch 200 loss = 7.884479761123657;
# epoch 300 loss = 6.7581154108047485;
# epoch 400 loss = 6.873623967170715;
# epoch 500 loss = 8.668454051017761;
# epoch 600 loss = 13.478034496307373;
# epoch 700 loss = 6.328506290912628;
# epoch 800 loss = 9.100349485874176;
# epoch 900 loss = 7.510712742805481;
# eff_hat:
# tensor([4.6139, 7.2627], requires_grad=True)
# meanfield vals OrderedDict([('obs', tensor(12.)), ('df', tensor(3.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 561.6131103038788;
# epoch 100 loss = 11.25068575143814;
# epoch 200 loss = 11.626501023769379;
# epoch 300 loss = 11.421338319778442;
# epoch 400 loss = 10.573325872421265;
# epoch 500 loss = 9.917707860469818;
# epoch 600 loss = 11.27693796157837;
# epoch 700 loss = 12.366294205188751;
# epoch 800 loss = 9.633572340011597;
# epoch 900 loss = 10.384863018989563;
# epoch 1000 loss = 9.428725481033325;
# epoch 1100 loss = 5.1359365582466125;
# eff_hat:
# tensor([ 0.4172, 11.7326], requires_grad=True)
# sig:
# tensor([0.2888, 0.3463], grad_fn=<AddBackward0>)
# MLE vals OrderedDict([('obs', tensor(12.)), ('df', tensor(3.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 455.393593788147;
# epoch 100 loss = 11.919532418251038;
# epoch 200 loss = 11.69612169265747;
# epoch 300 loss = 11.411097347736359;
# epoch 400 loss = 10.845759272575378;
# epoch 500 loss = 9.992217779159546;
# epoch 600 loss = 9.741537928581238;
# epoch 700 loss = 9.737904727458954;
# epoch 800 loss = 9.737898170948029;
# epoch 900 loss = 9.737898766994476;
# epoch 1000 loss = 9.737899124622345;
# epoch 1100 loss = 9.737899124622345;
# epoch 1200 loss = 9.737899124622345;
# eff_hat:
# tensor([ 0.2566, 11.6898], requires_grad=True)
# 0 1 ['laplace', 'meanfield', 'MLE']
#
#
#
#
#
#
#
#
#
#
# 0 1 ['laplace', 'meanfield', 'MLE']
# laplace vals OrderedDict([('obs', tensor(32.)), ('df', tensor(3.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 3161.085659980774;
# epoch 100 loss = 471.2823052406311;
# epoch 200 loss = 15.5809046626091;
# epoch 300 loss = 17.20584535598755;
# epoch 400 loss = 16.602473258972168;
# epoch 500 loss = 16.564915657043457;
# epoch 600 loss = 16.937763333320618;
# epoch 700 loss = 17.073058605194092;
# epoch 800 loss = 15.918164253234863;
# epoch 900 loss = 16.06654578447342;
# epoch 1000 loss = 16.38380068540573;
# epoch 1100 loss = 16.22145175933838;
# eff_hat:
# tensor([13.1544, 18.6839], requires_grad=True)
# meanfield vals OrderedDict([('obs', tensor(32.)), ('df', tensor(3.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 3196.2001435756683;
# epoch 100 loss = 363.3010108470917;
# epoch 200 loss = 20.76055884361267;
# epoch 300 loss = 20.193292140960693;
# epoch 400 loss = 18.603181540966034;
# epoch 500 loss = 19.266717433929443;
# epoch 600 loss = 19.692973613739014;
# epoch 700 loss = 19.886413991451263;
# epoch 800 loss = 19.724030554294586;
# epoch 900 loss = 19.455680429935455;
# epoch 1000 loss = 19.812194645404816;
# eff_hat:
# tensor([13.5989, 18.5777], requires_grad=True)
# sig:
# tensor([0.3308, 0.3186], grad_fn=<AddBackward0>)
# MLE vals OrderedDict([('obs', tensor(32.)), ('df', tensor(3.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 3205.393410682678;
# epoch 100 loss = 465.9999294281006;
# epoch 200 loss = 19.830345153808594;
# epoch 300 loss = 19.76816815137863;
# epoch 400 loss = 19.764976263046265;
# epoch 500 loss = 19.761060059070587;
# epoch 600 loss = 19.7563236951828;
# epoch 700 loss = 19.750651836395264;
# epoch 800 loss = 19.743878543376923;
# epoch 900 loss = 19.735800206661224;
# epoch 1000 loss = 19.72614222764969;
# epoch 1100 loss = 19.71455889940262;
# epoch 1200 loss = 19.700591146945953;
# epoch 1300 loss = 19.6836496591568;
# epoch 1400 loss = 19.662944972515106;
# epoch 1500 loss = 19.637413024902344;
# epoch 1600 loss = 19.60560804605484;
# epoch 1700 loss = 19.565504014492035;
# epoch 1800 loss = 19.514215111732483;
# epoch 1900 loss = 19.44749242067337;
# epoch 2000 loss = 19.358851492404938;
# epoch 2100 loss = 19.237900376319885;
# epoch 2200 loss = 19.066868901252747;
# epoch 2300 loss = 18.812386393547058;
# epoch 2400 loss = 18.402263343334198;
# epoch 2500 loss = 17.637798964977264;
# epoch 2600 loss = 15.651234149932861;
# epoch 2700 loss = 13.669596374034882;
# epoch 2800 loss = 13.66889351606369;
# epoch 2900 loss = 13.66889375448227;
# epoch 3000 loss = 13.66889375448227;
# eff_hat:
# tensor([ 0.0941, 31.8859], requires_grad=True)
# 0 1 ['laplace', 'meanfield', 'MLE']
#
#
#
#
#
#
#
#
#
#
# 0 1 ['laplace', 'meanfield', 'MLE']
# laplace vals OrderedDict([('obs', tensor(32.)), ('df', tensor(7.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 3059.4225690364838;
# epoch 100 loss = 457.08625626564026;
# epoch 200 loss = 26.79407161474228;
# epoch 300 loss = 22.840229988098145;
# epoch 400 loss = 23.847846746444702;
# epoch 500 loss = 28.130105018615723;
# epoch 600 loss = 27.402701795101166;
# epoch 700 loss = 27.334722101688385;
# epoch 800 loss = 28.748502731323242;
# epoch 900 loss = 28.335718095302582;
# epoch 1000 loss = 27.39010787010193;
# eff_hat:
# tensor([13.2470, 18.7612], requires_grad=True)
# meanfield vals OrderedDict([('obs', tensor(32.)), ('df', tensor(7.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 2932.0412039756775;
# epoch 100 loss = 394.29060459136963;
# epoch 200 loss = 41.236401081085205;
# epoch 300 loss = 30.611263871192932;
# epoch 400 loss = 30.39642095565796;
# epoch 500 loss = 31.124203264713287;
# epoch 600 loss = 30.642478823661804;
# epoch 700 loss = 32.01635801792145;
# epoch 800 loss = 30.044493079185486;
# epoch 900 loss = 30.450492799282074;
# epoch 1000 loss = 30.487783670425415;

# %%
#raise Exception()
from importlib import reload
import twobytwo #import *
reload(twobytwo)
from twobytwo import *
import cProfile as profile

if True:

    for aniter in range(1):
        for nparticles in [1,5]:
                    #
                    print(aniter,nparticles)
                    result = trainGuide(nparticles,filename="testresults/ei2_amortized_laplace_transparent_.csv")
                    print(aniter,nparticles)
                    for line in range(10):
                        print()
                    
else:
    plt.plot([getMLE(.01 + x/100,1.,0,1.) for x in range(500)])
# Out:
# Reloading cmult...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-21-ff6c853df29d> in <module>
#       1 #raise Exception()
#       2 from importlib import reload
# ----> 3 import twobytwo #import *
#       4 reload(twobytwo)
#       5 from twobytwo import *
#
# ~\Dropbox\eipython\eipython\twobytwo.py in <module>
#      32 import go_or_nogo
#      33 from cmult import CMult
# ---> 34 from vecdelta import VecDelta
#      35 import linearize
#      36 reload(linearize)
#
# ModuleNotFoundError: No module named 'vecdelta'

# %%
raise Exception()
from importlib import reload
import mlm #import *
reload(mlm)
from mlm import *
import cProfile as profile

if True:

    for aniter in range(1):
        for nparticles in [1,5]:
                    #
                    print(aniter,nparticles)
                    result = trainGuide(nparticles,filename="testresults/mlm7_amortized_laplace_transparent_.csv")
                    print(aniter,nparticles)
                    for line in range(10):
                        print()
                    
else:
    plt.plot([getMLE(.01 + x/100,1.,0,1.) for x in range(500)])
# Out:
# Reloading linearize.
# Reloading linearize.
# 0 1
# ec:tensor([0.0000, 0.5000, 0.0000])
# erc:tensor([[0., 1., 2.],
#         [2., 0., 0.]])
# y[0]:tensor([[3.3500e+02, 6.5100e+02, 5.0140e+03],
#         [8.0000e+00, 2.0000e+00, 0.0000e+00]])
# trueparams OrderedDict([('ec', tensor([0.0000, 0.5000, 0.0000])), ('erc', tensor([[0., 1., 2.],
#         [2., 0., 0.]])), ('eprc', tensor([[[ 0.2198,  0.0562,  0.3204],
#          [ 0.2206, -0.1079, -0.3713]],
#
#         [[ 0.2814,  0.1298,  0.2614],
#          [ 1.1511, -0.7344, -0.7933]],
#
#         [[ 0.6016,  0.0423, -0.6001],
#          [-0.0024, -0.1152, -0.1959]],
#
#         [[ 0.2716, -0.1976,  0.1028],
#          [-0.2252, -0.2865, -0.2777]],
#
#         [[-0.7656, -0.6171,  0.9099],
#          [-0.2758, -0.6627,  0.0943]],
#
#         [[-0.0345, -0.2475, -0.7391],
#          [ 1.2836, -0.2366,  0.1678]],
#
#         [[ 0.7546,  1.0410,  0.8534],
#          [ 1.1902, -0.5335,  0.5575]],
#
#         [[-0.0703,  0.4029,  0.1638],
#          [-0.3804, -0.7995,  0.0092]],
#
#         [[ 0.4209, -0.2000,  0.5197],
#          [ 0.1791, -0.0017, -0.2672]],
#
#         [[ 0.5843,  0.1973, -0.5225],
#          [-0.4783,  0.0168,  0.3550]],
#
#         [[-0.7676, -0.2063,  0.4832],
#          [ 0.8124, -1.3067, -0.8482]],
#
#         [[-0.1141,  0.1400,  0.0366],
#          [ 0.5567,  0.1411,  0.2171]],
#
#         [[ 0.2285, -0.4327,  0.3907],
#          [-0.4634,  0.1032, -0.1667]],
#
#         [[-0.2144,  0.1165,  0.4813],
#          [ 0.1746, -0.4607, -0.0281]],
#
#         [[-0.3508,  0.5183, -0.3018],
#          [-0.6394,  0.0620,  0.5824]],
#
#         [[ 0.4617,  0.6936,  0.6875],
#          [ 0.3298,  0.2383, -0.5082]],
#
#         [[ 0.3052,  0.2334,  0.9753],
#          [-0.5315,  0.5702, -0.0449]],
#
#         [[ 0.3649, -0.9227, -0.0510],
#          [-0.5168, -0.1563,  0.1229]],
#
#         [[ 0.1886,  0.5506, -0.5714],
#          [ 0.0188,  0.1443,  0.1933]],
#
#         [[-0.1005, -0.0590, -0.4147],
#          [-0.7036,  0.8134,  0.0861]],
#
#         [[-0.3521,  0.1574,  0.0787],
#          [ 0.1927,  0.2868,  0.4990]],
#
#         [[ 0.2718,  0.0394,  0.4992],
#          [-0.2494,  0.3806,  0.3092]],
#
#         [[-0.1497, -0.0939,  0.9579],
#          [ 0.3451, -0.1570, -0.5394]],
#
#         [[ 0.1204, -0.6981,  0.0568],
#          [ 0.5524, -0.6976,  0.2376]],
#
#         [[ 0.5405,  0.0657,  0.7868],
#          [ 0.3907,  0.4937, -0.7439]],
#
#         [[ 0.2933,  0.0791,  0.3334],
#          [-0.4972, -0.5947, -0.5980]],
#
#         [[ 0.6559, -0.1049,  0.3909],
#          [ 0.4948,  0.0858,  0.4380]],
#
#         [[-0.1435,  0.5108,  0.2193],
#          [-0.0054,  0.6692, -0.1397]],
#
#         [[-0.2759, -1.4445, -0.7550],
#          [ 0.5121,  0.0977, -0.3686]],
#
#         [[ 0.8501,  0.1731,  0.4856],
#          [ 0.7251, -0.0260, -0.3142]]])), ('corr', tensor([[ 0.0182, -0.0857,  0.1101],
#         [-0.1071,  0.0123, -0.0566]]))])
# epoch 0 loss = 96236.84943652153; logsdrchat = 1.9950000047683716;
#  erchat = tensor([[-0.0050, -0.0050,  0.0050],
#         [ 0.0050, -0.0050, -0.0050]], requires_grad=True)
#  corrhat = tensor([[-0.0050, -0.0050,  0.0050],
#         [-0.0050,  0.0050,  0.0050]], requires_grad=True)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-b7b3064739de> in <module>
#      11                     #
#      12                     print(aniter,nparticles)
# ---> 13                     result = trainGuide(nparticles,filename="testresults/mlm7_amortized_laplace_transparent_.csv")
#      14                     print(aniter,nparticles)
#      15                     for line in range(10):
#
# ~\Dropbox\eipython\eipython\mlm.py in trainGuide(nparticles, filename)
#     461                     #                 "norm_scale","gum_scale")]]
#     462     for i in range(3001):
# --> 463         loss = svi.step(processed_data, include_nuisance=True)
#     464         if len(losses)==0:
#     465             mean_losses.append(loss)
#
# ~\Anaconda3new\lib\site-packages\pyro\infer\svi.py in step(self, *args, **kwargs)
#      97         # get loss and compute gradients
#      98         with poutine.trace(param_only=True) as param_capture:
# ---> 99             loss = self.loss_and_grads(self.model, self.guide, *args, **kwargs)
#     100
#     101         params = set(site["value"].unconstrained()
#
# ~\Anaconda3new\lib\site-packages\pyro\infer\trace_elbo.py in loss_and_grads(self, model, guide, *args, **kwargs)
#     134             if trainable_params and getattr(surrogate_loss_particle, 'requires_grad', False):
#     135                 surrogate_loss_particle = surrogate_loss_particle / self.num_particles
# --> 136                 surrogate_loss_particle.backward(retain_graph=self.retain_graph)
#     137
#     138         warn_if_nan(loss, "loss")
#
# ~\Anaconda3new\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     105                 products. Defaults to ``False``.
#     106         """
# --> 107         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     108
#     109     def register_hook(self, hook):
#
# ~\Anaconda3new\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      91     Variable._execution_engine.run_backward(
#      92         tensors, grad_tensors, retain_graph, create_graph,
# ---> 93         allow_unreachable=True)  # allow_unreachable flag
#      94
#      95
#
# KeyboardInterrupt:
