# %% [markdown]
# # Quick intro
#
# One pair of ts, with pictures:

# %%
from importlib import reload
import twoT #import *
reload(twoT)
from twoT import *
import cProfile as profile

#vals = MIDDF35
guidenames = ["laplace","meanfield"]#,"MLE"]
if True:

    for aniter in range(1):
        for nparticles in [1]:#,5]:
                for vals in [LOWDF0,LOWDFM,LOWDFP,MIDDFP,HIDF0,HIDFP]:
                    #

                    print(aniter,nparticles,guidenames,)
                    result = trainGuides(guidenames,nparticles,vals,filename="testresults/demo_amortized_laplace_reduced_4.csv")
                    print(aniter,nparticles,guidenames)
                    for line in range(10):
                        print()
                    
else:
    plt.plot([getMLE(.01 + x/100,1.,0,1.) for x in range(500)])
# Out:
# 0 1 ['laplace', 'meanfield']
# laplace vals OrderedDict([('obs', tensor(0.)), ('df', tensor(2.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = -0.008596658706665039;
# epoch 100 loss = 2.5719059705734253;
# epoch 200 loss = 2.162261962890625;
# epoch 300 loss = 1.8095185160636902;
# epoch 400 loss = 1.99400395154953;
# epoch 500 loss = 1.8942113518714905;
# epoch 600 loss = 1.815032720565796;
# eff_hat:
# tensor([ 0.1741, -0.0342], requires_grad=True)
# psi:
# tensor([0.2612, 0.2282], grad_fn=<AddBackward0>)
# meanfield vals OrderedDict([('obs', tensor(0.)), ('df', tensor(2.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# C:\Users\jameson\Dropbox\eipython\eipython\twoT.py:136: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   store_row.update([(k,ts(v)) for k,v in hat_data.items()])
# epoch 0 loss = 10.813115358352661;
# epoch 100 loss = 2.1935251355171204;
# epoch 200 loss = 2.0224253237247467;
# epoch 300 loss = 2.1799119114875793;
# epoch 400 loss = 3.8361003398895264;
# epoch 500 loss = 1.9290125370025635;
# epoch 600 loss = 2.5967289209365845;
# epoch 700 loss = 6.072295248508453;
# epoch 800 loss = 3.0912476778030396;
# epoch 900 loss = 3.186836063861847;
# epoch 1000 loss = 1.9221493005752563;
# epoch 1100 loss = 3.0419704914093018;
# epoch 1200 loss = 0.4058840274810791;
# epoch 1300 loss = 2.4186800718307495;
# epoch 1400 loss = 2.172408103942871;
# epoch 1500 loss = 7.351939916610718;
# epoch 1600 loss = 1.113293170928955;
# epoch 1700 loss = 1.8746693134307861;
# epoch 1800 loss = -0.6487654447555542;
# epoch 1900 loss = 1.6092604398727417;
# epoch 2000 loss = 2.701389193534851;
# epoch 2100 loss = 0.9251883029937744;
# epoch 2200 loss = 3.7277048230171204;
# epoch 2300 loss = 1.944589912891388;
# epoch 2400 loss = 2.1471357941627502;
# epoch 2500 loss = 3.6168627738952637;
# epoch 2600 loss = 2.197924852371216;
# eff_hat:
# tensor([0.0596, 0.0487], requires_grad=True)
# sig:
# tensor([0.3743, 0.2737], grad_fn=<AddBackward0>)
# 0 1 ['laplace', 'meanfield']
#
#
#
#
#
#
#
#
#
#
# 0 1 ['laplace', 'meanfield']
# laplace vals OrderedDict([('obs', tensor(3.)), ('df', tensor(2.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 25.222325801849365;
# epoch 100 loss = 3.9206655621528625;
# epoch 200 loss = 2.934166669845581;
# epoch 300 loss = 2.9637003540992737;
# epoch 400 loss = 3.2442551255226135;
# epoch 500 loss = 3.205354154109955;
# epoch 600 loss = 2.847961902618408;
# epoch 700 loss = 2.9974841475486755;
# epoch 800 loss = 3.1489614248275757;
# epoch 900 loss = 3.4004449248313904;
# epoch 1000 loss = 2.8854640126228333;
# epoch 1100 loss = 2.426615536212921;
# epoch 1200 loss = 4.135996103286743;
# epoch 1300 loss = 2.944355547428131;
# epoch 1400 loss = 2.588875651359558;
# epoch 1500 loss = 3.724181890487671;
# epoch 1600 loss = 4.550382971763611;
# epoch 1700 loss = 3.3933059573173523;
# epoch 1800 loss = 3.443280816078186;
# epoch 1900 loss = 2.614958345890045;
# epoch 2000 loss = 3.383993148803711;
# epoch 2100 loss = 3.1741878390312195;
# epoch 2200 loss = 2.9975630044937134;
# epoch 2300 loss = 3.0240906476974487;
# epoch 2400 loss = 2.872489273548126;
# epoch 2500 loss = 2.2047388553619385;
# epoch 2600 loss = 3.1233410239219666;
# epoch 2700 loss = 2.6462698578834534;
# eff_hat:
# tensor([1.3418, 1.3166], requires_grad=True)
# psi:
# tensor([0.2344, 0.3259], grad_fn=<AddBackward0>)
# meanfield vals OrderedDict([('obs', tensor(3.)), ('df', tensor(2.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 71.62018537521362;
# epoch 100 loss = 4.2796794176101685;
# epoch 200 loss = 5.853982329368591;
# epoch 300 loss = 1.6455949544906616;
# epoch 400 loss = 5.8875322341918945;
# epoch 500 loss = 4.025367975234985;
# epoch 600 loss = 4.728783369064331;
# epoch 700 loss = 3.765490710735321;
# epoch 800 loss = 3.5607699155807495;
# epoch 900 loss = 2.9355995655059814;
# epoch 1000 loss = 4.415423214435577;
# epoch 1100 loss = 3.5321402549743652;
# epoch 1200 loss = 5.929257869720459;
# epoch 1300 loss = 3.655705749988556;
# epoch 1400 loss = 5.304177284240723;
# epoch 1500 loss = 3.452599883079529;
# epoch 1600 loss = 3.0813319087028503;
# epoch 1700 loss = 5.418394923210144;
# epoch 1800 loss = 4.573080062866211;
# epoch 1900 loss = 2.7133500576019287;
# epoch 2000 loss = 4.542166888713837;
# epoch 2100 loss = 4.70402193069458;
# epoch 2200 loss = 4.724534630775452;
# epoch 2300 loss = 1.4289828538894653;
# epoch 2400 loss = 4.373505234718323;
# epoch 2500 loss = 2.9845966696739197;
# epoch 2600 loss = 3.9425888657569885;
# epoch 2700 loss = 4.590188145637512;
# epoch 2800 loss = 3.915468215942383;
# epoch 2900 loss = 5.2404255867004395;
# epoch 3000 loss = 2.8225383162498474;
# eff_hat:
# tensor([1.5600, 1.5221], requires_grad=True)
# sig:
# tensor([0.3196, 0.3867], grad_fn=<AddBackward0>)
# 0 1 ['laplace', 'meanfield']
#
#
#
#
#
#
#
#
#
#
# 0 1 ['laplace', 'meanfield']
# laplace vals OrderedDict([('obs', tensor(7.)), ('df', tensor(2.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 158.38158893585205;
# epoch 100 loss = 5.4869807958602905;
# epoch 200 loss = 5.426453590393066;
# epoch 300 loss = 5.587800443172455;
# epoch 400 loss = 5.534678936004639;
# epoch 500 loss = 4.727529406547546;
# epoch 600 loss = 4.3102803230285645;
# epoch 700 loss = 5.795637309551239;
# epoch 800 loss = 5.785664737224579;
# epoch 900 loss = 4.12416672706604;
# epoch 1000 loss = 5.977981448173523;
# epoch 1100 loss = 4.295114815235138;
# epoch 1200 loss = 4.32008022069931;
# epoch 1300 loss = 4.101995289325714;
# epoch 1400 loss = 4.24366682767868;
# epoch 1500 loss = 5.813166230916977;
# epoch 1600 loss = 5.708482027053833;
# epoch 1700 loss = 4.421108067035675;
# epoch 1800 loss = 6.438927054405212;
# epoch 1900 loss = 4.386392593383789;
# epoch 2000 loss = 6.6145734786987305;
# epoch 2100 loss = 5.946430683135986;
# epoch 2200 loss = 5.338479936122894;
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-19d19b2953ea> in <module>
#      15
#      16                     print(aniter,nparticles,guidenames,)
# ---> 17                     result = trainGuides(guidenames,nparticles,vals,filename="testresults/demo_amortized_laplace_reduced_4.csv")
#      18                     print(aniter,nparticles,guidenames)
#      19                     for line in range(10):
#
# ~\Dropbox\eipython\eipython\twoT.py in trainGuides(guidenames, nparticles, vals, filename)
#     380             else:
#     381                 this_store = None
# --> 382             loss = svi.step(store=this_store,**vals)
#     383             if len(losses)==0:
#     384                 mean_losses.append(loss)
#
# ~\Anaconda3new\lib\site-packages\pyro\infer\svi.py in step(self, *args, **kwargs)
#      97         # get loss and compute gradients
#      98         with poutine.trace(param_only=True) as param_capture:
# ---> 99             loss = self.loss_and_grads(self.model, self.guide, *args, **kwargs)
#     100
#     101         params = set(site["value"].unconstrained()
#
# ~\Anaconda3new\lib\site-packages\pyro\infer\trace_elbo.py in loss_and_grads(self, model, guide, *args, **kwargs)
#     123         loss = 0.0
#     124         # grab a trace from the generator
# --> 125         for model_trace, guide_trace in self._get_traces(model, guide, *args, **kwargs):
#     126             loss_particle, surrogate_loss_particle = self._differentiable_loss_particle(model_trace, guide_trace)
#     127             loss += loss_particle / self.num_particles
#
# ~\Anaconda3new\lib\site-packages\pyro\infer\elbo.py in _get_traces(self, model, guide, *args, **kwargs)
#     166         else:
#     167             for i in range(self.num_particles):
# --> 168                 yield self._get_trace(model, guide, *args, **kwargs)
#
# ~\Anaconda3new\lib\site-packages\pyro\infer\trace_elbo.py in _get_trace(self, model, guide, *args, **kwargs)
#      50         """
#      51         model_trace, guide_trace = get_importance_trace(
# ---> 52             "flat", self.max_plate_nesting, model, guide, *args, **kwargs)
#      53         if is_validation_enabled():
#      54             check_if_enumerated(guide_trace)
#
# ~\Anaconda3new\lib\site-packages\pyro\infer\enum.py in get_importance_trace(graph_type, max_plate_nesting, model, guide, *args, **kwargs)
#      40     against it.
#      41     """
# ---> 42     guide_trace = poutine.trace(guide, graph_type=graph_type).get_trace(*args, **kwargs)
#      43     model_trace = poutine.trace(poutine.replay(model, trace=guide_trace),
#      44                                 graph_type=graph_type).get_trace(*args, **kwargs)
#
# ~\Anaconda3new\lib\site-packages\pyro\poutine\trace_messenger.py in get_trace(self, *args, **kwargs)
#     167         Calls this poutine and returns its trace instead of the function's return value.
#     168         """
# --> 169         self(*args, **kwargs)
#     170         return self.msngr.get_trace()
#
# ~\Anaconda3new\lib\site-packages\pyro\poutine\trace_messenger.py in __call__(self, *args, **kwargs)
#     145                                       args=args, kwargs=kwargs)
#     146             try:
# --> 147                 ret = self.fn(*args, **kwargs)
#     148             except (ValueError, RuntimeError):
#     149                 exc_type, exc_value, traceback = sys.exc_info()
#
# ~\Dropbox\eipython\eipython\twoT.py in laplace(assymetry, store, *args, **kwargs)
#      90     blockedTrace = poutine.block(poutine.trace(hessCenter).get_trace)(*args,**kwargs)
#      91     logPosterior = blockedTrace.log_prob_sum()
# ---> 92     Info = -myhessian.hessian(logPosterior, hat_data.values())#, allow_unused=True)
#      93     #print("det:",np.linalg.det(Info.data.numpy()))
#      94     #print(Info)
#
# ~\Dropbox\eipython\eipython\myhessian.py in hessian(output, inputs, out, allow_unused, create_graph, return_grad)
#      36         for j in range(inp.numel()):
#      37             if grad[j].requires_grad:
# ---> 38                 row = gradient(grad[j], inputs[i:], create_graph=True, retain_graph=True)[j:]
#      39             else:
#      40                 row = grad[j].new_zeros(sum(x.numel() for x in inputs[i:]) - j)
#
# ~\Anaconda3new\lib\site-packages\hessian-0.0.0-py3.7.egg\hessian\gradient.py in gradient(outputs, inputs, grad_outputs, retain_graph, create_graph)
#      20                                 allow_unused=True,
#      21                                 retain_graph=retain_graph,
# ---> 22                                 create_graph=create_graph)
#      23     grads = [x if x is not None else torch.zeros_like(y) for x, y in zip(grads, inputs)]
#      24     return torch.cat([x.contiguous().view(-1) for x in grads])
#
# ~\Anaconda3new\lib\site-packages\torch\autograd\__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused)
#     151     return Variable._execution_engine.run_backward(
#     152         outputs, grad_outputs, retain_graph, create_graph,
# --> 153         inputs, allow_unused)
#     154
#     155
#
# KeyboardInterrupt:

# %% [markdown]
# Amortizable hierarchical t model:

# %%
from importlib import reload
import demoT #import *
reload(demoT)
from demoT import *
import cProfile as profile

#vals = MIDDF35
guidenames = ["amortized_laplace"]#,"laplace","amortized_deterministic_laplace",]#,"meanfield",]#,"MLE"]
if True:

    for aniter in range(1):
        for nparticles in [1]:#,5]:
            for trueparams in [tdom_norm_params,ndom_norm_params,tdom_fat_params,ndom_fat_params,]:
                for guidename in guidenames:
                    #

                    print(aniter,nparticles,guidenames,trueparams)
                    result = trainGuide(guidename,nparticles,trueparams,filename="testresults/demoT_2.csv")
                    print(aniter,nparticles,guidenames)
                    for line in range(10):
                        print()
                    
else:
    plt.plot([getMLE(.01 + x/100,1.,0,1.) for x in range(500)])
# Out:
# 0 1 ['amortized_laplace'] {'modal_effect': tensor(1.), 'df': tensor(3.), 't_scale': tensor(2.)}
# generating data {'modal_effect': tensor(1.), 'df': tensor(3.), 't_scale': tensor(2.)}
# creating torch.Size([]) torch.Size([44]) torch.Size([]) torch.Size([44]) torch.Size([44])
# Not none.
# esize torch.Size([44])
# epoch 0 loss = 257.62097215652466;
# mode_hat tensor(-0.0050, requires_grad=True)
# ltscale_hat tensor(0.0050, requires_grad=True)
# ldfraw_hat tensor(-0.0050, requires_grad=True)
# dm.grad
# ddfr.grad
# dtr.grad
# dm.grad
# ddfr.grad
# dtr.grad
# assert approx_eq( tensor([-4.1311e+00,  5.3988e+01,  1.4226e+02, -3.9761e-01,  8.5616e-02,
#          1.5824e+02, -3.9158e+01,  1.4331e+02, -2.2881e+02, -8.1064e+02,
#          3.0884e+02,  9.1687e+02, -2.5434e-02, -8.7596e+00,  1.5286e+02,
#         -7.6829e+01,  9.9354e+01, -3.4451e-02,  2.0036e+03,  2.4094e+01,
#          1.9643e+01,  4.3905e+02,  1.5235e-05,  4.8078e-02,  4.1778e+02,
#          9.6614e+02,  3.1750e+03,  7.2055e+00, -1.7423e-01, -1.7143e+00,
#          2.7560e+02, -7.3539e+00,  1.2760e+01, -2.2226e+01, -5.0139e+01,
#         -6.6374e+01, -1.5462e+03, -2.2587e+02,  3.8167e+03, -5.2968e+01,
#         -5.3406e+02,  8.2842e+00,  1.6216e-01, -2.7425e+01],
#        grad_fn=<PowBackward0>) tensor([ 4.1970e+00, -5.4217e+01, -1.4291e+02,  4.0020e-01, -8.6016e-02,
#         -1.5844e+02,  3.9293e+01, -1.4350e+02,  2.2897e+02,  8.1119e+02,
#         -3.0964e+02, -9.1872e+02,  2.5997e-02,  9.0086e+00, -1.5348e+02,
#          7.7137e+01, -9.9705e+01,  3.4965e-02, -2.0064e+03, -2.4170e+01,
#         -1.9846e+01, -4.3939e+02, -1.6229e-05, -4.8938e-02, -4.1784e+02,
#         -9.6650e+02, -3.1772e+03, -7.4386e+00,  1.7475e-01,  1.8013e+00,
#         -2.7665e+02,  7.3574e+00, -1.3096e+01,  2.2298e+01,  5.0158e+01,
#          6.6430e+01,  1.5464e+03,  2.2608e+02, -3.8170e+03,  5.3610e+01,
#          5.3623e+02, -8.4542e+00, -1.6297e-01,  2.7469e+01],
#        grad_fn=<MulBackward0>) tensor([ -7.4616,  17.4486,  24.4428,  -3.3604,   2.0094,  24.7677, -15.5945,
#          23.9642, -27.9274, -42.8894,  31.5506,  46.0069,  -1.3643,  -9.8672,
#          24.9778, -19.6721,  21.4383,  -1.4988,  60.1265,  13.2205,  12.5700,
#          34.8580,   0.1198,   1.6801,  33.9857,  45.2278,  68.9507,   9.2795,
#          -2.5420,  -5.7925,  30.6907,  -8.8305,  11.2157, -12.8685, -16.8153,
#         -18.4410, -52.6425, -27.8626,  71.2427, -17.9243, -39.1342,   9.5384,
#          1051.6630,  -152.2751,  2020.0090,  -289.4275, -1499.6334,   225.8264,
#          -935.4119,  -132.0632,  2160.2153,   264.7486,  2146.9233, -1057.1154,
#         -2594.4009,  -527.0780,   351.5890,  1083.7070,  4623.8760,  5982.7202,
#           151.4789,  6491.1641,  -678.2402,  -112.9432,   778.3702,   403.4937,
#          2306.0837,   -25.5226,   970.9512,  -871.0499, -2694.8792,  -925.0692,
#          -468.1620, -5449.2222], grad_fn=<MulBackward0>) tensor([-3529.7622, -1364.6570, -1966.4541,   870.6577,   510.1041,   721.5544,
#          3445.8752,   711.6554,  2788.6211,  -478.0892,   607.8393,  5021.3369,
#         -1051.5906,   152.2745, -2019.5248,   289.4260,  1499.4697,  -225.8257,
#           935.2929,   132.0631, -2159.7075,  -264.7480, -2145.7085,  1057.0557,
#          2594.3438,   527.0741,  -351.5843, -1083.5026, -4623.6772, -5975.6372,
#          -151.4783, -6491.0571,   678.1860,   112.9431,  -778.3629,  -403.4927,
#         -2306.0088,    25.5227,  -970.9388,   870.9510,  2692.9998,   924.9813,
#           468.1602,  5448.7710], grad_fn=<MulBackward0>)
# assert2 approx_eq( tensor([ 6.3477e-03,  2.4414e-04,  1.2207e-04, -1.2207e-04,  6.1035e-05,
#         -1.2207e-04, -7.3242e-04, -6.1035e-05, -7.3242e-04,  1.2207e-04,
#         -1.2207e-04, -1.9531e-03,  1.2207e-04,  4.5776e-05,  0.0000e+00,
#          3.0518e-05, -2.4414e-04,  1.2207e-04, -6.1035e-05,  0.0000e+00,
#          2.4414e-04,  3.0518e-05,  0.0000e+00,  1.2207e-04, -4.8828e-04,
#         -1.2207e-04,  3.0518e-05,  1.2207e-04, -1.5381e-01,  4.8828e-03,
#          1.0681e-04,  9.2773e-03,  6.1035e-05, -6.1035e-05,  1.8311e-04,
#          1.2207e-04,  4.8828e-04,  4.9591e-05, -6.1035e-05,  0.0000e+00,
#         -2.4414e-04,  0.0000e+00, -3.0518e-05,  0.0000e+00],
#        grad_fn=<AddBackward0>)
# Final mean_losses: 215.43594939699335
# ldfraw_hat:
# -1.0056445598602295
# lpsi:
# tensor([-6.5004, -3.2051, -5.9407, -5.9225, -5.9701, -5.7857, -5.9744, -5.8492,
#         -5.8981, -5.9039], requires_grad=True)
# ltscale_hat:
# 2.1696927547454834
# mode_hat:
# 0.02049154043197632
# 0 1 ['amortized_laplace']
#
#
#
#
#
#
#
#
#
#
# 0 1 ['amortized_laplace'] {'modal_effect': tensor(1.), 'df': tensor(-1.), 't_scale': tensor(-2.)}
# generating data {'modal_effect': tensor(1.), 'df': tensor(-1.), 't_scale': tensor(-2.)}
# creating torch.Size([]) torch.Size([44]) torch.Size([]) torch.Size([44]) torch.Size([44])
# Not none.
# esize torch.Size([44])
# epoch 0 loss = 115.02763247489929;
# mode_hat tensor(0.0050, requires_grad=True)
# ltscale_hat tensor(0.0050, requires_grad=True)
# ldfraw_hat tensor(0.0050, requires_grad=True)
# epoch 100 loss = 91.48504567146301;
# mode_hat tensor(0.5050, requires_grad=True)
# ltscale_hat tensor(-0.2167, requires_grad=True)
# ldfraw_hat tensor(0.5048, requires_grad=True)
# epoch 200 loss = 97.3850257396698;
# mode_hat tensor(0.9285, requires_grad=True)
# ltscale_hat tensor(-0.6097, requires_grad=True)
# ldfraw_hat tensor(0.9947, requires_grad=True)
# epoch 300 loss = 70.77644371986389;
# mode_hat tensor(0.9240, requires_grad=True)
# ltscale_hat tensor(-0.6055, requires_grad=True)
# ldfraw_hat tensor(1.4789, requires_grad=True)
# epoch 400 loss = 79.91177082061768;
# mode_hat tensor(0.9501, requires_grad=True)
# ltscale_hat tensor(-0.5773, requires_grad=True)
# ldfraw_hat tensor(1.9324, requires_grad=True)
# epoch 500 loss = 95.27461504936218;
# mode_hat tensor(0.9107, requires_grad=True)
# ltscale_hat tensor(-0.5429, requires_grad=True)
# ldfraw_hat tensor(2.0551, requires_grad=True)
# epoch 600 loss = 87.71568489074707;
# mode_hat tensor(0.9136, requires_grad=True)
# ltscale_hat tensor(-0.5812, requires_grad=True)
# ldfraw_hat tensor(2.0322, requires_grad=True)
# epoch 700 loss = 93.29251742362976;
# mode_hat tensor(0.9537, requires_grad=True)
# ltscale_hat tensor(-0.5657, requires_grad=True)
# ldfraw_hat tensor(2.0234, requires_grad=True)
# Final mean_losses: 88.62667355749338
# ldfraw_hat:
# 2.0622222423553467
# lpsi:
# tensor([-3.9751, -4.8131, -5.2155, -5.1379, -5.1686, -5.2063, -5.1773, -5.2352,
#         -5.1750, -5.1918], requires_grad=True)
# ltscale_hat:
# -0.5631974339485168
# mode_hat:
# 0.9313360452651978
# 0 1 ['amortized_laplace']

# %%
#raise Exception()
from importlib import reload
import twobytwo #import *
reload(twobytwo)
from twobytwo import *
import cProfile as profile

if True:

    for aniter in range(1):
        for nparticles in [1,5]:
                    #
                    print(aniter,nparticles)
                    result = trainGuide(nparticles,filename="testresults/ei2_amortized_laplace_transparent_.csv")
                    print(aniter,nparticles)
                    for line in range(10):
                        print()
                    
else:
    plt.plot([getMLE(.01 + x/100,1.,0,1.) for x in range(500)])
# Out:
# Reloading cmult...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-23-fe707acf81bf> in <module>
#       2 #raise Exception()
#       3 from importlib import reload
# ----> 4 import twobytwo #import *
#       5 reload(twobytwo)
#       6 from twobytwo import *
#
# ~\Dropbox\eipython\eipython\twobytwo.py in <module>
#      32 import go_or_nogo
#      33 from cmult import CMult
# ---> 34 from vecdelta import VecDelta
#      35 import linearize
#      36 reload(linearize)
#
# ModuleNotFoundError: No module named 'vecdelta'

# %%
raise Exception()
from importlib import reload
import mlm #import *
reload(mlm)
from mlm import *
import cProfile as profile

if True:

    for aniter in range(1):
        for nparticles in [1,5]:
                    #
                    print(aniter,nparticles)
                    result = trainGuide(nparticles,filename="testresults/mlm7_amortized_laplace_transparent_.csv")
                    print(aniter,nparticles)
                    for line in range(10):
                        print()
                    
else:
    plt.plot([getMLE(.01 + x/100,1.,0,1.) for x in range(500)])
# Out:
# Reloading linearize.
# Reloading linearize.
# 0 1
# ec:tensor([0.0000, 0.5000, 0.0000])
# erc:tensor([[0., 1., 2.],
#         [2., 0., 0.]])
# y[0]:tensor([[3.3500e+02, 6.5100e+02, 5.0140e+03],
#         [8.0000e+00, 2.0000e+00, 0.0000e+00]])
# trueparams OrderedDict([('ec', tensor([0.0000, 0.5000, 0.0000])), ('erc', tensor([[0., 1., 2.],
#         [2., 0., 0.]])), ('eprc', tensor([[[ 0.2198,  0.0562,  0.3204],
#          [ 0.2206, -0.1079, -0.3713]],
#
#         [[ 0.2814,  0.1298,  0.2614],
#          [ 1.1511, -0.7344, -0.7933]],
#
#         [[ 0.6016,  0.0423, -0.6001],
#          [-0.0024, -0.1152, -0.1959]],
#
#         [[ 0.2716, -0.1976,  0.1028],
#          [-0.2252, -0.2865, -0.2777]],
#
#         [[-0.7656, -0.6171,  0.9099],
#          [-0.2758, -0.6627,  0.0943]],
#
#         [[-0.0345, -0.2475, -0.7391],
#          [ 1.2836, -0.2366,  0.1678]],
#
#         [[ 0.7546,  1.0410,  0.8534],
#          [ 1.1902, -0.5335,  0.5575]],
#
#         [[-0.0703,  0.4029,  0.1638],
#          [-0.3804, -0.7995,  0.0092]],
#
#         [[ 0.4209, -0.2000,  0.5197],
#          [ 0.1791, -0.0017, -0.2672]],
#
#         [[ 0.5843,  0.1973, -0.5225],
#          [-0.4783,  0.0168,  0.3550]],
#
#         [[-0.7676, -0.2063,  0.4832],
#          [ 0.8124, -1.3067, -0.8482]],
#
#         [[-0.1141,  0.1400,  0.0366],
#          [ 0.5567,  0.1411,  0.2171]],
#
#         [[ 0.2285, -0.4327,  0.3907],
#          [-0.4634,  0.1032, -0.1667]],
#
#         [[-0.2144,  0.1165,  0.4813],
#          [ 0.1746, -0.4607, -0.0281]],
#
#         [[-0.3508,  0.5183, -0.3018],
#          [-0.6394,  0.0620,  0.5824]],
#
#         [[ 0.4617,  0.6936,  0.6875],
#          [ 0.3298,  0.2383, -0.5082]],
#
#         [[ 0.3052,  0.2334,  0.9753],
#          [-0.5315,  0.5702, -0.0449]],
#
#         [[ 0.3649, -0.9227, -0.0510],
#          [-0.5168, -0.1563,  0.1229]],
#
#         [[ 0.1886,  0.5506, -0.5714],
#          [ 0.0188,  0.1443,  0.1933]],
#
#         [[-0.1005, -0.0590, -0.4147],
#          [-0.7036,  0.8134,  0.0861]],
#
#         [[-0.3521,  0.1574,  0.0787],
#          [ 0.1927,  0.2868,  0.4990]],
#
#         [[ 0.2718,  0.0394,  0.4992],
#          [-0.2494,  0.3806,  0.3092]],
#
#         [[-0.1497, -0.0939,  0.9579],
#          [ 0.3451, -0.1570, -0.5394]],
#
#         [[ 0.1204, -0.6981,  0.0568],
#          [ 0.5524, -0.6976,  0.2376]],
#
#         [[ 0.5405,  0.0657,  0.7868],
#          [ 0.3907,  0.4937, -0.7439]],
#
#         [[ 0.2933,  0.0791,  0.3334],
#          [-0.4972, -0.5947, -0.5980]],
#
#         [[ 0.6559, -0.1049,  0.3909],
#          [ 0.4948,  0.0858,  0.4380]],
#
#         [[-0.1435,  0.5108,  0.2193],
#          [-0.0054,  0.6692, -0.1397]],
#
#         [[-0.2759, -1.4445, -0.7550],
#          [ 0.5121,  0.0977, -0.3686]],
#
#         [[ 0.8501,  0.1731,  0.4856],
#          [ 0.7251, -0.0260, -0.3142]]])), ('corr', tensor([[ 0.0182, -0.0857,  0.1101],
#         [-0.1071,  0.0123, -0.0566]]))])
# epoch 0 loss = 96236.84943652153; logsdrchat = 1.9950000047683716;
#  erchat = tensor([[-0.0050, -0.0050,  0.0050],
#         [ 0.0050, -0.0050, -0.0050]], requires_grad=True)
#  corrhat = tensor([[-0.0050, -0.0050,  0.0050],
#         [-0.0050,  0.0050,  0.0050]], requires_grad=True)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-b7b3064739de> in <module>
#      11                     #
#      12                     print(aniter,nparticles)
# ---> 13                     result = trainGuide(nparticles,filename="testresults/mlm7_amortized_laplace_transparent_.csv")
#      14                     print(aniter,nparticles)
#      15                     for line in range(10):
#
# ~\Dropbox\eipython\eipython\mlm.py in trainGuide(nparticles, filename)
#     461                     #                 "norm_scale","gum_scale")]]
#     462     for i in range(3001):
# --> 463         loss = svi.step(processed_data, include_nuisance=True)
#     464         if len(losses)==0:
#     465             mean_losses.append(loss)
#
# ~\Anaconda3new\lib\site-packages\pyro\infer\svi.py in step(self, *args, **kwargs)
#      97         # get loss and compute gradients
#      98         with poutine.trace(param_only=True) as param_capture:
# ---> 99             loss = self.loss_and_grads(self.model, self.guide, *args, **kwargs)
#     100
#     101         params = set(site["value"].unconstrained()
#
# ~\Anaconda3new\lib\site-packages\pyro\infer\trace_elbo.py in loss_and_grads(self, model, guide, *args, **kwargs)
#     134             if trainable_params and getattr(surrogate_loss_particle, 'requires_grad', False):
#     135                 surrogate_loss_particle = surrogate_loss_particle / self.num_particles
# --> 136                 surrogate_loss_particle.backward(retain_graph=self.retain_graph)
#     137
#     138         warn_if_nan(loss, "loss")
#
# ~\Anaconda3new\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     105                 products. Defaults to ``False``.
#     106         """
# --> 107         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     108
#     109     def register_hook(self, hook):
#
# ~\Anaconda3new\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      91     Variable._execution_engine.run_backward(
#      92         tensors, grad_tensors, retain_graph, create_graph,
# ---> 93         allow_unreachable=True)  # allow_unreachable flag
#      94
#      95
#
# KeyboardInterrupt:

# %%
from importlib import reload
import demo #import *
reload(demo)
from demo import *
import cProfile as profile


kwargs = dict(obs=ts(7.),df=ts(2.),sig=ts(.4))
kwargs = dict(obs=ts(4.),df=ts(5.),sig=ts(.4))
kwargs = dict(obs=ts(7.),df=ts(2.),sig=ts(.4))
ps = getTruePosteriors([.5,.95],-8,.1,**kwargs)


fig, ax = plt.subplots(figsize=(6, 6))
for p in ps:
    ax.fill([x for x,y in p], [y for x,y in p], fill=False)

#confidence_ellipse(torch.ones(2),torch.eye(2),ax,alpha=0.5, facecolor='pink', edgecolor='purple', zorder=0)
#print("hi")
plt.show()
