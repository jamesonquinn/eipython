# %% [markdown]
# # Quick intro
#
# This is a jupyter notebook for testing / coding. So far, each code block is a separate test; unlike an ordinary notebook, they are not meant to run sequentially.
#
# First, test to see jupyter is running correctly at all:

# %%
import os
import sys

print("hi!!! you")
# Out:
# hi!!! you

# %% [markdown]
# Next, running the demo.

# %%
# Out:
#   File "<ipython-input-7-b3a8c0b914d1>", line 38
#     plt.plot(print
#                   ^
# SyntaxError: unexpected EOF while parsing

# %%
(

# %%
from importlib import reload
import demo #import *
reload(demo)
from demo import *
import cProfile as profile

if True:

    for aniter in range(1):
        for nparticles in [1,5]:
            for guidename in guides.keys():
                for eparams in [fake_effects_params,f2,f3,f4]:
                    #

                    print(aniter,nparticles,guidename,eparams)
                    result = trainGuide(guidename,nparticles,eparams,filename="testresults/demo_amortized_laplace_untransparent_fixed.csv")
                    print(aniter,nparticles,guidename,eparams)
                    for line in range(10):
                        print()
                    
else:
    plt.plot([getMLE(.01 + x/100,1.,0,1.) for x in range(500)])
# Out:
# Not none.
# Fake: tensor([ 3.0437,  7.5090, -1.5103, -0.3024,  2.0977,  4.9130,  5.2267,  5.6853,
#          1.1820, -2.2022,  1.4352, -1.0240, -2.4354,  5.9806,  4.3392, -3.6774,
#          1.2130,  0.1894,  0.2195, -0.4485,  2.1252, -0.7879,  2.4541,  2.3516,
#          3.8411,  2.0965, -3.2426, -1.4275,  2.3680,  1.2010, -1.5603, -0.9272,
#          7.2800,  3.3061, -0.5055, -0.0286, -2.7379,  0.5560, -1.2198, -1.7948,
#          0.5285,  1.2482, -0.4140,  2.9405])
# 0 1 amortized_laplace {'modal_effect': tensor(0.), 'norm_scale': tensor(0.1000), 'gum_scale': tensor(2.)}
# Not none.
# epoch 0 loss = 20096.02191954851;
#  mode_hat = 0.004999999888241291;
#  nscale_hat = 0.9950000047683716
#  gscale_hat = 0.9950000047683716
# epoch 10 loss = 28494.73608660698;
#  mode_hat = 0.031470347195863724;
#  nscale_hat = 0.9450000524520874
#  gscale_hat = 0.9450000524520874
# epoch 20 loss = 18208.29603546858;
#  mode_hat = 0.03723382577300072;
#  nscale_hat = 0.8950001001358032
#  gscale_hat = 0.8950001001358032
# epoch 30 loss = 18175.46939074993;
#  mode_hat = 0.07000166177749634;
#  nscale_hat = 0.8618901371955872
#  gscale_hat = 0.845000147819519
# epoch 40 loss = 14222.37179517746;
#  mode_hat = 0.09523680806159973;
#  nscale_hat = 0.8242273330688477
#  gscale_hat = 0.8039307594299316
# epoch 50 loss = 15583.998004078865;
#  mode_hat = 0.12101438641548157;
#  nscale_hat = 0.7839007377624512
#  gscale_hat = 0.754889190196991
# epoch 60 loss = 14566.630645096302;
#  mode_hat = 0.14208100736141205;
#  nscale_hat = 0.7349393367767334
#  gscale_hat = 0.7123706936836243
# epoch 70 loss = 15827.010350883007;
#  mode_hat = 0.16637063026428223;
#  nscale_hat = 0.7020309567451477
#  gscale_hat = 0.6662840843200684
# epoch 80 loss = 15626.974442780018;
#  mode_hat = 0.19510212540626526;
#  nscale_hat = 0.6672647595405579
#  gscale_hat = 0.6214941740036011
# epoch 90 loss = 19284.658728182316;
#  mode_hat = 0.22084163129329681;
#  nscale_hat = 0.6402630805969238
#  gscale_hat = 0.5759333968162537
# epoch 100 loss = 18609.78041100502;
#  mode_hat = 0.2568647265434265;
#  nscale_hat = 0.5945486426353455
#  gscale_hat = 0.540174663066864
# epoch 110 loss = 14876.364751517773;
#  mode_hat = 0.27987709641456604;
#  nscale_hat = 0.5450088381767273
#  gscale_hat = 0.5079940557479858
# epoch 120 loss = 11490.273895919323;
#  mode_hat = 0.30925726890563965;
#  nscale_hat = 0.5114410519599915
#  gscale_hat = 0.4781242609024048
# epoch 130 loss = 17176.336148679256;
#  mode_hat = 0.3338644802570343;
#  nscale_hat = 0.4736013114452362
#  gscale_hat = 0.43550851941108704
# epoch 140 loss = 12063.868994295597;
#  mode_hat = 0.3781156539916992;
#  nscale_hat = 0.4332292675971985
#  gscale_hat = 0.4084616005420685
# epoch 150 loss = 15173.994242429733;
#  mode_hat = 0.4167144000530243;
#  nscale_hat = 0.39379334449768066
#  gscale_hat = 0.4020097851753235
# epoch 160 loss = 12053.76049888134;
#  mode_hat = 0.4494953751564026;
#  nscale_hat = 0.36046549677848816
#  gscale_hat = 0.3717314302921295
# epoch 170 loss = 14833.160629034042;
#  mode_hat = 0.4834202229976654;
#  nscale_hat = 0.33021974563598633
#  gscale_hat = 0.36084550619125366
# epoch 180 loss = 15130.245603442192;
#  mode_hat = 0.49785667657852173;
#  nscale_hat = 0.3009002208709717
#  gscale_hat = 0.3445514440536499
# epoch 190 loss = 12703.153135180473;
#  mode_hat = 0.5094567537307739;
#  nscale_hat = 0.2726498544216156
#  gscale_hat = 0.3130282461643219
# epoch 200 loss = 15056.798826873302;
#  mode_hat = 0.5354337096214294;
#  nscale_hat = 0.2514347434043884
#  gscale_hat = 0.28388699889183044
# epoch 210 loss = 14090.294970035553;
#  mode_hat = 0.5746843218803406;
#  nscale_hat = 0.22749178111553192
#  gscale_hat = 0.2553752362728119
# epoch 220 loss = 12707.979085028172;
#  mode_hat = 0.613323986530304;
#  nscale_hat = 0.22874131798744202
#  gscale_hat = 0.2297390103340149
# epoch 230 loss = 14053.626237213612;
#  mode_hat = 0.6367571353912354;
#  nscale_hat = 0.2177058756351471
#  gscale_hat = 0.20739154517650604
# epoch 240 loss = 14211.850636005402;
#  mode_hat = 0.651273250579834;
#  nscale_hat = 0.2110946923494339
#  gscale_hat = 0.21376636624336243
# epoch 250 loss = 11609.713276684284;
#  mode_hat = 0.6684824824333191;
#  nscale_hat = 0.21211589872837067
#  gscale_hat = 0.23563402891159058
# epoch 260 loss = 15231.655800700188;
#  mode_hat = 0.6824310421943665;
#  nscale_hat = 0.2007545679807663
#  gscale_hat = 0.2204716056585312
# epoch 270 loss = 11962.772572517395;
#  mode_hat = 0.670441746711731;
#  nscale_hat = 0.1955205202102661
#  gscale_hat = 0.20963455736637115
# epoch 280 loss = 13854.681658923626;
#  mode_hat = 0.6449007391929626;
#  nscale_hat = 0.19623851776123047
#  gscale_hat = 0.18869809806346893
# epoch 290 loss = 12961.58197581768;
#  mode_hat = 0.6332845687866211;
#  nscale_hat = 0.19330520927906036
#  gscale_hat = 0.16136625409126282
# epoch 300 loss = 13678.669066131115;
#  mode_hat = 0.66475909948349;
#  nscale_hat = 0.19468912482261658
#  gscale_hat = 0.14320605993270874
# epoch 310 loss = 13268.549056112766;
#  mode_hat = 0.6831802129745483;
#  nscale_hat = 0.18394415080547333
#  gscale_hat = 0.11870890855789185
# epoch 320 loss = 13641.419937610626;
#  mode_hat = 0.7011195421218872;
#  nscale_hat = 0.1642276495695114
#  gscale_hat = 0.12766049802303314
# epoch 330 loss = 14624.790494084358;
#  mode_hat = 0.7171992659568787;
#  nscale_hat = 0.15791358053684235
#  gscale_hat = 0.1296994537115097
# epoch 340 loss = 12543.992171645164;
#  mode_hat = 0.7166755795478821;
#  nscale_hat = 0.14371258020401
#  gscale_hat = 0.12298880517482758
# epoch 350 loss = 13130.83804064989;
#  mode_hat = 0.7279248833656311;
#  nscale_hat = 0.14424003660678864
#  gscale_hat = 0.11295783519744873
# epoch 360 loss = 13110.086924016476;
#  mode_hat = 0.7379170656204224;
#  nscale_hat = 0.1371225267648697
#  gscale_hat = 0.09660205245018005
# epoch 370 loss = 12959.4988270998;
#  mode_hat = 0.735490620136261;
#  nscale_hat = 0.13370731472969055
#  gscale_hat = 0.08244846016168594
# epoch 380 loss = 13413.020144879818;
#  mode_hat = 0.7422612309455872;
#  nscale_hat = 0.12404245883226395
#  gscale_hat = 0.0825996994972229
# epoch 390 loss = 13337.922103822231;
#  mode_hat = 0.7505578994750977;
#  nscale_hat = 0.11799967288970947
#  gscale_hat = 0.06378000974655151
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# epoch 400 loss = 13323.737712860107;
#  mode_hat = 0.7567110061645508;
#  nscale_hat = 0.11962570995092392
#  gscale_hat = 0.05708994343876839
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# epoch 410 loss = 13901.961533486843;
#  mode_hat = 0.7618099451065063;
#  nscale_hat = 0.0977509468793869
#  gscale_hat = 0.0643736943602562
# epoch 420 loss = 13003.752148211002;
#  mode_hat = 0.7626928091049194;
#  nscale_hat = 0.10212536156177521
#  gscale_hat = 0.0663096234202385
# getMLE: replacing nans
# epoch 430 loss = 13179.669432401657;
#  mode_hat = 0.7715575695037842;
#  nscale_hat = 0.10731732845306396
#  gscale_hat = 0.05438502877950668
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# epoch 440 loss = 13118.706201136112;
#  mode_hat = 0.7717455625534058;
#  nscale_hat = 0.11294937133789062
#  gscale_hat = 0.043654073029756546
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# epoch 450 loss = 13151.45175987482;
#  mode_hat = 0.7980248332023621;
#  nscale_hat = 0.12100465595722198
#  gscale_hat = 0.04018714651465416
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# epoch 460 loss = 13033.470033228397;
#  mode_hat = 0.7907478213310242;
#  nscale_hat = 0.11449291557073593
#  gscale_hat = 0.03478389233350754
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# getMLE: replacing nans
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-1ee16d21d33a> in <module>
#      14
#      15                     print(aniter,nparticles,guidename,eparams)
# ---> 16                     result = trainGuide(guidename,nparticles,eparams,filename="testresults/demo_amortized_laplace_untransparent_fixed.csv")
#      17                     print(aniter,nparticles,guidename,eparams)
#      18                     for line in range(10):
#
# ~\Dropbox\eipython\eipython\demo.py in trainGuide(guidename, nparticles, trueparams, filename)
#     554                                     "norm_scale","gum_scale")]]
#     555     for i in range(3001):
# --> 556         loss = svi.step(N,fake_effects,errors,ts(10.),ts(10.))
#     557         if len(losses)==0:
#     558             mean_losses.append(loss)
#
# ~\Anaconda3new\lib\site-packages\pyro\infer\svi.py in step(self, *args, **kwargs)
#      97         # get loss and compute gradients
#      98         with poutine.trace(param_only=True) as param_capture:
# ---> 99             loss = self.loss_and_grads(self.model, self.guide, *args, **kwargs)
#     100
#     101         params = set(site["value"].unconstrained()
#
# ~\Anaconda3new\lib\site-packages\pyro\infer\trace_elbo.py in loss_and_grads(self, model, guide, *args, **kwargs)
#     123         loss = 0.0
#     124         # grab a trace from the generator
# --> 125         for model_trace, guide_trace in self._get_traces(model, guide, *args, **kwargs):
#     126             loss_particle, surrogate_loss_particle = self._differentiable_loss_particle(model_trace, guide_trace)
#     127             loss += loss_particle / self.num_particles
#
# ~\Anaconda3new\lib\site-packages\pyro\infer\elbo.py in _get_traces(self, model, guide, *args, **kwargs)
#     166         else:
#     167             for i in range(self.num_particles):
# --> 168                 yield self._get_trace(model, guide, *args, **kwargs)
#
# ~\Anaconda3new\lib\site-packages\pyro\infer\trace_elbo.py in _get_trace(self, model, guide, *args, **kwargs)
#      50         """
#      51         model_trace, guide_trace = get_importance_trace(
# ---> 52             "flat", self.max_plate_nesting, model, guide, *args, **kwargs)
#      53         if is_validation_enabled():
#      54             check_if_enumerated(guide_trace)
#
# ~\Anaconda3new\lib\site-packages\pyro\infer\enum.py in get_importance_trace(graph_type, max_plate_nesting, model, guide, *args, **kwargs)
#      40     against it.
#      41     """
# ---> 42     guide_trace = poutine.trace(guide, graph_type=graph_type).get_trace(*args, **kwargs)
#      43     model_trace = poutine.trace(poutine.replay(model, trace=guide_trace),
#      44                                 graph_type=graph_type).get_trace(*args, **kwargs)
#
# ~\Anaconda3new\lib\site-packages\pyro\poutine\trace_messenger.py in get_trace(self, *args, **kwargs)
#     167         Calls this poutine and returns its trace instead of the function's return value.
#     168         """
# --> 169         self(*args, **kwargs)
#     170         return self.msngr.get_trace()
#
# ~\Anaconda3new\lib\site-packages\pyro\poutine\trace_messenger.py in __call__(self, *args, **kwargs)
#     145                                       args=args, kwargs=kwargs)
#     146             try:
# --> 147                 ret = self.fn(*args, **kwargs)
#     148             except (ValueError, RuntimeError):
#     149                 exc_type, exc_value, traceback = sys.exc_info()
#
# ~\Dropbox\eipython\eipython\demo.py in amortized_laplace(N, effects, errors, scalehyper, tailhyper)
#     340     theta_names = ["modal_effect", "norm_scale", "gum_scale"]
#     341     theta_parts = dict((theta_name,hat_data[theta_name]) for theta_name in theta_names)
# --> 342     Info = -myhessian.hessian(logPosterior, hat_data.values())#, allow_unused=True)
#     343
#     344
#
# ~\Anaconda3new\lib\site-packages\hessian-0.0.0-py3.7.egg\hessian\hessian.py in hessian(output, inputs, out, allow_unused, create_graph)
#      32         for j in range(inp.numel()):
#      33             if grad[j].requires_grad:
# ---> 34                 row = gradient(grad[j], inputs[i:], retain_graph=True, create_graph=create_graph)[j:]
#      35             else:
#      36                 row = grad[j].new_zeros(sum(x.numel() for x in inputs[i:]) - j)
#
# ~\Anaconda3new\lib\site-packages\hessian-0.0.0-py3.7.egg\hessian\gradient.py in gradient(outputs, inputs, grad_outputs, retain_graph, create_graph)
#      20                                 allow_unused=True,
#      21                                 retain_graph=retain_graph,
# ---> 22                                 create_graph=create_graph)
#      23     grads = [x if x is not None else torch.zeros_like(y) for x, y in zip(grads, inputs)]
#      24     return torch.cat([x.contiguous().view(-1) for x in grads])
#
# ~\Anaconda3new\lib\site-packages\torch\autograd\__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused)
#     147     return Variable._execution_engine.run_backward(
#     148         outputs, grad_outputs, retain_graph, create_graph,
# --> 149         inputs, allow_unused)
#     150
#     151
#
# KeyboardInterrupt:

# %%
print(fake_effects)

# %%
import myhessian
import torch
ts = torch.tensor
t = ts([i+.5 for i in range(5)], requires_grad=True)
l = torch.sum(t**3)
[lg] = torch.autograd.grad(l,t,create_graph=True,retain_graph=True)
[lgg] = torch.autograd.grad(lg[1],t,create_graph=True,retain_graph=True)
lgg2 = lgg.contiguous().view(-1)
print(lgg2.size())
lgg3 = torch.zeros(6,6)#,requires_grad=True)
lgg3[1,1:].add_(lgg2.type_as(lgg3))
print(lg)
h = myhessian.hessian(l,t)
l2 = torch.sum(lgg3)
l2.backward()
print(t.grad)
print(lgg3.requires_grad)
# Out:
# torch.Size([5])
# tensor([ 0.7500,  6.7500, 18.7500, 36.7500, 60.7500], grad_fn=<MulBackward0>)
# tensor([0., 6., 0., 0., 0.])
# True

# %%
from importlib import reload
import demo #import *
reload(demo)
from demo import *
import cProfile as profile

print("hi")

print(lambertw(ts([0.])),lambertw(ts([1.])),lambertw(ts([50.])))
print("hi")

testMLE()
# Out:
# Not none.
# Fake: tensor([0.7708, 0.9373, 0.3363, 0.4669, 0.7751, 1.0240, 0.9237, 1.0633, 0.5697,
#         0.2267, 0.9604, 0.3158, 0.2745, 1.3635, 1.0884, 0.3226, 0.4992, 0.4686,
#         0.3450, 0.5070, 0.8096, 0.4685, 1.2292, 0.5951, 0.8807, 0.7200, 0.0693,
#         0.0639, 0.6489, 0.4998, 0.3163, 0.3981, 1.4540, 0.7402, 0.4704, 0.4906,
#         0.2753, 0.5539, 0.4448, 0.1483, 0.6295, 0.6658, 0.4501, 0.8183])
# hi
# tensor([0.]) tensor([0.5671]) tensor([2.8609])
# hi
# tensor([0.1005]) tensor([0.0317]) tensor([-0.0180]) tensor([0.0839]) tensor([0.0165])
# getMLE seems to have failed, tensor([0.0497]) tensor([0.0317]) tensor([-0.0180]) tensor([0.1005]) tensor([0.0839]) tensor([0.0165]) 0.0001 tensor([1.4605]) tensor([1.4605])
# 0.04971396550536156
# getMLE seems to have failed, tensor([0.0497]) tensor([0.0317]) tensor([-0.0180]) tensor([0.1005]) tensor([0.0839]) tensor([0.0165]) -0.0001 tensor([1.4605]) tensor([1.4605])
# 0.04971396550536156
# tensor([0.0577]) tensor([0.1795]) tensor([0.0234]) tensor([0.0567]) tensor([0.0010])
# getMLE seems to have failed, tensor([0.2029]) tensor([0.1795]) tensor([0.0234]) tensor([0.0577]) tensor([0.0567]) tensor([0.0010]) 0.0001 tensor([3.5022]) tensor([3.5022])
# 0.20291371643543243
# getMLE seems to have failed, tensor([0.2029]) tensor([0.1795]) tensor([0.0234]) tensor([0.0577]) tensor([0.0567]) tensor([0.0010]) -0.0001 tensor([3.5022]) tensor([3.5022])
# 0.20291371643543243
# tensor([-0.0431]) tensor([0.0203]) tensor([0.0853]) tensor([-0.0029]) tensor([-0.0402])
# getMLE seems to have failed, tensor([0.1056]) tensor([0.0203]) tensor([0.0853]) tensor([-0.0431]) tensor([-0.0029]) tensor([-0.0402]) 0.0001 tensor([4.3006]) tensor([4.3006])
# 0.10555315017700195
# getMLE seems to have failed, tensor([0.1056]) tensor([0.0203]) tensor([0.0853]) tensor([-0.0431]) tensor([-0.0029]) tensor([-0.0402]) -0.0001 tensor([4.3006]) tensor([4.3006])
# 0.10555315017700195
# tensor([-0.5133]) tensor([0.2653]) tensor([-0.6627]) tensor([-0.0532]) tensor([-0.4601])
# getMLE seems to have failed, tensor([0.9281]) tensor([0.2653]) tensor([-0.6627]) tensor([-0.5133]) tensor([-0.0532]) tensor([-0.4601]) -0.0001 tensor([-0.3945]) tensor([-0.3945])
# 0.9280707240104675
# tensor([-0.0096]) tensor([0.1945]) tensor([-0.1062]) tensor([-0.0073]) tensor([-0.0022])
# getMLE seems to have failed, tensor([0.3008]) tensor([0.1945]) tensor([-0.1062]) tensor([-0.0096]) tensor([-0.0073]) tensor([-0.0022]) 0.0001 tensor([1.9595]) tensor([1.9595])
# 0.30076369643211365
# getMLE seems to have failed, tensor([0.3008]) tensor([0.1945]) tensor([-0.1062]) tensor([-0.0096]) tensor([-0.0073]) tensor([-0.0022]) -0.0001 tensor([1.9595]) tensor([1.9595])
# 0.30076369643211365
# tensor([-0.6875]) tensor([0.1635]) tensor([0.7658]) tensor([-0.0458]) tensor([-0.6417])
# getMLE seems to have failed, tensor([0.9293]) tensor([0.1635]) tensor([0.7658]) tensor([-0.6875]) tensor([-0.0458]) tensor([-0.6417]) -0.0001 tensor([-0.3539]) tensor([-0.3539])
# 0.92925626039505
# tensor([0.0995]) tensor([0.0343]) tensor([-0.0744]) tensor([0.0265]) tensor([0.0730])
# getMLE seems to have failed, tensor([0.1087]) tensor([0.0343]) tensor([-0.0744]) tensor([0.0995]) tensor([0.0265]) tensor([0.0730]) 0.0001 tensor([3.0668]) tensor([3.0667])
# 0.10871163010597229
# getMLE seems to have failed, tensor([0.1087]) tensor([0.0343]) tensor([-0.0744]) tensor([0.0995]) tensor([0.0265]) tensor([0.0730]) -0.0001 tensor([3.0668]) tensor([3.0667])
# 0.10871163010597229
# tensor([0.3200]) tensor([0.1916]) tensor([0.4579]) tensor([0.0370]) tensor([0.2830])
# getMLE seems to have failed, tensor([0.6495]) tensor([0.1916]) tensor([0.4579]) tensor([0.3200]) tensor([0.0370]) tensor([0.2830]) 0.0001 tensor([0.3386]) tensor([0.3386])
# 0.6495132446289062
# getMLE seems to have failed, tensor([0.6495]) tensor([0.1916]) tensor([0.4579]) tensor([0.3200]) tensor([0.0370]) tensor([0.2830]) -0.0001 tensor([0.3386]) tensor([0.3386])
# 0.6495132446289062
# tensor([0.9391]) tensor([1.0316]) tensor([-0.5356]) tensor([0.7647]) tensor([0.1744])
# tensor([-0.5753]) tensor([0.6851]) tensor([-0.0301]) tensor([nan]) tensor([nan])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-209d28769f82> in <module>
#      10 print("hi")
#      11
# ---> 12 testMLE()
#
# ~\Dropbox\eipython\eipython\demo.py in testMLE(n)
#     259         npr, gpr = getMLE(nscale,gscale,0.,obs)
#     260         print(obs,nscale,gscale,npr,gpr)
# --> 261         ml = getdens(nscale,gscale,npr,gpr)
#     262         for delta in [.0001,-.0001]:
#     263             mlnot = getdens(nscale,gscale,npr+delta,gpr-delta)
#
# ~\Dropbox\eipython\eipython\demo.py in getdens(nscale, gscale, np, gp)
#     248
#     249 def getdens(nscale,gscale,np,gp):
# --> 250     return (dist.Normal(0,nscale).log_prob(np) +
#     251             dist.Gumbel(0,torch.abs(gscale)).log_prob(torch.sign(gscale)*gp))
#     252
#
# ~\Anaconda3new\lib\site-packages\torch\distributions\normal.py in log_prob(self, value)
#      70     def log_prob(self, value):
#      71         if self._validate_args:
# ---> 72             self._validate_sample(value)
#      73         # compute the variance
#      74         var = (self.scale ** 2)
#
# ~\Anaconda3new\lib\site-packages\torch\distributions\distribution.py in _validate_sample(self, value)
#     251
#     252         if not self.support.check(value).all():
# --> 253             raise ValueError('The value argument must be within the support')
#     254
#     255     def _get_checked_instance(self, cls, _instance=None):
#
# ValueError: The value argument must be within the support
