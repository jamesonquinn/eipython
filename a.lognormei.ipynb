# %% [markdown]
# # Quick intro
#
# This is a jupyter notebook for testing / coding. So far, each code block is a separate test; unlike an ordinary notebook, they are not meant to run sequentially.
#
# First, test to see jupyter is running correctly at all:

# %%
import os
import sys

print("hi!!!")
# Out:
# hi!!!

# %% [markdown]
# Next, running "ei". This started out as a copy of Fritz's code but it's evolved into a working version of ours.

# %%
from importlib import reload
import ei #import *
reload(ei)
from ei import *
import cProfile as profile

# %prun result = trainGuide()
# Out:
# Yes, I will run.
# Reloading cmult...
# Reloading polytopize.
# Reloading polytopize.
# Yes, I will run.
# Reloading polytopize.
# model:begin
# ec:tensor([0.0000, 0.5000, 0.0000])
# erc:tensor([[0., 1., 2.],
#         [2., 0., 0.],
#         [0., 0., 0.],
#         [0., 0., 0.]])
# y[0]:tensor([[ 25., 171., 237.],
#         [238.,  50.,  34.],
#         [ 69.,  80.,  58.],
#         [ 21.,  42.,  25.]])
# scale tensor(6.1368)
# svi.step(... 0 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-68503.0547, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 0 loss = 4395977.967655182; logsdrchat = 1.9950000047683716;
#  erchat = tensor([[-0.0050,  0.0050, -0.0050],
#         [-0.0050, -0.0050,  0.0050],
#         [ 0.0050,  0.0050, -0.0050],
#         [-0.0050, -0.0050,  0.0050]], requires_grad=True)
# scale tensor(6.4169)
# svi.step(... 1 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93592.6562, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 2 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93613.3672, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 3 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93291.1562, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 4 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93376.5781, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 5 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93440.0391, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 6 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93493.0938, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 7 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93598.1172, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 8 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93620.9844, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 9 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93297.3281, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 10 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93384.2031, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 10 loss = 5702381.118929625; logsdrchat = 1.9450000524520874;
#  erchat = tensor([[-0.0053, -0.0076, -0.0029],
#         [-0.0269, -0.0380,  0.0240],
#         [ 0.0211,  0.0197, -0.0183],
#         [-0.0093, -0.0010,  0.0064]], requires_grad=True)
# scale tensor(5.8768)
# svi.step(... 11 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93450.4922, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 12 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93505.8984, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 13 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93613.7344, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 14 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93639.0859, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 15 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93314.2344, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 16 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93402.3828, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 17 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93468.9219, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 18 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93524.5859, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 19 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93632.9766, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 20 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93657.5312, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 20 loss = 5585924.1919231415; logsdrchat = 1.8950001001358032;
#  erchat = tensor([[-0.0065, -0.0244,  0.0107],
#         [-0.0470, -0.0483,  0.0418],
#         [ 0.0250,  0.0113, -0.0055],
#         [ 0.0004,  0.0080, -0.0058]], requires_grad=True)
# scale tensor(5.4095)
# svi.step(... 21 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93330.4844, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 22 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93418.4609, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 23 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93486.6406, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 24 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93542.4609, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 25 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93650.0078, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 26 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93675.7266, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 27 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93346.9609, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 28 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93433.9609, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 29 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93501.1172, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 30 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93555.3984, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 30 loss = 5703106.953723431; logsdrchat = 1.845000147819519;
#  erchat = tensor([[-0.0064, -0.0419,  0.0265],
#         [-0.0659, -0.0669,  0.0504],
#         [ 0.0309,  0.0044,  0.0022],
#         [ 0.0001,  0.0154, -0.0129]], requires_grad=True)
# scale tensor(6.4169)
# svi.step(... 31 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93661.5547, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 32 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93683.7500, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 33 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93349.9531, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 34 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93434.1953, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 35 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93498.8594, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 36 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93552.9453, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 37 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93659.9375, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 38 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93683.3672, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 39 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93348.3359, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 40 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93434.9375, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 40 loss = 4063601.3116772175; logsdrchat = 1.7950001955032349;
#  erchat = tensor([[-0.0219, -0.0407,  0.0379],
#         [-0.0870, -0.0782,  0.0598],
#         [ 0.0283, -0.0076,  0.0127],
#         [ 0.0042,  0.0364, -0.0225]], requires_grad=True)
# scale tensor(5.8768)
# svi.step(... 41 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93500.8203, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 42 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93555.0859, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 43 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93662.7812, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 44 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93688.0781, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 45 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93351.9844, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 46 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93438.9531, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 47 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93504.5312, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 48 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93560.0781, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 49 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93667.4297, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 50 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93691.3906, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 50 loss = 4457056.972111702; logsdrchat = 1.7450002431869507;
#  erchat = tensor([[-0.0276, -0.0535,  0.0335],
#         [-0.0895, -0.0829,  0.0656],
#         [ 0.0229, -0.0022,  0.0094],
#         [ 0.0070,  0.0530, -0.0158]], requires_grad=True)
# scale tensor(5.4095)
# svi.step(... 51 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93351.6250, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 52 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93437.8203, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 53 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93502.0938, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 54 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93556.1484, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 55 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93661.7109, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 56 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93682.9531, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 57 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93340.7266, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 58 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93428.1641, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 59 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93494.7031, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 60 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93551.9531, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 60 loss = 4773868.967930317; logsdrchat = 1.6950002908706665;
#  erchat = tensor([[-0.0389, -0.0635,  0.0388],
#         [-0.0928, -0.0998,  0.0876],
#         [ 0.0270, -0.0083,  0.0073],
#         [ 0.0025,  0.0696, -0.0244]], requires_grad=True)
# scale tensor(6.4169)
# svi.step(... 61 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93661.3203, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 62 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93686.1484, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 63 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93342.7266, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 64 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93428.3438, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 65 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93491.2031, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 66 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93546.6562, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 67 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93653.3984, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 68 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93677.3984, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 69 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93333.4453, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 70 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93422.3906, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 70 loss = 3254705.887836218; logsdrchat = 1.6450003385543823;
#  erchat = tensor([[-0.0426, -0.0744,  0.0544],
#         [-0.0800, -0.1203,  0.1172],
#         [ 0.0378, -0.0099,  0.0003],
#         [-0.0191,  0.0872, -0.0255]], requires_grad=True)
# scale tensor(5.8768)
# svi.step(... 71 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93489.3359, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 72 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93550.0703, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 73 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93661.5469, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 74 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93688.8750, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 75 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93346.5000, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 76 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93437.5703, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 77 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93506.2656, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 78 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93568.0234, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 79 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93679.9688, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 80 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93709.7500, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 80 loss = 7019954.197689295; logsdrchat = 1.5950003862380981;
#  erchat = tensor([[-0.0556, -0.0776,  0.0653],
#         [-0.0758, -0.1191,  0.1178],
#         [ 0.0597, -0.0213, -0.0206],
#         [-0.0290,  0.0883, -0.0052]], requires_grad=True)
# scale tensor(5.4095)
# svi.step(... 81 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93365.0938, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 82 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93458.3594, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 83 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93529.6719, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 84 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93588.8516, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 85 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93701.4141, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 86 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93731.4062, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 87 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93384.0156, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 88 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93474.7656, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 89 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93544.0469, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 90 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93601.6875, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 90 loss = 4879105.616407156; logsdrchat = 1.545000433921814;
#  erchat = tensor([[-0.0689, -0.0723,  0.0766],
#         [-0.0754, -0.1216,  0.1141],
#         [ 0.0770, -0.0170, -0.0413],
#         [-0.0315,  0.0783,  0.0096]], requires_grad=True)
# scale tensor(6.4169)
# svi.step(... 91 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93711.7422, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 92 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93739.9375, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 93 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93390.1797, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 94 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93482.6953, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 95 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93557.0469, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 96 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93618.6953, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 97 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93732.5547, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 98 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93765.5469, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 99 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93417.6016, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 100 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93512.2656, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 100 loss = 6035034.273994684; logsdrchat = 1.4950004816055298;
#  erchat = tensor([[-0.0809, -0.0780,  0.0911],
#         [-0.0839, -0.1139,  0.1093],
#         [ 0.0873, -0.0083, -0.0565],
#         [-0.0368,  0.0575,  0.0266]], requires_grad=True)
# scale tensor(5.8768)
# svi.step(... 101 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93589.6562, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 102 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93652.3750, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 103 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93767.5312, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 104 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93799.5781, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 105 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93448.9297, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 106 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93542.6953, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 107 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93620.8828, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 108 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93682.2500, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 109 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93799.8359, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 110 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93836.9062, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 110 loss = 5381553.138297558; logsdrchat = 1.4450005292892456;
#  erchat = tensor([[-0.0785, -0.0910,  0.1111],
#         [-0.0824, -0.1060,  0.0896],
#         [ 0.0890,  0.0037, -0.0646],
#         [-0.0356,  0.0408,  0.0441]], requires_grad=True)
# scale tensor(5.4095)
# svi.step(... 111 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93487.8125, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 112 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93584.1641, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 113 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93664.0156, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 114 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93727.4219, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 115 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93845.6797, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 116 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93880.2344, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 117 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93526.9062, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 118 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93620.1875, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 119 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93697.9688, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 120 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93758.9375, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 120 loss = 5193869.286049366; logsdrchat = 1.3950005769729614;
#  erchat = tensor([[-0.0850, -0.0978,  0.1359],
#         [-0.0873, -0.1056,  0.0839],
#         [ 0.0845,  0.0119, -0.0677],
#         [-0.0378,  0.0358,  0.0473]], requires_grad=True)
# scale tensor(6.4169)
# svi.step(... 121 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93875.0781, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 122 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93910.0859, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 123 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93556.3984, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 124 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93648.2891, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 125 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93725.4297, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 126 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93785.8828, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 127 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93898.8672, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 128 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93932.7656, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 129 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93576.2656, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 130 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93668.1016, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 130 loss = 5626923.246045828; logsdrchat = 1.3450006246566772;
#  erchat = tensor([[-0.0905, -0.1007,  0.1638],
#         [-0.0966, -0.1111,  0.0862],
#         [ 0.0971,  0.0057, -0.0798],
#         [-0.0494,  0.0490,  0.0404]], requires_grad=True)
# scale tensor(5.8768)
# svi.step(... 131 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93745.2891, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 132 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93803.7891, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 133 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93919.2344, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 134 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93955.3906, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 135 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93604.6562, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 136 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93696.4922, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 137 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93774.5156, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 138 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93831.5547, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 139 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93943.7969, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 140 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93975.2969, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 140 loss = 5160244.15927434; logsdrchat = 1.295000672340393;
#  erchat = tensor([[-0.0918, -0.1111,  0.1832],
#         [-0.0920, -0.1214,  0.0934],
#         [ 0.1041,  0.0104, -0.0873],
#         [-0.0449,  0.0653,  0.0370]], requires_grad=True)
# scale tensor(5.4095)
# svi.step(... 141 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93620.6719, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 142 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93709.8750, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 143 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93783.0859, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 144 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93836.5547, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 145 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93945.6875, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 146 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93971.3281, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 147 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93614.2812, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 148 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93701.2656, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 149 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93774.7422, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 150 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93831.7656, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 150 loss = 6009225.06948185; logsdrchat = 1.2450007200241089;
#  erchat = tensor([[-0.0868, -0.1334,  0.2018],
#         [-0.0839, -0.1352,  0.1106],
#         [ 0.1159,  0.0180, -0.0952],
#         [-0.0435,  0.0789,  0.0314]], requires_grad=True)
# scale tensor(6.4169)
# svi.step(... 151 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93939.5781, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 152 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93962.5391, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 153 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93603.6562, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 154 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93682.8359, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 155 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93748.5391, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 156 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93802.1562, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 157 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93909.1797, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 158 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93935.9297, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 159 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93584.5000, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 160 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93671.4922, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 160 loss = 4277344.791149139; logsdrchat = 1.1950007677078247;
#  erchat = tensor([[-0.0806, -0.1636,  0.2264],
#         [-0.0884, -0.1571,  0.1313],
#         [ 0.1427,  0.0063, -0.0961],
#         [-0.0474,  0.1054,  0.0171]], requires_grad=True)
# scale tensor(5.8768)
# svi.step(... 161 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93742.2578, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 162 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93801.2734, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 163 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93913.2109, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 164 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93939.5547, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 165 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93592.0234, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 166 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93682.1406, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 167 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93756.6250, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 168 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93819.4375, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 169 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93929.6016, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 170 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93952.7656, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 170 loss = 4037059.416885376; logsdrchat = 1.1450008153915405;
#  erchat = tensor([[-0.0857, -0.1965,  0.2599],
#         [-0.1054, -0.1771,  0.1508],
#         [ 0.1630, -0.0048, -0.1138],
#         [-0.0509,  0.1169,  0.0057]], requires_grad=True)
# scale tensor(5.4095)
# svi.step(... 171 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93609.2734, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 172 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93693.5078, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 173 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93758.1250, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 174 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93810.9062, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 175 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93911.6094, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 176 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93929.0078, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 177 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93592.3047, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 178 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93679.0703, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 179 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93745.2031, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 180 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93801.4844, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 180 loss = 5100536.326876402; logsdrchat = 1.0950008630752563;
#  erchat = tensor([[-0.0877, -0.2325,  0.2756],
#         [-0.1040, -0.2009,  0.1685],
#         [ 0.1703, -0.0029, -0.1356],
#         [-0.0664,  0.1360,  0.0027]], requires_grad=True)
# scale tensor(6.4169)
# svi.step(... 181 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93906., grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 182 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93923.3828, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 183 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93590.6875, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 184 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93676.5234, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 185 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93743.9141, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 186 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93799.9297, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 187 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93901.4141, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 188 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93911.2109, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 189 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93575.1562, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 190 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93657.5000, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 190 loss = 4274033.191915512; logsdrchat = 1.0450009107589722;
#  erchat = tensor([[-0.0896, -0.2511,  0.2932],
#         [-0.1196, -0.2220,  0.1970],
#         [ 0.1814, -0.0207, -0.1402],
#         [-0.0617,  0.1664, -0.0171]], requires_grad=True)
# scale tensor(5.8768)
# svi.step(... 191 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93724.0547, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 192 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93784.2656, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 193 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93890.8750, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 194 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93906.6797, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 195 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93584.8672, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 196 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93676.0859, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 197 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93746.6406, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 198 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93812.8281, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 199 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93919.7734, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 200 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93930.7500, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 200 loss = 4434921.738102913; logsdrchat = 0.995000958442688;
#  erchat = tensor([[-0.0718, -0.2804,  0.3151],
#         [-0.1473, -0.2461,  0.2274],
#         [ 0.1967, -0.0412, -0.1475],
#         [-0.0507,  0.1942, -0.0292]], requires_grad=True)
# scale tensor(5.4095)
# svi.step(... 201 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93601.3125, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 202 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93683.0078, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 203 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93745.5156, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 204 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93808.2578, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 205 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93907.7422, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 206 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93911.8281, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 207 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93586.6719, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 208 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93663.5156, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 209 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93719.6562, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 210 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93782.4453, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 210 loss = 4013394.3493249416; logsdrchat = 0.9450010061264038;
#  erchat = tensor([[-0.0624, -0.3187,  0.3421],
#         [-0.1399, -0.2701,  0.2448],
#         [ 0.2255, -0.0610, -0.1663],
#         [-0.0656,  0.2211, -0.0403]], requires_grad=True)
# scale tensor(6.4169)
# svi.step(... 211 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93882.3906, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 212 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93887.4844, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 213 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93566.5859, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 214 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93645.6250, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 215 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93704.0078, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 216 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93766.1328, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 217 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93869.1250, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 218 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93873.9297, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 219 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93560.5781, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 220 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93646.1328, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 220 loss = 5935742.971322298; logsdrchat = 0.8950010538101196;
#  erchat = tensor([[-0.0501, -0.3494,  0.3692],
#         [-0.1222, -0.2988,  0.2646],
#         [ 0.2476, -0.0776, -0.1782],
#         [-0.0884,  0.2431, -0.0443]], requires_grad=True)
# scale tensor(5.8768)
# svi.step(... 221 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93707.8984, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 222 tensor(6.1368)
# guide:begin tensor(6.1368)
# model:begin
# model:end
# lp::: tensor(-93776.7109, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 223 tensor(6.4169)
# guide:begin tensor(6.4169)
# model:begin
# model:end
# lp::: tensor(-93886.9453, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 224 tensor(6.7238)
# guide:begin tensor(6.7238)
# model:begin
# model:end
# lp::: tensor(-93895.0938, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 225 tensor(5.4095)
# guide:begin tensor(5.4095)
# model:begin
# model:end
# lp::: tensor(-93582.0703, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 226 tensor(5.6350)
# guide:begin tensor(5.6350)
# model:begin
# model:end
# lp::: tensor(-93660.3828, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.8768)
# svi.step(... 227 tensor(5.8768)
# guide:begin tensor(5.8768)
# model:begin
# model:end
# lp::: tensor(-93718.9922, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# ...
#         [0.0719, 0.0771, 0.0534],
#         [0.1058, 0.1134, 0.0785],
#         [0.1396, 0.1497, 0.1036]])
# tensor(0.4606, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0054, -0.0289,  0.2761],
#         [ 0.0257,  0.1968,  0.0256],
#         [ 0.2868, -0.0291, -0.0057],
#         [ 0.0257,  0.2069,  0.0256]], grad_fn=<SubBackward0>)
# tensor([[0.0805, 0.0836, 0.0778],
#         [0.0825, 0.0857, 0.0798],
#         [0.0838, 0.0871, 0.0810],
#         [0.0859, 0.0892, 0.0830]])
# tensor(0.7423, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0197, -0.0430,  0.1865],
#         [ 0.0261,  0.1447,  0.0371],
#         [ 0.3146, -0.0284,  0.0059],
#         [ 0.0261,  0.3130,  0.0371]], grad_fn=<SubBackward0>)
# tensor([[0.0430, 0.0478, 0.0330],
#         [0.0722, 0.0803, 0.0554],
#         [0.1014, 0.1128, 0.0779],
#         [0.1306, 0.1453, 0.1003]])
# tensor(0.5212, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[ 0.0095, -0.0132,  0.3398],
#         [ 0.0243,  0.2427,  0.0127],
#         [ 0.2664, -0.0287, -0.0175],
#         [ 0.0243,  0.1268,  0.0127]], grad_fn=<SubBackward0>)
# tensor([[0.1091, 0.1102, 0.1169],
#         [0.0908, 0.0917, 0.0973],
#         [0.0715, 0.0722, 0.0766],
#         [0.0532, 0.0537, 0.0570]])
# tensor(0.7086, grad_fn=<DivBackward0>)
# model:begin
# model:end
# lp::: tensor(-218805.3438, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 1839 tensor(5.4095)
# guide:begin tensor(5.4095)
# optimize_Q SHRINK_FAC tensor([[-0.0173, -0.0411,  0.2045],
#         [ 0.0265,  0.1533,  0.0356],
#         [ 0.3098, -0.0290,  0.0038],
#         [ 0.0265,  0.2918,  0.0356]], grad_fn=<SubBackward0>)
# tensor([[0.0505, 0.0548, 0.0408],
#         [0.0744, 0.0808, 0.0602],
#         [0.0984, 0.1067, 0.0795],
#         [0.1223, 0.1327, 0.0989]])
# tensor(0.5658, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0271, -0.0513,  0.1692],
#         [ 0.0273,  0.1262,  0.0439],
#         [ 0.3209, -0.0292,  0.0117],
#         [ 0.0273,  0.3372,  0.0439]], grad_fn=<SubBackward0>)
# tensor([[0.0316, 0.0347, 0.0244],
#         [0.0688, 0.0756, 0.0531],
#         [0.1057, 0.1162, 0.0815],
#         [0.1423, 0.1564, 0.1097]])
# tensor(0.3994, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-1.3191e-02, -3.7655e-02,  2.2835e-01],
#         [ 2.7087e-02,  1.6593e-01,  3.2820e-02],
#         [ 3.0401e-01, -3.0031e-02,  1.8335e-04],
#         [ 2.7089e-02,  2.6259e-01,  3.2818e-02]], grad_fn=<SubBackward0>)
# tensor([[0.0612, 0.0640, 0.0522],
#         [0.0779, 0.0815, 0.0664],
#         [0.0946, 0.0989, 0.0807],
#         [0.1113, 0.1164, 0.0949]])
# tensor(0.6235, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0237, -0.0466,  0.1731],
#         [ 0.0257,  0.1359,  0.0399],
#         [ 0.3176, -0.0277,  0.0094],
#         [ 0.0257,  0.3305,  0.0400]], grad_fn=<SubBackward0>)
# tensor([[0.0355, 0.0403, 0.0270],
#         [0.0696, 0.0791, 0.0529],
#         [0.1034, 0.1174, 0.0786],
#         [0.1368, 0.1554, 0.1040]])
# tensor(0.4593, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0076, -0.0315,  0.2640],
#         [ 0.0262,  0.1877,  0.0277],
#         [ 0.2920, -0.0295, -0.0041],
#         [ 0.0262,  0.2211,  0.0277]], grad_fn=<SubBackward0>)
# tensor([[0.0757, 0.0782, 0.0709],
#         [0.0814, 0.0840, 0.0762],
#         [0.0870, 0.0899, 0.0815],
#         [0.0927, 0.0957, 0.0868]])
# tensor(0.7059, grad_fn=<DivBackward0>)
# model:begin
# model:end
# lp::: tensor(-239473.7500, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.6350)
# svi.step(... 1840 tensor(5.6350)
# guide:begin tensor(5.6350)
# optimize_Q SHRINK_FAC tensor([[-0.0227, -0.0463,  0.1873],
#         [ 0.0265,  0.1406,  0.0398],
#         [ 0.3146, -0.0286,  0.0083],
#         [ 0.0265,  0.3142,  0.0398]], grad_fn=<SubBackward0>)
# tensor([[0.0408, 0.0450, 0.0326],
#         [0.0714, 0.0786, 0.0569],
#         [0.1015, 0.1118, 0.0809],
#         [0.1313, 0.1446, 0.1047]])
# tensor(0.4879, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[ 0.0097, -0.0129,  0.3080],
#         [ 0.0243,  0.2315,  0.0125],
#         [ 0.2781, -0.0286, -0.0177],
#         [ 0.0243,  0.1584,  0.0125]], grad_fn=<SubBackward0>)
# tensor([[0.1025, 0.1062, 0.0961],
#         [0.0902, 0.0934, 0.0846],
#         [0.0780, 0.0807, 0.0731],
#         [0.0657, 0.0680, 0.0616]])
# tensor(0.7308, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0185, -0.0420,  0.1994],
#         [ 0.0263,  0.1513,  0.0363],
#         [ 0.3113, -0.0287,  0.0049],
#         [ 0.0263,  0.2972,  0.0363]], grad_fn=<SubBackward0>)
# tensor([[0.0480, 0.0525, 0.0385],
#         [0.0739, 0.0808, 0.0592],
#         [0.0993, 0.1086, 0.0796],
#         [0.1243, 0.1359, 0.0996]])
# tensor(0.5498, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0270, -0.0523,  0.1674],
#         [ 0.0286,  0.1232,  0.0448],
#         [ 0.3230, -0.0306,  0.0110],
#         [ 0.0286,  0.3385,  0.0448]], grad_fn=<SubBackward0>)
# tensor([[0.0311, 0.0334, 0.0236],
#         [0.0694, 0.0745, 0.0527],
#         [0.1071, 0.1149, 0.0813],
#         [0.1455, 0.1561, 0.1104]])
# tensor(0.3854, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0122, -0.0381,  0.2178],
#         [ 0.0286,  0.1617,  0.0333],
#         [ 0.3111, -0.0318, -0.0012],
#         [ 0.0286,  0.2691,  0.0333]], grad_fn=<SubBackward0>)
# tensor([[0.0596, 0.0604, 0.0474],
#         [0.0796, 0.0807, 0.0633],
#         [0.0990, 0.1003, 0.0787],
#         [0.1178, 0.1194, 0.0937]])
# tensor(0.6071, grad_fn=<DivBackward0>)
# model:begin
# model:end
# lp::: tensor(-241527.3750, grad_fn=<AddBackward0>)
# ps2
# guide:end
# model:begin
# model:end
# epoch 1840 loss = 296983.9051659107; logsdrchat = -1.580854058265686;
#  erchat = tensor([[-4.1953, -5.6635,  7.4013],
#         [-4.3544,  4.1797, -2.2135],
#         [ 7.1688, -6.7467, -2.3097],
#         [-4.4004,  5.3323, -2.2363]], requires_grad=True)
# scale tensor(5.8768)
# svi.step(... 1841 tensor(5.8768)
# guide:begin tensor(5.8768)
# optimize_Q SHRINK_FAC tensor([[-0.0271, -0.0498,  0.1765],
#         [ 0.0256,  0.1323,  0.0426],
#         [ 0.3144, -0.0272,  0.0123],
#         [ 0.0256,  0.3323,  0.0426]], grad_fn=<SubBackward0>)
# tensor([[0.0337, 0.0386, 0.0273],
#         [0.0679, 0.0777, 0.0549],
#         [0.1014, 0.1161, 0.0820],
#         [0.1356, 0.1552, 0.1097]])
# tensor(0.4321, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0088, -0.0314,  0.2500],
#         [ 0.0249,  0.1854,  0.0276],
#         [ 0.2946, -0.0279, -0.0026],
#         [ 0.0249,  0.2357,  0.0276]], grad_fn=<SubBackward0>)
# tensor([[0.0704, 0.0759, 0.0635],
#         [0.0799, 0.0861, 0.0720],
#         [0.0886, 0.0955, 0.0799],
#         [0.0967, 0.1043, 0.0872]])
# tensor(0.7001, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0232, -0.0471,  0.1843],
#         [ 0.0268,  0.1382,  0.0404],
#         [ 0.3149, -0.0289,  0.0086],
#         [ 0.0268,  0.3187,  0.0404]], grad_fn=<SubBackward0>)
# tensor([[0.0394, 0.0435, 0.0312],
#         [0.0709, 0.0783, 0.0562],
#         [0.1017, 0.1122, 0.0807],
#         [0.1332, 0.1470, 0.1057]])
# tensor(0.4752, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[ 0.0050, -0.0172,  0.2912],
#         [ 0.0239,  0.2215,  0.0160],
#         [ 0.2827, -0.0278, -0.0136],
#         [ 0.0239,  0.1786,  0.0160]], grad_fn=<SubBackward0>)
# tensor([[0.0936, 0.0990, 0.0863],
#         [0.0877, 0.0928, 0.0809],
#         [0.0809, 0.0856, 0.0747],
#         [0.0733, 0.0776, 0.0676]])
# tensor(0.7471, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0214, -0.0426,  0.1971],
#         [ 0.0239,  0.1515,  0.0366],
#         [ 0.3056, -0.0257,  0.0082],
#         [ 0.0239,  0.3064,  0.0366]], grad_fn=<SubBackward0>)
# tensor([[0.0442, 0.0519, 0.0371],
#         [0.0703, 0.0826, 0.0590],
#         [0.0956, 0.1122, 0.0802],
#         [0.1218, 0.1429, 0.1022]])
# tensor(0.5436, grad_fn=<DivBackward0>)
# model:begin
# model:end
# lp::: tensor(-231675.4844, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.1368)
# svi.step(... 1842 tensor(6.1368)
# guide:begin tensor(6.1368)
# optimize_Q SHRINK_FAC tensor([[ 0.0290,  0.0064,  0.3770],
#         [ 0.0236,  0.2863, -0.0032],
#         [ 0.2600, -0.0294, -0.0335],
#         [ 0.0236,  0.0634, -0.0032]], grad_fn=<SubBackward0>)
# tensor([[0.1386, 0.1347, 0.1390],
#         [0.1031, 0.1002, 0.1034],
#         [0.0663, 0.0644, 0.0665],
#         [0.0282, 0.0274, 0.0283]])
# tensor(0.6585, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0140, -0.0387,  0.2121],
#         [ 0.0274,  0.1597,  0.0337],
#         [ 0.3087, -0.0303,  0.0008],
#         [ 0.0274,  0.2796,  0.0337]], grad_fn=<SubBackward0>)
# tensor([[0.0557, 0.0590, 0.0447],
#         [0.0771, 0.0817, 0.0619],
#         [0.0976, 0.1034, 0.0783],
#         [0.1190, 0.1261, 0.0955]])
# tensor(0.5976, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0253, -0.0503,  0.1729],
#         [ 0.0280,  0.1283,  0.0431],
#         [ 0.3208, -0.0301,  0.0099],
#         [ 0.0280,  0.3315,  0.0431]], grad_fn=<SubBackward0>)
# tensor([[0.0342, 0.0369, 0.0262],
#         [0.0701, 0.0757, 0.0537],
#         [0.1056, 0.1140, 0.0809],
#         [0.1415, 0.1528, 0.1083]])
# tensor(0.4194, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0085, -0.0312,  0.2371],
#         [ 0.0250,  0.1813,  0.0274],
#         [ 0.2971, -0.0280, -0.0028],
#         [ 0.0250,  0.2502,  0.0274]], grad_fn=<SubBackward0>)
# tensor([[0.0668, 0.0735, 0.0571],
#         [0.0791, 0.0870, 0.0676],
#         [0.0901, 0.0992, 0.0770],
#         [0.1024, 0.1127, 0.0875]])
# tensor(0.6950, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0235, -0.0482,  0.1829],
#         [ 0.0278,  0.1349,  0.0415],
#         [ 0.3175, -0.0300,  0.0085],
#         [ 0.0278,  0.3196,  0.0415]], grad_fn=<SubBackward0>)
# tensor([[0.0388, 0.0418, 0.0305],
#         [0.0713, 0.0768, 0.0560],
#         [0.1034, 0.1113, 0.0812],
#         [0.1359, 0.1463, 0.1066]])
# tensor(0.4598, grad_fn=<DivBackward0>)
# model:begin
# model:end
# lp::: tensor(-236178.8125, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.4169)
# svi.step(... 1843 tensor(6.4169)
# guide:begin tensor(6.4169)
# optimize_Q SHRINK_FAC tensor([[ 0.0026, -0.0239,  0.2791],
#         [ 0.0287,  0.2038,  0.0218],
#         [ 0.2924, -0.0331, -0.0136],
#         [ 0.0287,  0.1917,  0.0218]], grad_fn=<SubBackward0>)
# tensor([[0.0909, 0.0873, 0.0797],
#         [0.0896, 0.0861, 0.0786],
#         [0.0866, 0.0832, 0.0760],
#         [0.0853, 0.0820, 0.0748]])
# tensor(0.7082, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0200, -0.0447,  0.1938],
#         [ 0.0276,  0.1439,  0.0386],
#         [ 0.3144, -0.0301,  0.0056],
#         [ 0.0276,  0.3047,  0.0386]], grad_fn=<SubBackward0>)
# tensor([[0.0451, 0.0482, 0.0357],
#         [0.0735, 0.0785, 0.0581],
#         [0.1014, 0.1083, 0.0802],
#         [0.1297, 0.1386, 0.1026]])
# tensor(0.5136, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[ 0.0244, -0.0015,  0.3457],
#         [ 0.0273,  0.2610,  0.0035],
#         [ 0.2725, -0.0333, -0.0311],
#         [ 0.0273,  0.1006,  0.0035]], grad_fn=<SubBackward0>)
# tensor([[0.1296, 0.1205, 0.1186],
#         [0.1026, 0.0954, 0.0939],
#         [0.0732, 0.0680, 0.0670],
#         [0.0462, 0.0429, 0.0423]])
# tensor(0.6649, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0161, -0.0412,  0.2107],
#         [ 0.0279,  0.1546,  0.0358],
#         [ 0.3102, -0.0307,  0.0023],
#         [ 0.0279,  0.2829,  0.0358]], grad_fn=<SubBackward0>)
# tensor([[0.0537, 0.0561, 0.0437],
#         [0.0764, 0.0798, 0.0621],
#         [0.0986, 0.1030, 0.0802],
#         [0.1213, 0.1267, 0.0987]])
# tensor(0.5703, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0261, -0.0504,  0.1706],
#         [ 0.0274,  0.1275,  0.0432],
#         [ 0.3205, -0.0294,  0.0107],
#         [ 0.0274,  0.3352,  0.0432]], grad_fn=<SubBackward0>)
# tensor([[0.0329, 0.0361, 0.0252],
#         [0.0692, 0.0759, 0.0530],
#         [0.1055, 0.1157, 0.0808],
#         [0.1417, 0.1554, 0.1086]])
# tensor(0.4132, grad_fn=<DivBackward0>)
# model:begin
# model:end
# lp::: tensor(-235473.7188, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(6.7238)
# svi.step(... 1844 tensor(6.7238)
# guide:begin tensor(6.7238)
# optimize_Q SHRINK_FAC tensor([[-0.0120, -0.0360,  0.2360],
#         [ 0.0266,  0.1720,  0.0314],
#         [ 0.3002, -0.0295, -0.0006],
#         [ 0.0266,  0.2539,  0.0314]], grad_fn=<SubBackward0>)
# tensor([[0.0642, 0.0678, 0.0561],
#         [0.0785, 0.0829, 0.0686],
#         [0.0922, 0.0973, 0.0805],
#         [0.1065, 0.1124, 0.0930]])
# tensor(0.6467, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0219, -0.0469,  0.1759],
#         [ 0.0281,  0.1339,  0.0404],
#         [ 0.3211, -0.0304,  0.0070],
#         [ 0.0281,  0.3244,  0.0404]], grad_fn=<SubBackward0>)
# tensor([[0.0381, 0.0408, 0.0283],
#         [0.0719, 0.0771, 0.0534],
#         [0.1058, 0.1134, 0.0785],
#         [0.1396, 0.1497, 0.1036]])
# tensor(0.4606, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0054, -0.0289,  0.2761],
#         [ 0.0257,  0.1968,  0.0256],
#         [ 0.2868, -0.0291, -0.0057],
#         [ 0.0257,  0.2069,  0.0256]], grad_fn=<SubBackward0>)
# tensor([[0.0805, 0.0836, 0.0778],
#         [0.0825, 0.0857, 0.0798],
#         [0.0838, 0.0871, 0.0810],
#         [0.0859, 0.0892, 0.0830]])
# tensor(0.7423, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0197, -0.0430,  0.1865],
#         [ 0.0261,  0.1447,  0.0371],
#         [ 0.3146, -0.0284,  0.0059],
#         [ 0.0261,  0.3130,  0.0371]], grad_fn=<SubBackward0>)
# tensor([[0.0430, 0.0478, 0.0330],
#         [0.0722, 0.0803, 0.0554],
#         [0.1014, 0.1128, 0.0779],
#         [0.1306, 0.1453, 0.1003]])
# tensor(0.5212, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[ 0.0095, -0.0132,  0.3398],
#         [ 0.0243,  0.2427,  0.0127],
#         [ 0.2664, -0.0287, -0.0175],
#         [ 0.0243,  0.1268,  0.0127]], grad_fn=<SubBackward0>)
# tensor([[0.1091, 0.1102, 0.1169],
#         [0.0908, 0.0917, 0.0973],
#         [0.0715, 0.0722, 0.0766],
#         [0.0532, 0.0537, 0.0570]])
# tensor(0.7086, grad_fn=<DivBackward0>)
# model:begin
# model:end
# lp::: tensor(-219314.0312, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end
# scale tensor(5.4095)
# svi.step(... 1845 tensor(5.4095)
# guide:begin tensor(5.4095)
# optimize_Q SHRINK_FAC tensor([[-0.0173, -0.0411,  0.2045],
#         [ 0.0265,  0.1533,  0.0356],
#         [ 0.3098, -0.0290,  0.0038],
#         [ 0.0265,  0.2918,  0.0356]], grad_fn=<SubBackward0>)
# tensor([[0.0505, 0.0548, 0.0408],
#         [0.0744, 0.0808, 0.0602],
#         [0.0984, 0.1067, 0.0795],
#         [0.1223, 0.1327, 0.0989]])
# tensor(0.5658, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0271, -0.0513,  0.1692],
#         [ 0.0273,  0.1262,  0.0439],
#         [ 0.3209, -0.0292,  0.0117],
#         [ 0.0273,  0.3372,  0.0439]], grad_fn=<SubBackward0>)
# tensor([[0.0316, 0.0347, 0.0244],
#         [0.0688, 0.0756, 0.0531],
#         [0.1057, 0.1162, 0.0815],
#         [0.1423, 0.1564, 0.1097]])
# tensor(0.3994, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-1.3190e-02, -3.7655e-02,  2.2835e-01],
#         [ 2.7088e-02,  1.6593e-01,  3.2820e-02],
#         [ 3.0401e-01, -3.0031e-02,  1.8354e-04],
#         [ 2.7089e-02,  2.6259e-01,  3.2818e-02]], grad_fn=<SubBackward0>)
# tensor([[0.0612, 0.0640, 0.0522],
#         [0.0779, 0.0815, 0.0664],
#         [0.0946, 0.0989, 0.0807],
#         [0.1113, 0.1164, 0.0949]])
# tensor(0.6235, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0237, -0.0466,  0.1731],
#         [ 0.0257,  0.1359,  0.0399],
#         [ 0.3176, -0.0277,  0.0094],
#         [ 0.0257,  0.3305,  0.0400]], grad_fn=<SubBackward0>)
# tensor([[0.0355, 0.0403, 0.0270],
#         [0.0696, 0.0791, 0.0529],
#         [0.1034, 0.1174, 0.0786],
#         [0.1368, 0.1554, 0.1040]])
# tensor(0.4593, grad_fn=<DivBackward0>)
# optimize_Q SHRINK_FAC tensor([[-0.0076, -0.0315,  0.2640],
#         [ 0.0262,  0.1877,  0.0277],
#         [ 0.2920, -0.0295, -0.0041],
#         [ 0.0262,  0.2211,  0.0277]], grad_fn=<SubBackward0>)
# tensor([[0.0757, 0.0782, 0.0709],
#         [0.0814, 0.0840, 0.0762],
#         [0.0870, 0.0899, 0.0815],
#         [0.0927, 0.0957, 0.0868]])
# tensor(0.7059, grad_fn=<DivBackward0>)
# model:begin
# model:end
# lp::: tensor(-240115.0312, grad_fn=<AddBackward0>)
# guide:end
# model:begin
# model:end

# %% [markdown]
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# Now, "toypyro", a minimal model to narrow in on and reproduce any bugs.

# %%
from importlib import reload
import demo #import *
reload(demo)
from demo import *
import cProfile as profile


result = trainGuide()
# Out:
# epoch 0 loss = 9970.42696261406
# epoch 10 loss = 8222.381203889847
# epoch 20 loss = 60.06933152675629
# epoch 30 loss = 1137.6531113386154
# epoch 40 loss = 1467.7961308956146
# epoch 50 loss = 503.1370403766632
# epoch 60 loss = 5752.136534690857
# epoch 70 loss = 1244.33548527956
# epoch 80 loss = 8540.950506448746
# epoch 90 loss = 569.7613765001297
# epoch 100 loss = 6894.649996995926
# epoch 110 loss = 4175.3235194683075
# epoch 120 loss = 472.6241273880005
# epoch 130 loss = 1902.5091660022736
# epoch 140 loss = 913.3949070572853
# epoch 150 loss = 120.05118358135223
# epoch 160 loss = 24.606423556804657
# epoch 170 loss = 110.1393538415432
# epoch 180 loss = 74.07718658447266
# epoch 190 loss = 5440.085318565369
# epoch 200 loss = 516.0992064476013
# epoch 210 loss = 593.9815967679024
# epoch 220 loss = 344.73766988515854
# epoch 230 loss = 933.6469010710716
# epoch 240 loss = 190.28482508659363
# epoch 250 loss = 852.1514495611191
# epoch 260 loss = 223.10303181409836
# epoch 270 loss = 1054.054571211338
# epoch 280 loss = 67.37258738279343
# epoch 290 loss = 425.1358232498169
# epoch 300 loss = 1052.9819769859314
# epoch 310 loss = 1674.3172267079353
# epoch 320 loss = 434.36263167858124
# epoch 330 loss = 371.0104421377182
# epoch 340 loss = 534.7153202295303
# epoch 350 loss = 76.14917385578156
# epoch 360 loss = 1898.6710789203644
# epoch 370 loss = 190.43798637390137
# epoch 380 loss = 499.90254777669907
# epoch 390 loss = 227.2196364402771
# epoch 400 loss = 549.3110811710358
# epoch 410 loss = 840.1415543556213
# epoch 420 loss = 187.75638806819916
# epoch 430 loss = 8.163513362407684
# epoch 440 loss = 36.8250629901886
# epoch 450 loss = 282.2171347141266
# epoch 460 loss = 88.93707716464996
# epoch 470 loss = -8.457634627819061
# epoch 480 loss = 415.9394348859787
# epoch 490 loss = 27.139925122261047
# epoch 500 loss = 238.95548915863037
# epoch 510 loss = 308.2312113046646
# epoch 520 loss = -13.960336089134216
# epoch 530 loss = 211.98778748512268
# epoch 540 loss = 214.59208965301514
# epoch 550 loss = 434.7178844213486
# epoch 560 loss = 216.3488790988922
# epoch 570 loss = 1302.4268074035645
# epoch 580 loss = 156.7089728116989
# epoch 590 loss = 215.6293957233429
# epoch 600 loss = 417.47256302833557
# epoch 610 loss = 323.62663531303406
# epoch 620 loss = 898.4031736850739
# epoch 630 loss = 69.56500446796417
# epoch 640 loss = -21.20420789718628
# epoch 650 loss = -14.589676976203918
# epoch 660 loss = 32.44058358669281
# epoch 670 loss = 18.092478275299072
# epoch 680 loss = -8.768603086471558
# epoch 690 loss = 0.3066471815109253
# epoch 700 loss = -17.7206848859787
# epoch 710 loss = 10.318970441818237
# epoch 720 loss = 27.703640580177307
# epoch 730 loss = -8.549628853797913
# epoch 740 loss = 97.89159786701202
# epoch 750 loss = -23.435295581817627
# epoch 760 loss = 80.2417802810669
# epoch 770 loss = 191.0366222858429
# epoch 780 loss = 1.0039712190628052
# epoch 790 loss = -14.158635020256042
# epoch 800 loss = 101.04626989364624
# epoch 810 loss = -4.6242356300354
# epoch 820 loss = 67.7615761756897
# epoch 830 loss = 204.67140352725983
# epoch 840 loss = 24.472697854042053
# epoch 850 loss = -9.110898852348328
# epoch 860 loss = -10.40952980518341
# epoch 870 loss = 12.897611021995544
# epoch 880 loss = 81.61308634281158
# epoch 890 loss = -16.697559475898743
# epoch 900 loss = 10.683896660804749
# epoch 910 loss = 58.94023394584656
# epoch 920 loss = -20.48142147064209
# epoch 930 loss = 36.798425793647766
# epoch 940 loss = -4.461576581001282
# epoch 950 loss = 32.648712038993835
# epoch 960 loss = -20.80633819103241
# epoch 970 loss = 13.59885823726654
# epoch 980 loss = 27.542380213737488
# epoch 990 loss = -20.179308533668518
# epoch 1000 loss = -19.005021929740906
# epoch 1010 loss = -18.2170547246933
# epoch 1020 loss = -19.43075668811798
# epoch 1030 loss = -4.924235939979553
# epoch 1040 loss = -21.92120921611786
# epoch 1050 loss = 16.83372700214386
# epoch 1060 loss = -11.871260285377502
# epoch 1070 loss = -10.325113654136658
# epoch 1080 loss = -18.82685911655426
# epoch 1090 loss = 10.077147364616394
# epoch 1100 loss = -27.32503378391266
# epoch 1110 loss = -5.696203827857971
# epoch 1120 loss = -13.577538132667542
# epoch 1130 loss = -19.523112654685974
# epoch 1140 loss = -12.977255702018738
# epoch 1150 loss = -23.81832444667816
# epoch 1160 loss = -16.85115420818329
# epoch 1170 loss = -6.799846529960632
# epoch 1180 loss = -20.49998939037323
# epoch 1190 loss = -15.655739068984985
# epoch 1200 loss = -9.904370427131653
# epoch 1210 loss = -29.566373586654663
# epoch 1220 loss = 5.4111088514328
# epoch 1230 loss = -28.05242884159088
# epoch 1240 loss = -21.681487321853638
# epoch 1250 loss = -13.319893598556519
# epoch 1260 loss = -12.41371762752533
# epoch 1270 loss = -21.702600359916687
# epoch 1280 loss = -22.059823989868164
# epoch 1290 loss = -25.3575279712677
# epoch 1300 loss = -26.640719413757324
# epoch 1310 loss = -24.549542903900146
# epoch 1320 loss = -19.065369606018066
# epoch 1330 loss = -19.86486268043518
# epoch 1340 loss = -20.076615929603577
# epoch 1350 loss = -26.849024534225464
# epoch 1360 loss = -22.73797631263733
# epoch 1370 loss = -19.59937858581543
# epoch 1380 loss = -28.688270330429077
# epoch 1390 loss = -25.230886578559875
# epoch 1400 loss = -19.165393352508545
# epoch 1410 loss = -21.86486506462097
# epoch 1420 loss = -17.583155870437622
# epoch 1430 loss = -18.787638187408447
# epoch 1440 loss = -21.011450052261353
# epoch 1450 loss = -22.13494110107422
# epoch 1460 loss = -13.651560068130493
# epoch 1470 loss = -21.351763010025024
# epoch 1480 loss = -20.056892037391663
# epoch 1490 loss = -15.752094388008118
# epoch 1500 loss = -26.150632858276367
# epoch 1510 loss = -30.08116364479065
# epoch 1520 loss = -13.490179896354675
# epoch 1530 loss = -11.820260643959045
# epoch 1540 loss = -27.708999156951904
# epoch 1550 loss = -21.760513305664062
# epoch 1560 loss = -25.024082899093628
# epoch 1570 loss = -30.239800810813904
# epoch 1580 loss = -24.265573501586914
# epoch 1590 loss = -12.849509716033936
# epoch 1600 loss = -21.990947246551514
# epoch 1610 loss = -25.473822593688965
# epoch 1620 loss = -21.74608302116394
# epoch 1630 loss = -29.68125820159912
# epoch 1640 loss = -16.449406623840332
# epoch 1650 loss = -22.486225843429565
# epoch 1660 loss = -21.300263166427612
# epoch 1670 loss = -23.194011330604553
# epoch 1680 loss = -20.318111419677734
# epoch 1690 loss = -25.038808345794678
# epoch 1700 loss = -23.52825403213501
# epoch 1710 loss = -11.93352997303009
# epoch 1720 loss = -20.955570459365845
# epoch 1730 loss = -24.713982343673706
# epoch 1740 loss = -22.206504344940186
# epoch 1750 loss = -18.968297481536865
# epoch 1760 loss = -27.074164748191833
# epoch 1770 loss = -21.310234308242798
# epoch 1780 loss = -21.19845724105835
# epoch 1790 loss = -24.367520809173584
# epoch 1800 loss = -26.015806794166565
# epoch 1810 loss = -23.054303884506226
# epoch 1820 loss = -25.64688992500305
# epoch 1830 loss = -13.319884181022644
# epoch 1840 loss = -17.32163166999817
# epoch 1850 loss = -23.7455712556839
# epoch 1860 loss = -25.545387268066406
# epoch 1870 loss = -27.497881412506104
# epoch 1880 loss = -24.89391028881073
# epoch 1890 loss = -24.854057788848877
# epoch 1900 loss = -23.371911883354187
# epoch 1910 loss = -26.387003779411316
# epoch 1920 loss = -22.207335233688354
# epoch 1930 loss = -22.02166199684143
# epoch 1940 loss = -23.83713984489441
# epoch 1950 loss = -25.31385374069214
# epoch 1960 loss = -16.196258068084717
# epoch 1970 loss = -22.292989253997803
# epoch 1980 loss = -23.85995388031006
# epoch 1990 loss = -28.101629972457886
# epoch 2000 loss = -22.794631123542786
# epoch 2010 loss = -22.766714811325073
# epoch 2020 loss = -25.436706066131592
# epoch 2030 loss = -25.03978204727173
# epoch 2040 loss = -26.8535076379776
# epoch 2050 loss = -22.176397800445557
# epoch 2060 loss = -16.28916573524475
# epoch 2070 loss = -19.07245898246765
# epoch 2080 loss = -22.417195081710815
# epoch 2090 loss = -29.459009885787964
# epoch 2100 loss = -15.73995041847229
# epoch 2110 loss = -21.550569772720337
# epoch 2120 loss = -19.20262575149536
# epoch 2130 loss = -25.475621461868286
# epoch 2140 loss = -25.69290542602539
# epoch 2150 loss = -26.19874334335327
# epoch 2160 loss = -25.563206911087036
# epoch 2170 loss = -27.548903465270996
# epoch 2180 loss = -22.519362926483154
# epoch 2190 loss = -20.045663595199585
# epoch 2200 loss = -22.438573360443115
# epoch 2210 loss = -25.288503170013428
# epoch 2220 loss = -21.962993383407593
# epoch 2230 loss = -16.933046579360962
# epoch 2240 loss = -19.901620388031006
# epoch 2250 loss = -15.773172616958618
# epoch 2260 loss = -16.03392219543457
# epoch 2270 loss = -27.897440671920776
# epoch 2280 loss = -20.802294731140137
# epoch 2290 loss = -24.83900547027588
# epoch 2300 loss = -30.2585289478302
# epoch 2310 loss = -20.315150022506714
# epoch 2320 loss = -22.15317392349243
# epoch 2330 loss = -25.159435987472534
# epoch 2340 loss = -20.672945022583008
# epoch 2350 loss = -23.544315814971924
# epoch 2360 loss = -21.54719305038452
# epoch 2370 loss = -22.543355226516724
# epoch 2380 loss = -23.42118239402771
# epoch 2390 loss = -21.949904322624207
# epoch 2400 loss = -31.188451051712036
# epoch 2410 loss = -18.388630628585815
# epoch 2420 loss = -18.03581702709198
# epoch 2430 loss = -27.299959778785706
# epoch 2440 loss = -27.348795413970947
# epoch 2450 loss = -21.49933934211731
# epoch 2460 loss = -24.72176694869995
# epoch 2470 loss = -20.447677612304688
# epoch 2480 loss = -27.689104080200195
# epoch 2490 loss = -24.22283685207367
# epoch 2500 loss = -22.203494548797607
# epoch 2510 loss = -19.911522388458252
# epoch 2520 loss = -22.637953996658325
# epoch 2530 loss = -18.87294626235962
# epoch 2540 loss = -31.51684594154358
# epoch 2550 loss = -21.241424798965454
# epoch 2560 loss = -18.018275499343872
# epoch 2570 loss = -20.61366891860962
# epoch 2580 loss = -26.1727454662323
# epoch 2590 loss = -20.367342233657837
# epoch 2600 loss = -21.66036605834961
# epoch 2610 loss = -20.375153064727783
# epoch 2620 loss = -28.787466764450073
# epoch 2630 loss = -26.659034252166748
# epoch 2640 loss = -27.07300877571106
# epoch 2650 loss = -20.351962089538574
# epoch 2660 loss = -21.9063138961792
# epoch 2670 loss = -21.56492280960083
# epoch 2680 loss = -27.147707223892212
# epoch 2690 loss = -23.924439072608948
# epoch 2700 loss = -21.84794807434082
# epoch 2710 loss = -25.21865200996399
# epoch 2720 loss = -23.206295013427734
# epoch 2730 loss = -31.85695791244507
# epoch 2740 loss = -21.257530689239502
# epoch 2750 loss = -16.897451639175415
# epoch 2760 loss = -17.47722029685974
# epoch 2770 loss = -20.478862285614014
# epoch 2780 loss = -27.533504486083984
# epoch 2790 loss = -23.544565200805664
# epoch 2800 loss = -17.046606063842773
# epoch 2810 loss = -25.670005321502686
# epoch 2820 loss = -25.69626784324646
# epoch 2830 loss = -27.408512592315674
# epoch 2840 loss = -24.09447407722473
# epoch 2850 loss = -15.136472463607788
# epoch 2860 loss = -18.049262523651123
# epoch 2870 loss = -19.774412989616394
# epoch 2880 loss = -20.50040626525879
# epoch 2890 loss = -25.857336282730103
# epoch 2900 loss = -18.43021249771118
# epoch 2910 loss = -21.843361854553223
# epoch 2920 loss = -21.852466821670532
# epoch 2930 loss = -25.457306385040283
# epoch 2940 loss = -35.21738600730896
# epoch 2950 loss = -17.756343126296997
# epoch 2960 loss = -17.89638376235962
# epoch 2970 loss = -22.20802640914917
# epoch 2980 loss = -17.484975576400757
# epoch 2990 loss = -20.95511245727539
# epoch 3000 loss = -15.643475770950317
# logScaleHat:
# -3.4726879596710205
# logTailHat:
# 0.29934072494506836
# meanHat:
# -0.034671951085329056
# meanSig:
# 0.015605974942445755
# truthHat:
# tensor([-0.0286, -0.0322, -0.0375, -0.0357, -0.0525, -0.0504, -0.0500, -0.0541,
#         -0.0367, -0.0450, -0.0574, -0.0379, -0.0411, -0.0153, -0.0267, -0.0459,
#         -0.0555, -0.0385, -0.0429, -0.0377, -0.0214, -0.0371, -0.0546, -0.0285,
#         -0.0435, -0.0514, -0.0516, -0.0364, -0.0439, -0.0525, -0.0455, -0.0388,
#         -0.0331, -0.0612, -0.0482, -0.0386, -0.0361, -0.0341, -0.0338, -0.0455,
#         -0.0555, -0.0040, -0.0210, -0.0291], requires_grad=True)
# truthRho:
# 0.008846916258335114
# truthSEmult:
# 0.28036901354789734

# %% [markdown]
# Next, run "polytopize", which has all of my pre-Fritz attempts to code.

# %%
import torch
ts = torch.tensor
import pyro.distributions as dist
import pyro
import cmult

t1 = ts([3.,4.])
t2 = ts([2.,5.])

m = t1.view(-1,1).mm(t1.view(1,-1))

print(m)

#means = torch.zeros(3,2)
#means[1,1] = 100.
with pyro.plate('dumb',3):
    #t3 = pyro.sample('irrelevant',dist.Normal(means,ts(1.)).to_event(1))
    t3 = pyro.sample('irrelevant',cmult.CMult(50,torch.ones(3,3,3)/3).to_event(2))

#print(t3)

mult = cmult.CMult(50,torch.ones(3)/3)
print(mult.log_prob(ts([0.,50,0])))
print(mult.log_prob(ts([0.,1,0])))
# Out:
# tensor([[ 9., 12.],
#         [12., 16.]])
# tensor(-54.9306)
# tensor(-1.0986)

# %%
yhat1 = polytopize(4,3,pyro.get_param_store()["what_0"],
                 get_indep(4,3,ts([68.,20,25,56]),ts([63.,32,74])))

erchat = pyro.get_param_store()["erchat"]

print(pyro.get_param_store()["what_0"])
print(erchat)
print(recenter_rc(erchat))
print(pyro.get_param_store()["logsdrchat"])
# Out:
# tensor([[-0.3764, -0.7578],
#         [-0.0823,  0.0420],
#         [ 0.0860,  0.2053]], requires_grad=True)
# tensor([[-0.0440, -0.0448,  0.1284],
#         [-0.0490, -0.0334,  0.1120],
#         [-0.0486, -0.0243,  0.0850],
#         [-0.0567, -0.0134,  0.0715]], requires_grad=True)
# tensor([[ 0.0031, -0.0173,  0.0341],
#         [-0.0019, -0.0059,  0.0177],
#         [-0.0015,  0.0032, -0.0093],
#         [-0.0096,  0.0141, -0.0227]], grad_fn=<SubBackward0>)
# tensor(-3.1610, requires_grad=True)

# %% [markdown]
# # Testing hessian transparency

# %%
import torch
ts = torch.tensor
os = torch.ones
zs = torch.zeros
from importlib import reload
import myhessian
reload(myhessian)

t1 = os(2,2,requires_grad=True)
r = torch.sum(t1 * t1 * t1)

h = myhessian.hessian(r,t1)
print("hess",h)
r2 = torch.sum(h * h)
[r3] = torch.autograd.grad(r,t1,create_graph=True,retain_graph=True)
print("d ",r3)
print("Σd ",torch.sum(r3))
[r4] = torch.autograd.grad(torch.sum(r3),t1,create_graph=True,retain_graph=True)
print("dΣdΣd ",torch.autograd.grad(torch.sum(r4),t1,create_graph=True,retain_graph=True))
print(torch.autograd.grad(r2,t1))
# Out:
# hess tensor([[6., 0., 0., 0.],
#         [0., 6., 0., 0.],
#         [0., 0., 6., 0.],
#         [0., 0., 0., 6.]], grad_fn=<CopySlices>)
# d  tensor([[3., 3.],
#         [3., 3.]], grad_fn=<AddBackward0>)
# Σd  tensor(12., grad_fn=<SumBackward0>)
# dΣdΣd  (tensor([[6., 6.],
#         [6., 6.]]),)
# (tensor([[72., 72.],
#         [72., 72.]]),)

# %%
import sys
import hessian

from importlib import reload
import polytopize #import *
reload(polytopize)
from polytopize import *

import tests
# Out:
# Yes, I will run.
# Yes, I will run.
# ge fail
# loc tensor([[ 0.3147],
#         [ 2.4440],
#         [-4.0535],
#         [ 2.2007]])
# polytopedLoc tensor([[ 2.1063e-01,  2.1136e-02],
#         [ 2.8514e-01, -1.8626e-09],
#         [ 3.4959e-01,  9.9957e-02],
#         [ 3.5462e-01,  1.1892e-02],
#         [ 2.5462e+00,  3.2228e-01]])
# ge fail
# loc tensor([[-5.8855],
#         [-5.2805],
#         [ 5.4654],
#         [ 0.1889]])
# polytopedLoc tensor([[ 2.8885e-01,  1.1871e+00],
#         [ 8.5629e-01,  2.0505e+00],
#         [ 3.9984e-01, -1.4901e-08],
#         [ 9.5542e-01,  1.5538e+00],
#         [ 1.0063e+00,  9.9522e-01]])
# Reloading cmult...
# callable? <bound method TorchDistributionMixin.__call__ of Multinomial()>
# callable? <bound method TorchDistributionMixin.__call__ of TorchCMult()>
# Sampling multinomial: tensor([1., 2.])
# Sampling cm2: tensor([0., 3.])
# tensor(5.6022, grad_fn=<NegBackward>) tensor([[112.2500]])

# %% [markdown]
# # Test rank1torch (to get yhat from pi,n,v)

# %%
from importlib import reload
import rank1torch #import *
reload(rank1torch)
from rank1torch import *

test_solver()
# Out:
# Testing optimize_Q (50 tests):
# R=3, C=5, tolerance=0.001
# ==================================================
# Oh no! In test 3, Q has some negative entries:
# 	 trueQ[2][4]=0.00010659269901225343,
# 	     Q[2][4]=-0.00021605131041724235
# Oh no! In test 5, Q has some negative entries:
# 	 trueQ[1][4]=0.00011974151857430115,
# 	     Q[1][4]=-1.1631345842033625e-06
# Oh no! In test 8, Q has some negative entries:
# 	 trueQ[0][1]=2.882161788875237e-05,
# 	     Q[0][1]=-0.0004783869662787765
# Oh no! In test 15, Q has some negative entries:
# 	 trueQ[2][3]=0.0007846675580367446,
# 	     Q[2][3]=-6.166117964312434e-05
# Oh no! In test 28, Q has some negative entries:
# 	 trueQ[0][4]=8.13114020274952e-05,
# 	     Q[0][4]=-0.00018321917741559446
# Oh no! In test 40, Q has some negative entries:
# 	 trueQ[2][3]=0.00032634526723995805,
# 	     Q[2][3]=-0.000617634505033493
# Oh no! In test 47, Q has some negative entries:
# 	 trueQ[2][1]=0.00017936740186996758,
# 	     Q[2][1]=-0.00041433278238400817
# Oh no! In test 48, Q has some negative entries:
# 	 trueQ[0][0]=4.524858377408236e-05,
# 	     Q[0][0]=-0.0006647921400144696
#
# Cumulative results for the 50 tests
# (R=3, C=5, tolerance=0.001):
# -------------------------------------------
# Worst error in entry of Q: 0.0019194334745407104
#
# To get within tolerance, it took us:
# 002 iterations: ***** 5.0 times
# 003 iterations: ********** 10.0 times
# 004 iterations: *********** 11.0 times
# 005 iterations: ****** 6.0 times
# 006 iterations: **** 4.0 times
# 007 iterations: **** 4.0 times
# 008 iterations: ****** 6.0 times
# 010 iterations: *** 3.0 times
# 013 iterations: * 1.0 times

# %% [markdown]
# Finally, this is a cell for directly experimenting with pytorch and/or pyro. Basically, for getting the tensor syntax right.

# %%
import torch
import cmult
import pyro
from importlib import reload
reload(cmult)
from cmult import CMult

#print(CMult(probs=torch.tensor([1., 1., 1., 1.])).log_prob(torch.tensor([1.2, 1.5, 1., 1.])))

#print(CMult(100, torch.tensor([ 1., 1., 1., 1.])).sample())

R, C = (3,4)

y = pyro.distributions.Normal(0.,4.).sample(torch.Size([R-1,C-1]))


w = torch.cat((y,-y.sum(1).unsqueeze(1)),1)
w = torch.cat((w,-w.sum(0).unsqueeze(0)),0)

#print(w)
b = w.argmax()
print(b)
print(w,w[b//C,b % C])

tt = torch.zeros(R,C)
print(tt,R,C,tt[:(R-1),:(C-1)])

# %% [markdown]
# ## Overview
#
# Most SVI problems in pyro are coded as a model, a generic guide (such as: multivariate Gaussian in all parameters), and specific observations/data (passed as arguments to svi.step). For EI, that's going to be different; the observations are going to be built into the guide function, leaving nothing to include in the "data" argument to svi.step.
#
# That means there is a lot of work for the guide to do. As usual, it must establish reasonable distributional families for the posterior of each of the hyperparameters. But for the latent parameters, the job of the guide is to take a "relative strength" number for each race/candidate/precinct combo, and turn that into a number of votes for each combo, such that those numbers obey all the constraints set by observations. This means that for each precinct (considered separately), the latent guide must:
#
# -Find the "center point" where candidate preference is independent of race.
#
# -Find the "basis vectors" (actually, there are more than enough of them to form a basis) which determine the directions to move in the space.
#
# -For any given set of "relative strengths" which is a distance $d$ in a direction $\theta$, find the first constraint violated when moving in that direction, and the distance $r$ between the origin and that constraint.
#
# -Project the "relative strengths" onto the numbers of votes, by moving $r(1-e^{-d})$ in direction $\theta$.

# %% [markdown]
# #### a = zs(2,2,2,2)
# a[0,1,1,1] = 2
# print(a[1,1])
# print(a[0,1])
# print(torch.max(a))
# print(torch.distributions.exponential.Exponential(ts([1])).sample(4))

# %%
print("hi","world")
a = zs(2,2,2,2)
a[0,1,1,1] = 2 
print(torch.max(a[0,1])) 
print(pyro.distributions.Exponential(1.).sample(torch.Size([3])))
a.add_(torch.ones(2,2,2))
print(torch.exp)
