# %% [markdown]
# # Quick intro
#
# This is a jupyter notebook for testing / coding. So far, each code block is a separate test; unlike an ordinary notebook, they are not meant to run sequentially.
#
# Let's do MCMC:

# %% [markdown]
# Next, running "ei". This started out as a copy of Fritz's code but it's evolved into a working version of ours.

# %%
from importlib import reload
import ei2 #import *
reload(ei2)
from ei2 import *
import cProfile as profile

# %prun result = trainGuide()
# Out:
# Yes, I will run.
# Reloading polytopize.
# model:begin 1.0 False
# ec:tensor([0.0000, 0.5000])
# erc:tensor([[0., 1.],
#         [2., 0.],
#         [0., 0.]])
# y[0]:tensor([[164., 159.],
#         [105., 117.],
#         [ 61.,  56.]])
# scale tensor(6.1139)
# svi.step(... 0 tensor(6.1139)
# guide:begin tensor(6.1139) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(6.1139) True
# model y tensor(6.1139) torch.Size([5, 3, 2]) tensor([[161.0121, 161.9879],
#         [110.6647, 111.3353]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-23432.2676, grad_fn=<AddBackward0>) 361
# calc_lls
# rescaledSDDD torch.Size([8, 8])
# tensor([[  0.0000,   0.0000,  -0.9940,   0.9940],
#         [  0.0000,   0.0000,   0.0000,   0.0000],
#         [ -0.9940,   0.0000,  88.1389, -80.7498],
#         [  0.9940,   0.0000, -80.7498,  88.1389]], grad_fn=<SliceBackward>)
# tensor([[  0.5542,   0.0000,  -0.9940,   0.9940],
#         [  0.0000,   0.5932,   0.0000,   0.0000],
#         [ -0.9940,   0.0000,  91.0008, -80.7498],
#         [  0.9940,   0.0000, -80.7498,  91.0008]], grad_fn=<SliceBackward>)
# example:
# tensor([[   0.0000,    0.0000,   -6.0770,    6.0770],
#         [   0.0000,    0.0000,    0.0000,    0.0000],
#         [  -6.0770,    0.0000,  538.8687, -493.6931],
#         [   6.0770,    0.0000, -493.6931,  538.8688]], grad_fn=<SliceBackward>)
# tensor([[   3.3885,    0.0000,   -6.0770,    6.0770],
#         [   0.0000,    3.6268,    0.0000,    0.0000],
#         [  -6.0770,    0.0000,  556.3661, -493.6931],
#         [   6.0770,    0.0000, -493.6931,  556.3664]], grad_fn=<SliceBackward>)
# marginal
# tensor([[33832.0312, -7382.8218, -3666.9561],
#         [-7382.8218, 22567.8887, 14975.3555],
#         [-3666.9561, 14975.3555, 26283.7539]], grad_fn=<SliceBackward>)
# tensor([[   7706.5039,   -3608.8889,   -1471.3616],
#         [  -3608.8923,  -25952.5801,  -56879.3477],
#         [  -1471.3628,  -56879.3477, -114291.2812]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[   7706.5039,   -3608.8889,   -1471.3616],
#         [  -3608.8923,  -25952.5801,  -56879.3477],
#         [  -1471.3628,  -56879.3477, -114291.2812]], grad_fn=<SliceBackward>)
# tensor([[446493.8750,  -3608.8892,  -1471.3615],
#         [ -3608.8923,  57003.3438, -56879.3477],
#         [ -1471.3628, -56879.3477,  57067.3438]], grad_fn=<SliceBackward>)
# ps2
# guide:end
# model:begin tensor(6.1139) True
# model y tensor(6.1139) torch.Size([5, 3, 2]) tensor([[160.4884, 162.5116],
#         [110.4346, 111.5654]], grad_fn=<SliceBackward>)
# model:end
# epoch 0 loss = 30710.865763306618; logsdrcstar = -1.0049999952316284;
#  ercstar = tensor([[-0.0050],
#         [ 0.0050]], requires_grad=True)
# scale tensor(6.3715)
# svi.step(... 1 tensor(6.3715)
# guide:begin tensor(6.3715) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(6.3715) True
# model y tensor(6.3715) torch.Size([5, 3, 2]) tensor([[157.2141, 160.7859],
#         [160.8017, 161.1983]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-31850.5645, grad_fn=<AddBackward0>) 361
# calc_lls
# rescaledSDDD torch.Size([8, 8])
# tensor([[ 6.2867e-05, -3.1536e-05, -9.9495e-01,  9.9495e-01],
#         [-3.1536e-05,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-9.9495e-01,  0.0000e+00,  8.6954e+01, -7.9491e+01],
#         [ 9.9495e-01,  0.0000e+00, -7.9491e+01,  8.6954e+01]],
#        grad_fn=<SliceBackward>)
# tensor([[ 3.3775e-03, -3.1536e-05, -9.9495e-01,  9.9495e-01],
#         [-3.1536e-05,  4.3868e-01,  0.0000e+00,  0.0000e+00],
#         [-9.9495e-01,  0.0000e+00,  1.2517e+03, -7.9491e+01],
#         [ 9.9495e-01,  0.0000e+00, -7.9491e+01,  1.2517e+03]],
#        grad_fn=<SliceBackward>)
# example:
# tensor([[ 4.0056e-04, -2.0093e-04, -6.3393e+00,  6.3393e+00],
#         [-2.0093e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-6.3393e+00,  0.0000e+00,  5.5403e+02, -5.0648e+02],
#         [ 6.3393e+00,  0.0000e+00, -5.0648e+02,  5.5403e+02]],
#        grad_fn=<SliceBackward>)
# tensor([[ 2.1520e-02, -2.0093e-04, -6.3393e+00,  6.3393e+00],
#         [-2.0093e-04,  2.7951e+00,  0.0000e+00,  0.0000e+00],
#         [-6.3393e+00,  0.0000e+00,  7.9749e+03, -5.0648e+02],
#         [ 6.3393e+00,  0.0000e+00, -5.0648e+02,  7.9749e+03]],
#        grad_fn=<SliceBackward>)
# marginal
# tensor([[ 45962.8984, -11010.2012,  -5453.8252],
#         [-11010.2012,  30637.5508,  20823.8750],
#         [ -5453.8252,  20823.8750,  36193.9258]], grad_fn=<SliceBackward>)
# tensor([[  25058.7852,  -28171.2793,  -21391.5938],
#         [ -28171.2676, -701188.1875, -393355.3750],
#         [ -21391.5938, -393355.3750, -293883.3750]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[  25058.7852,  -28171.2793,  -21391.5938],
#         [ -28171.2676, -701188.1875, -393355.3750],
#         [ -21391.5938, -393355.3750, -293883.3750]], grad_fn=<SliceBackward>)
# tensor([[7853857.5000,  -28171.2812,  -21391.5938],
#         [ -28171.2676,  394628.0625, -393355.3750],
#         [ -21391.5938, -393355.3750,  394177.8750]], grad_fn=<SliceBackward>)
# guide:end
# model:begin tensor(6.3715) True
# model y tensor(6.3715) torch.Size([5, 3, 2]) tensor([[ 17.8256, 300.1744],
#         [160.1322, 161.8678]], grad_fn=<SliceBackward>)
# model:end
# scale tensor(6.6595)
# svi.step(... 2 tensor(6.6595)
# guide:begin tensor(6.6595) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(6.6595) True
# model y tensor(6.6595) torch.Size([5, 3, 2]) tensor([[154.5073, 154.4927],
#         [214.1199, 207.8801]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-31845.9668, grad_fn=<AddBackward0>) 361
# calc_lls
# rescaledSDDD torch.Size([8, 8])
# tensor([[ 0.0000e+00,  2.4899e-06, -9.9495e-01,  9.9495e-01],
#         [ 2.4899e-06,  1.4392e-04, -1.7282e-03,  1.7282e-03],
#         [-9.9495e-01, -1.7282e-03,  8.4787e+01, -7.7248e+01],
#         [ 9.9495e-01,  1.7282e-03, -7.7248e+01,  8.4787e+01]],
#        grad_fn=<SliceBackward>)
# tensor([[ 3.9478e-01,  2.4899e-06, -9.9495e-01,  9.9495e-01],
#         [ 2.4899e-06,  4.2531e-03, -1.7282e-03,  1.7282e-03],
#         [-9.9495e-01, -1.7282e-03,  8.8590e+01, -7.7248e+01],
#         [ 9.9495e-01,  1.7282e-03, -7.7248e+01,  8.8589e+01]],
#        grad_fn=<SliceBackward>)
# example:
# tensor([[ 0.0000e+00,  1.6581e-05, -6.6259e+00,  6.6259e+00],
#         [ 1.6581e-05,  9.5847e-04, -1.1509e-02,  1.1509e-02],
#         [-6.6259e+00, -1.1509e-02,  5.6464e+02, -5.1444e+02],
#         [ 6.6259e+00,  1.1509e-02, -5.1444e+02,  5.6464e+02]],
#        grad_fn=<SliceBackward>)
# tensor([[ 2.6290e+00,  1.6581e-05, -6.6259e+00,  6.6259e+00],
#         [ 1.6581e-05,  2.8323e-02, -1.1509e-02,  1.1509e-02],
#         [-6.6259e+00, -1.1509e-02,  5.8996e+02, -5.1444e+02],
#         [ 6.6259e+00,  1.1509e-02, -5.1444e+02,  5.8996e+02]],
#        grad_fn=<SliceBackward>)
# marginal
# tensor([[ 45960.0547, -10135.2432,  -4975.3164],
#         [-10135.2432,  30608.6016,  20371.9219],
#         [ -4975.3164,  20371.9219,  35768.5273]], grad_fn=<SliceBackward>)
# tensor([[  28720.0469,  -16974.8477,   -7384.2192],
#         [ -16974.8516,  -84570.3516, -188059.7188],
#         [  -7384.2305, -188059.7188, -383156.0000]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[  28720.0469,  -16974.8477,   -7384.2192],
#         [ -16974.8516,  -84570.3516, -188059.7188],
#         [  -7384.2305, -188059.7188, -383156.0000]], grad_fn=<SliceBackward>)
# tensor([[4132512.2500,  -16974.8477,   -7384.2188],
#         [ -16974.8516,  188432.6875, -188059.7188],
#         [  -7384.2305, -188059.7188,  188674.6250]], grad_fn=<SliceBackward>)
# guide:end
# model:begin tensor(6.6595) True
# model y tensor(6.6595) torch.Size([5, 3, 2]) tensor([[154.2879, 154.7121],
#         [ 47.7321, 374.2679]], grad_fn=<SliceBackward>)
# model:end
# scale tensor(5.4732)
# svi.step(... 3 tensor(5.4732)
# guide:begin tensor(5.4732) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(5.4732) True
# model y tensor(5.4732) torch.Size([5, 3, 2]) tensor([[151.7691, 152.2309],
#         [265.2303, 256.7697]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-31839.7168, grad_fn=<AddBackward0>) 361
# calc_lls
# rescaledSDDD torch.Size([8, 8])
# tensor([[ 0.0000e+00, -5.8146e-06, -9.9442e-01,  9.9442e-01],
#         [-5.8146e-06,  1.2342e-04, -1.9439e-03,  1.9439e-03],
#         [-9.9442e-01, -1.9439e-03,  8.3612e+01, -7.5998e+01],
#         [ 9.9442e-01,  1.9439e-03, -7.5998e+01,  8.3612e+01]],
#        grad_fn=<SliceBackward>)
# tensor([[ 3.7251e-01, -5.8146e-06, -9.9442e-01,  9.9442e-01],
#         [-5.8146e-06,  3.4736e-03, -1.9439e-03,  1.9439e-03],
#         [-9.9442e-01, -1.9439e-03,  8.7528e+01, -7.5998e+01],
#         [ 9.9442e-01,  1.9439e-03, -7.5998e+01,  8.7528e+01]],
#        grad_fn=<SliceBackward>)
# example:
# tensor([[ 0.0000e+00, -3.1825e-05, -5.4427e+00,  5.4427e+00],
#         [-3.1825e-05,  6.7549e-04, -1.0640e-02,  1.0640e-02],
#         [-5.4427e+00, -1.0640e-02,  4.5763e+02, -4.1595e+02],
#         [ 5.4427e+00,  1.0640e-02, -4.1595e+02,  4.5763e+02]],
#        grad_fn=<SliceBackward>)
# tensor([[ 2.0388e+00, -3.1825e-05, -5.4427e+00,  5.4427e+00],
#         [-3.1825e-05,  1.9012e-02, -1.0640e-02,  1.0640e-02],
#         [-5.4427e+00, -1.0640e-02,  4.7906e+02, -4.1595e+02],
#         [ 5.4427e+00,  1.0640e-02, -4.1595e+02,  4.7906e+02]],
#        grad_fn=<SliceBackward>)
# marginal
# tensor([[ 45953.4219, -13965.7812,  -6893.0312],
#         [-13965.7812,  30606.1133,  22285.9473],
#         [ -6893.0312,  22285.9473,  37678.8633]], grad_fn=<SliceBackward>)
# tensor([[  29786.9902,  -19461.2070,  -10931.0752],
#         [ -19461.2109,  -75337.8438, -171754.6562],
#         [ -10931.0781, -171754.6719, -354130.8750]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[  29786.9902,  -19461.2070,  -10931.0752],
#         [ -19461.2109,  -75337.8438, -171754.6562],
#         [ -10931.0781, -171754.6719, -354130.8750]], grad_fn=<SliceBackward>)
# tensor([[5250885.5000,  -19461.2070,  -10931.0752],
#         [ -19461.2109,  172114.6250, -171754.6562],
#         [ -10931.0781, -171754.6719,  172344.0000]], grad_fn=<SliceBackward>)
# guide:end
# model:begin tensor(5.4732) True
# model y tensor(5.4732) torch.Size([5, 3, 2]) tensor([[152.7301, 151.2699],
#         [376.9191, 145.0809]], grad_fn=<SliceBackward>)
# model:end
# scale tensor(5.6676)
# svi.step(... 4 tensor(5.6676)
# guide:begin tensor(5.6676) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(5.6676) True
# model y tensor(5.6676) torch.Size([5, 3, 2]) tensor([[153.3523, 149.6477],
#         [320.9803, 301.0197]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-31838.8652, grad_fn=<AddBackward0>) 361
# calc_lls
# rescaledSDDD torch.Size([8, 8])
# tensor([[ 9.2770e-05, -8.0276e-05, -9.8990e-01,  9.8990e-01],
#         [-8.0276e-05,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-9.8990e-01,  0.0000e+00,  8.3441e+01, -7.5750e+01],
#         [ 9.8990e-01,  0.0000e+00, -7.5750e+01,  8.3441e+01]],
#        grad_fn=<SliceBackward>)
# tensor([[ 3.3447e-03, -8.0276e-05, -9.8990e-01,  9.8990e-01],
#         [-8.0276e-05,  3.0241e-01,  0.0000e+00,  0.0000e+00],
#         [-9.8990e-01,  0.0000e+00,  1.0163e+03, -7.5750e+01],
#         [ 9.8990e-01,  0.0000e+00, -7.5750e+01,  1.0163e+03]],
#        grad_fn=<SliceBackward>)
# example:
# tensor([[ 5.2578e-04, -4.5497e-04, -5.6103e+00,  5.6103e+00],
#         [-4.5497e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-5.6103e+00,  0.0000e+00,  4.7291e+02, -4.2932e+02],
#         [ 5.6103e+00,  0.0000e+00, -4.2932e+02,  4.7291e+02]],
#        grad_fn=<SliceBackward>)
# tensor([[ 1.8956e-02, -4.5497e-04, -5.6103e+00,  5.6103e+00],
#         [-4.5497e-04,  1.7139e+00,  0.0000e+00,  0.0000e+00],
#         [-5.6103e+00,  0.0000e+00,  5.7600e+03, -4.2932e+02],
#         [ 5.6103e+00,  0.0000e+00, -4.2932e+02,  5.7600e+03]],
#        grad_fn=<SliceBackward>)
# marginal
# tensor([[ 45954.3438, -13249.1191,  -6566.2520],
#         [-13249.1191,  30628.0703,  21938.5957],
#         [ -6566.2520,  21938.5957,  37310.9375]], grad_fn=<SliceBackward>)
# tensor([[  24530.6602,  -26936.8867,  -21481.4883],
#         [ -26936.8672, -387074.2500, -202252.6719],
#         [ -21481.4707, -202252.6250, -129796.8750]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[  24530.6602,  -26936.8867,  -21481.4883],
#         [ -26936.8672, -387074.2500, -202252.6719],
#         [ -21481.4707, -202252.6250, -129796.8750]], grad_fn=<SliceBackward>)
# tensor([[7591215.0000,  -26936.8887,  -21481.4883],
#         [ -26936.8672,  203014.1875, -202252.6719],
#         [ -21481.4707, -202252.6250,  202721.9688]], grad_fn=<SliceBackward>)
# guide:end
# model:begin tensor(5.6676) True
# model y tensor(5.6676) torch.Size([5, 3, 2]) tensor([[ 64.2321, 238.7679],
#         [319.0377, 302.9623]], grad_fn=<SliceBackward>)
# model:end
# scale tensor(5.8762)
# svi.step(... 5 tensor(5.8762)
# guide:begin tensor(5.8762) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(5.8762) True
# model y tensor(5.8762) torch.Size([5, 3, 2]) tensor([[143.2753, 154.7247],
#         [354.8916, 367.1084]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-31836.4941, grad_fn=<AddBackward0>) 361
# calc_lls
# rescaledSDDD torch.Size([8, 8])
# tensor([[ 2.0818e-04, -4.1179e-05, -9.8430e-01,  9.8430e-01],
#         [-4.1179e-05,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-9.8430e-01,  0.0000e+00,  8.2217e+01, -7.4449e+01],
#         [ 9.8430e-01,  0.0000e+00, -7.4449e+01,  8.2217e+01]],
#        grad_fn=<SliceBackward>)
# tensor([[ 4.8246e-03, -4.1179e-05, -9.8430e-01,  9.8430e-01],
#         [-4.1179e-05,  2.7345e-01,  0.0000e+00,  0.0000e+00],
#         [-9.8430e-01,  0.0000e+00,  6.9443e+02, -7.4449e+01],
#         [ 9.8430e-01,  0.0000e+00, -7.4449e+01,  6.9443e+02]],
#        grad_fn=<SliceBackward>)
# example:
# tensor([[ 1.2233e-03, -2.4198e-04, -5.7840e+00,  5.7840e+00],
#         [-2.4198e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-5.7840e+00,  0.0000e+00,  4.8313e+02, -4.3748e+02],
#         [ 5.7840e+00,  0.0000e+00, -4.3748e+02,  4.8313e+02]],
#        grad_fn=<SliceBackward>)
# tensor([[ 2.8351e-02, -2.4198e-04, -5.7840e+00,  5.7840e+00],
#         [-2.4198e-04,  1.6068e+00,  0.0000e+00,  0.0000e+00],
#         [-5.7840e+00,  0.0000e+00,  4.0807e+03, -4.3748e+02],
#         [ 5.7840e+00,  0.0000e+00, -4.3748e+02,  4.0807e+03]],
#        grad_fn=<SliceBackward>)
# marginal
# tensor([[ 45954.2891, -12528.3350,  -6239.4727],
#         [-12528.3350,  30650.7500,  21589.5430],
#         [ -6239.4727,  21589.5430,  36939.6133]], grad_fn=<SliceBackward>)
# tensor([[  22920.8457,  -16842.9668,  -18378.9297],
#         [ -16842.9727, -214108.0625,  -98827.4375],
#         [ -18378.9258,  -98827.4375,  -38824.8320]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[  22920.8457,  -16842.9668,  -18378.9297],
#         [ -16842.9727, -214108.0625,  -98827.4375],
#         [ -18378.9258,  -98827.4375,  -38824.8320]], grad_fn=<SliceBackward>)
# tensor([[5337999.0000,  -16842.9668,  -18378.9297],
#         [ -16842.9727,   99251.7500,  -98827.4375],
#         [ -18378.9258,  -98827.4375,   99086.6406]], grad_fn=<SliceBackward>)
# guide:end
# model:begin tensor(5.8762) True
# model y tensor(5.8762) torch.Size([5, 3, 2]) tensor([[125.9183, 172.0817],
#         [354.0480, 367.9520]], grad_fn=<SliceBackward>)
# model:end
# scale tensor(6.1139)
# svi.step(... 6 tensor(6.1139)
# guide:begin tensor(6.1139) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(6.1139) True
# model y tensor(6.1139) torch.Size([5, 3, 2]) tensor([[159.2534, 163.7466],
#         [111.9764, 110.0236]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-31822.3301, grad_fn=<AddBackward0>) 361
# calc_lls
# rescaledSDDD torch.Size([8, 8])
# tensor([[ 0.0000e+00, -1.6510e-04, -9.9410e-01,  9.9410e-01],
#         [-1.6510e-04,  7.2477e-05, -7.8815e-03,  7.8815e-03],
#         [-9.9410e-01, -7.8815e-03,  8.8579e+01, -8.0733e+01],
#         [ 9.9410e-01,  7.8815e-03, -8.0733e+01,  8.8579e+01]],
#        grad_fn=<SliceBackward>)
# tensor([[ 5.6769e-01, -1.6510e-04, -9.9410e-01,  9.9410e-01],
#         [-1.6510e-04,  4.9200e-03, -7.8815e-03,  7.8815e-03],
#         [-9.9410e-01, -7.8815e-03,  9.9683e+01, -8.0733e+01],
#         [ 9.9410e-01,  7.8815e-03, -8.0733e+01,  9.9683e+01]],
#        grad_fn=<SliceBackward>)
# example:
# tensor([[ 0.0000e+00, -1.0094e-03, -6.0778e+00,  6.0778e+00],
#         [-1.0094e-03,  4.4311e-04, -4.8186e-02,  4.8186e-02],
#         [-6.0778e+00, -4.8186e-02,  5.4156e+02, -4.9359e+02],
#         [ 6.0778e+00,  4.8186e-02, -4.9359e+02,  5.4156e+02]],
#        grad_fn=<SliceBackward>)
# tensor([[ 3.4708e+00, -1.0094e-03, -6.0778e+00,  6.0778e+00],
#         [-1.0094e-03,  3.0080e-02, -4.8186e-02,  4.8186e-02],
#         [-6.0778e+00, -4.8186e-02,  6.0945e+02, -4.9359e+02],
#         [ 6.0778e+00,  4.8186e-02, -4.9359e+02,  6.0945e+02]],
#        grad_fn=<SliceBackward>)
# marginal
# tensor([[ 45944.9062, -11826.2686,  -5873.8340],
#         [-11826.2686,  30635.0723,  21230.6699],
#         [ -5873.8340,  21230.6699,  36587.5078]], grad_fn=<SliceBackward>)
# tensor([[  21991.6270,  -15142.9082,  -12587.7861],
#         [ -15142.9062, -175542.5156, -144069.9375],
#         [ -12587.7812, -144069.9375, -187036.7188]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[  21991.6270,  -15142.9082,  -12587.7861],
#         [ -15142.9062, -175542.5156, -144069.9375],
#         [ -12587.7812, -144069.9375, -187036.7188]], grad_fn=<SliceBackward>)
# tensor([[4116648.7500,  -15142.9082,  -12587.7861],
#         [ -15142.9062,  144491.7656, -144069.9375],
#         [ -12587.7812, -144069.9375,  144486.0938]], grad_fn=<SliceBackward>)
# guide:end
# model:begin tensor(6.1139) True
# model y tensor(6.1139) torch.Size([5, 3, 2]) tensor([[160.3645, 162.6355],
#         [ 52.9036, 169.0964]], grad_fn=<SliceBackward>)
# model:end
# scale tensor(6.3715)
# svi.step(... 7 tensor(6.3715)
# guide:begin tensor(6.3715) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(6.3715) True
# model y tensor(6.3715) torch.Size([5, 3, 2]) tensor([[155.7777, 162.2223],
#         [161.2485, 160.7515]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-31843.3184, grad_fn=<AddBackward0>) 361
# calc_lls
# rescaledSDDD torch.Size([8, 8])
# tensor([[ 2.5085e-04, -1.0678e-05, -9.8586e-01,  9.8586e-01],
#         [-1.0678e-05,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-9.8586e-01,  0.0000e+00,  8.7398e+01, -7.9473e+01],
#         [ 9.8586e-01,  0.0000e+00, -7.9473e+01,  8.7398e+01]],
#        grad_fn=<SliceBackward>)
# tensor([[ 6.6784e-03, -1.0678e-05, -9.8586e-01,  9.8586e-01],
#         [-1.0678e-05,  4.3228e-01,  0.0000e+00,  0.0000e+00],
#         [-9.8586e-01,  0.0000e+00,  6.6281e+02, -7.9473e+01],
#         [ 9.8586e-01,  0.0000e+00, -7.9473e+01,  6.6281e+02]],
#        grad_fn=<SliceBackward>)
# example:
# tensor([[ 1.5983e-03, -6.8033e-05, -6.2814e+00,  6.2814e+00],
#         [-6.8033e-05,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-6.2814e+00,  0.0000e+00,  5.5685e+02, -5.0636e+02],
#         [ 6.2814e+00,  0.0000e+00, -5.0636e+02,  5.5685e+02]],
#        grad_fn=<SliceBackward>)
# tensor([[ 4.2551e-02, -6.8033e-05, -6.2814e+00,  6.2814e+00],
#         [-6.8033e-05,  2.7543e+00,  0.0000e+00,  0.0000e+00],
#         [-6.2814e+00,  0.0000e+00,  4.2231e+03, -5.0636e+02],
#         [ 6.2814e+00,  0.0000e+00, -5.0636e+02,  4.2231e+03]],
#        grad_fn=<SliceBackward>)
# marginal
# tensor([[ 45960.5859, -11012.1279,  -5454.1982],
#         [-11012.1279,  30637.4648,  20824.7969],
#         [ -5454.1982,  20824.7969,  36195.3945]], grad_fn=<SliceBackward>)
# tensor([[  22168.5273,  -11931.0508,  -15657.5078],
#         [ -11931.0332, -174719.9062,  -81546.0469],
#         [ -15657.4844,  -81546.0469,  -31637.7070]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[  22168.5273,  -11931.0508,  -15657.5078],
#         [ -11931.0332, -174719.9062,  -81546.0469],
#         [ -15657.4844,  -81546.0469,  -31637.7070]], grad_fn=<SliceBackward>)
# tensor([[4111988.5000,  -11931.0508,  -15657.5078],
#         [ -11931.0332,   81882.5625,  -81546.0469],
#         [ -15657.4844,  -81546.0469,   81764.5312]], grad_fn=<SliceBackward>)
# guide:end
# model:begin tensor(6.3715) True
# model y tensor(6.3715) torch.Size([5, 3, 2]) tensor([[103.7811, 214.2189],
#         [160.3752, 161.6248]], grad_fn=<SliceBackward>)
# model:end
# scale tensor(6.6595)
# svi.step(... 8 tensor(6.6595)
# guide:begin tensor(6.6595) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(6.6595) True
# model y tensor(6.6595) torch.Size([5, 3, 2]) tensor([[152.5838, 156.4162],
#         [212.8277, 209.1723]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-31838.7812, grad_fn=<AddBackward0>) 361
# calc_lls
# rescaledSDDD torch.Size([8, 8])
# tensor([[ 3.0448e-04,  1.8920e-05, -9.8292e-01,  9.8292e-01],
#         [ 1.8920e-05,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-9.8292e-01,  0.0000e+00,  8.5235e+01, -7.7230e+01],
#         [ 9.8292e-01,  0.0000e+00, -7.7230e+01,  8.5235e+01]],
#        grad_fn=<SliceBackward>)
# tensor([[ 6.6331e-03,  1.8920e-05, -9.8292e-01,  9.8292e-01],
#         [ 1.8920e-05,  3.6469e-01,  0.0000e+00,  0.0000e+00],
#         [-9.8292e-01,  0.0000e+00,  5.9863e+02, -7.7230e+01],
#         [ 9.8292e-01,  0.0000e+00, -7.7230e+01,  5.9863e+02]],
#        grad_fn=<SliceBackward>)
# example:
# tensor([[ 2.0277e-03,  1.2600e-04, -6.5458e+00,  6.5458e+00],
#         [ 1.2600e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-6.5458e+00,  0.0000e+00,  5.6762e+02, -5.1432e+02],
#         [ 6.5458e+00,  0.0000e+00, -5.1432e+02,  5.6762e+02]],
#        grad_fn=<SliceBackward>)
# tensor([[ 4.4173e-02,  1.2600e-04, -6.5458e+00,  6.5458e+00],
#         [ 1.2600e-04,  2.4287e+00,  0.0000e+00,  0.0000e+00],
#         [-6.5458e+00,  0.0000e+00,  3.9866e+03, -5.1432e+02],
#         [ 6.5458e+00,  0.0000e+00, -5.1432e+02,  3.9866e+03]],
#        grad_fn=<SliceBackward>)
# marginal
# tensor([[ 45958.3906, -10137.2598,  -4973.8955],
#         [-10137.2598,  30607.7422,  20372.5020],
#         [ -4973.8955,  20372.5020,  35771.1055]], grad_fn=<SliceBackward>)
# tensor([[  22002.8926,  -10915.3750,  -15158.4902],
#         [ -10915.3789, -146716.0938,  -68012.7734],
#         [ -15158.4873,  -68012.7656,  -25191.5273]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[  22002.8926,  -10915.3750,  -15158.4902],
#         [ -10915.3789, -146716.0938,  -68012.7734],
#         [ -15158.4873,  -68012.7656,  -25191.5273]], grad_fn=<SliceBackward>)
# tensor([[3871692.0000,  -10915.3750,  -15158.4912],
#         [ -10915.3789,   68301.1875,  -68012.7734],
#         [ -15158.4873,  -68012.7656,   68208.2812]], grad_fn=<SliceBackward>)
# guide:end
# model:begin tensor(6.6595) True
# model y tensor(6.6595) torch.Size([5, 3, 2]) tensor([[282.7867,  26.2133],
#         [213.7792, 208.2208]], grad_fn=<SliceBackward>)
# model:end
# scale tensor(5.4732)
# svi.step(... 9 tensor(5.4732)
# guide:begin tensor(5.4732) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(5.4732) True
# model y tensor(5.4732) torch.Size([5, 3, 2]) tensor([[149.9629, 154.0371],
#         [262.8376, 259.1624]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-31834.0449, grad_fn=<AddBackward0>) 361
# calc_lls
# rescaledSDDD torch.Size([8, 8])
# tensor([[ 3.1975e-04,  2.8661e-05, -9.8156e-01,  9.8156e-01],
#         [ 2.8661e-05,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-9.8156e-01,  0.0000e+00,  8.4063e+01, -7.5978e+01],
#         [ 9.8156e-01,  0.0000e+00, -7.5978e+01,  8.4063e+01]],
#        grad_fn=<SliceBackward>)
# tensor([[ 6.3871e-03,  2.8661e-05, -9.8156e-01,  9.8156e-01],
#         [ 2.8661e-05,  3.2356e-01,  0.0000e+00,  0.0000e+00],
#         [-9.8156e-01,  0.0000e+00,  5.8058e+02, -7.5978e+01],
#         [ 9.8156e-01,  0.0000e+00, -7.5978e+01,  5.8058e+02]],
#        grad_fn=<SliceBackward>)
# example:
# tensor([[ 1.7501e-03,  1.5687e-04, -5.3723e+00,  5.3723e+00],
#         [ 1.5687e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-5.3723e+00,  0.0000e+00,  4.6010e+02, -4.1585e+02],
#         [ 5.3723e+00,  0.0000e+00, -4.1585e+02,  4.6010e+02]],
#        grad_fn=<SliceBackward>)
# tensor([[ 3.4958e-02,  1.5687e-04, -5.3723e+00,  5.3723e+00],
#         [ 1.5687e-04,  1.7709e+00,  0.0000e+00,  0.0000e+00],
#         [-5.3723e+00,  0.0000e+00,  3.1776e+03, -4.1585e+02],
#         [ 5.3723e+00,  0.0000e+00, -4.1585e+02,  3.1776e+03]],
#        grad_fn=<SliceBackward>)
# marginal
# tensor([[ 45952.3516, -13973.0098,  -6896.1074],
#         [-13973.0098,  30606.9277,  22289.9688],
#         [ -6896.1074,  22289.9688,  37683.8281]], grad_fn=<SliceBackward>)
# tensor([[  20903.2637,  -15663.5547,  -17151.9492],
#         [ -15663.5645, -102659.4453,  -43562.4531],
#         [ -17151.9609,  -43562.4688,  -12104.6836]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[  20903.2637,  -15663.5547,  -17151.9492],
#         [ -15663.5645, -102659.4453,  -43562.4531],
#         [ -17151.9609,  -43562.4688,  -12104.6836]], grad_fn=<SliceBackward>)
# tensor([[4749377.5000,  -15663.5547,  -17151.9492],
#         [ -15663.5645,   43817.1484,  -43562.4531],
#         [ -17151.9609,  -43562.4688,   43736.8984]], grad_fn=<SliceBackward>)
# guide:end
# model:begin tensor(5.4732) True
# model y tensor(5.4732) torch.Size([5, 3, 2]) tensor([[269.4061,  34.5939],
#         [263.5929, 258.4071]], grad_fn=<SliceBackward>)
# model:end
# scale tensor(5.6676)
# svi.step(... 10 tensor(5.6676)
# guide:begin tensor(5.6676) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(5.6676) True
# model y tensor(5.6676) torch.Size([5, 3, 2]) tensor([[152.1326, 150.8674],
#         [318.4964, 303.5036]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-31833.2109, grad_fn=<AddBackward0>) 361
# calc_lls
# rescaledSDDD torch.Size([8, 8])
# tensor([[ 2.9543e-04,  2.1489e-05, -9.8202e-01,  9.8202e-01],
#         [ 2.1489e-05,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-9.8202e-01,  0.0000e+00,  8.3912e+01, -7.5746e+01],
#         [ 9.8202e-01,  0.0000e+00, -7.5746e+01,  8.3912e+01]],
#        grad_fn=<SliceBackward>)
# tensor([[ 5.8702e-03,  2.1489e-05, -9.8202e-01,  9.8202e-01],
#         [ 2.1489e-05,  2.9374e-01,  0.0000e+00,  0.0000e+00],
#         [-9.8202e-01,  0.0000e+00,  6.0044e+02, -7.5746e+01],
#         [ 9.8202e-01,  0.0000e+00, -7.5746e+01,  6.0044e+02]],
#        grad_fn=<SliceBackward>)
# example:
# tensor([[ 1.6744e-03,  1.2179e-04, -5.5657e+00,  5.5657e+00],
#         [ 1.2179e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-5.5657e+00,  0.0000e+00,  4.7558e+02, -4.2929e+02],
#         [ 5.5657e+00,  0.0000e+00, -4.2929e+02,  4.7558e+02]],
#        grad_fn=<SliceBackward>)
# tensor([[ 3.3270e-02,  1.2179e-04, -5.5657e+00,  5.5657e+00],
#         [ 1.2179e-04,  1.6648e+00,  0.0000e+00,  0.0000e+00],
#         [-5.5657e+00,  0.0000e+00,  3.4031e+03, -4.2929e+02],
#         [ 5.5657e+00,  0.0000e+00, -4.2929e+02,  3.4031e+03]],
#        grad_fn=<SliceBackward>)
# marginal
# tensor([[ 45953.5547, -13253.1924,  -6567.8652],
#         [-13253.1924,  30629.1699,  21941.1816],
#         [ -6567.8652,  21941.1816,  37314.4961]], grad_fn=<SliceBackward>)
# tensor([[  21218.5195,  -14848.4541,  -16859.1914],
#         [ -14848.4551, -121227.3594,  -53269.7422],
#         [ -16859.2031,  -53269.7422,  -17072.0039]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[  21218.5195,  -14848.4541,  -16859.1914],
#         [ -14848.4551, -121227.3594,  -53269.7422],
#         [ -16859.2031,  -53269.7422,  -17072.0039]], grad_fn=<SliceBackward>)
# tensor([[4623520.0000,  -14848.4541,  -16859.1914],
#         [ -14848.4551,   53546.2969,  -53269.7422],
#         [ -16859.2031,  -53269.7422,   53455.9570]], grad_fn=<SliceBackward>)
# ps2
# guide:end
# model:begin tensor(5.6676) True
# model y tensor(5.6676) torch.Size([5, 3, 2]) tensor([[231.5832,  71.4168],
#         [319.7036, 302.2964]], grad_fn=<SliceBackward>)
# model:end
# epoch 10 loss = 30965.484398961067; logsdrcstar = -1.0551334619522095;
#  ercstar = tensor([[-0.0145],
#         [ 0.0049]], requires_grad=True)
# scale tensor(5.8762)
# svi.step(... 11 tensor(5.8762)
# guide:begin tensor(5.8762) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(5.8762) True
# model y tensor(5.8762) torch.Size([5, 3, 2]) tensor([[142.6837, 155.3163],
#         [352.7497, 369.2503]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-31830.3633, grad_fn=<AddBackward0>) 361
# calc_lls
# rescaledSDDD torch.Size([8, 8])
# tensor([[ 3.2546e-04,  3.1496e-05, -9.8024e-01,  9.8024e-01],
#         [ 3.1496e-05,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-9.8024e-01,  0.0000e+00,  8.2676e+01, -7.4428e+01],
#         [ 9.8024e-01,  0.0000e+00, -7.4428e+01,  8.2676e+01]],
#        grad_fn=<SliceBackward>)
# tensor([[ 5.9607e-03,  3.1496e-05, -9.8024e-01,  9.8024e-01],
#         [ 3.1496e-05,  2.7143e-01,  0.0000e+00,  0.0000e+00],
#         [-9.8024e-01,  0.0000e+00,  5.6976e+02, -7.4428e+01],
#         [ 9.8024e-01,  0.0000e+00, -7.4428e+01,  5.6976e+02]],
#        grad_fn=<SliceBackward>)
# example:
# tensor([[ 1.9125e-03,  1.8508e-04, -5.7601e+00,  5.7601e+00],
#         [ 1.8508e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-5.7601e+00,  0.0000e+00,  4.8582e+02, -4.3735e+02],
#         [ 5.7601e+00,  0.0000e+00, -4.3735e+02,  4.8582e+02]],
#        grad_fn=<SliceBackward>)
# tensor([[ 3.5026e-02,  1.8508e-04, -5.7601e+00,  5.7601e+00],
#         [ 1.8508e-04,  1.5950e+00,  0.0000e+00,  0.0000e+00],
#         [-5.7601e+00,  0.0000e+00,  3.3481e+03, -4.3735e+02],
#         [ 5.7601e+00,  0.0000e+00, -4.3735e+02,  3.3481e+03]],
#        grad_fn=<SliceBackward>)
# marginal
# tensor([[ 45952.8203, -12530.2637,  -6240.0146],
#         [-12530.2637,  30651.4180,  21590.8398],
#         [ -6240.0146,  21590.8398,  36941.6680]], grad_fn=<SliceBackward>)
# tensor([[  21380.5020,  -14034.8643,  -16542.1836],
#         [ -14034.8477, -122968.5625,  -54543.9961],
#         [ -16542.1641,  -54544.0117,  -17875.4336]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[  21380.5020,  -14034.8643,  -16542.1836],
#         [ -14034.8477, -122968.5625,  -54543.9961],
#         [ -16542.1641,  -54544.0117,  -17875.4336]], grad_fn=<SliceBackward>)
# tensor([[4475652.5000,  -14034.8643,  -16542.1836],
#         [ -14034.8477,   54817.5938,  -54543.9961],
#         [ -16542.1641,  -54544.0117,   54729.6992]], grad_fn=<SliceBackward>)
# guide:end
# model:begin tensor(5.8762) True
# model y tensor(5.8762) torch.Size([5, 3, 2]) tensor([[222.4097,  75.5903],
#         [353.3644, 368.6356]], grad_fn=<SliceBackward>)
# model:end
# scale tensor(6.1139)
# svi.step(... 12 tensor(6.1139)
# guide:begin tensor(6.1139) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(6.1139) True
# model y tensor(6.1139) torch.Size([5, 3, 2]) tensor([[159.3290, 163.6710],
#         [111.6269, 110.3731]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-31816.0430, grad_fn=<AddBackward0>) 361
# calc_lls
# rescaledSDDD torch.Size([8, 8])
# tensor([[ 7.6208e-04,  4.3934e-04, -9.7953e-01,  9.7953e-01],
#         [ 4.3934e-04,  1.1661e-04,  1.4314e-02, -1.4314e-02],
#         [-9.7953e-01,  1.4314e-02,  8.9058e+01, -8.0727e+01],
#         [ 9.7953e-01, -1.4314e-02, -8.0727e+01,  8.9058e+01]],
#        grad_fn=<SliceBackward>)
# tensor([[ 1.5829e-02,  4.3934e-04, -9.7953e-01,  9.7953e-01],
#         [ 4.3934e-04,  6.4006e-03,  1.4314e-02, -1.4314e-02],
#         [-9.7953e-01,  1.4314e-02,  4.2929e+02, -8.0727e+01],
#         [ 9.7953e-01, -1.4314e-02, -8.0727e+01,  4.2929e+02]],
#        grad_fn=<SliceBackward>)
# example:
# tensor([[ 4.6592e-03,  2.6861e-03, -5.9887e+00,  5.9887e+00],
#         [ 2.6861e-03,  7.1295e-04,  8.7517e-02, -8.7517e-02],
#         [-5.9887e+00,  8.7517e-02,  5.4449e+02, -4.9355e+02],
#         [ 5.9887e+00, -8.7517e-02, -4.9355e+02,  5.4449e+02]],
#        grad_fn=<SliceBackward>)
# tensor([[ 9.6775e-02,  2.6861e-03, -5.9887e+00,  5.9887e+00],
#         [ 2.6861e-03,  3.9132e-02,  8.7517e-02, -8.7517e-02],
#         [-5.9887e+00,  8.7517e-02,  2.6246e+03, -4.9355e+02],
#         [ 5.9887e+00, -8.7517e-02, -4.9355e+02,  2.6246e+03]],
#        grad_fn=<SliceBackward>)
# marginal
# tensor([[ 45943.3828, -11827.7070,  -5874.1943],
#         [-11827.7070,  30635.7656,  21231.7363],
#         [ -5874.1943,  21231.7363,  36589.2773]], grad_fn=<SliceBackward>)
# tensor([[  22143.3203,  -11699.6484,  -11728.7227],
#         [ -11699.6465, -132183.1406,  -88457.7109],
#         [ -11728.7207,  -88457.7031,  -81287.0156]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[  22143.3203,  -11699.6484,  -11728.7227],
#         [ -11699.6465, -132183.1406,  -88457.7109],
#         [ -11728.7207,  -88457.7031,  -81287.0156]], grad_fn=<SliceBackward>)
# tensor([[3489965.2500,  -11699.6484,  -11728.7227],
#         [ -11699.6465,   88757.0781,  -88457.7109],
#         [ -11728.7207,  -88457.7031,   88706.3594]], grad_fn=<SliceBackward>)
# guide:end
# model:begin tensor(6.1139) True
# model y tensor(6.1139) torch.Size([5, 3, 2]) tensor([[173.4197, 149.5803],
#         [155.6683,  66.3317]], grad_fn=<SliceBackward>)
# model:end
# scale tensor(6.3715)
# svi.step(... 13 tensor(6.3715)
# guide:begin tensor(6.3715) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(6.3715) True
# model y tensor(6.3715) torch.Size([5, 3, 2]) tensor([[155.7544, 162.2456],
#         [160.7329, 161.2671]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-31837.4121, grad_fn=<AddBackward0>) 361
# calc_lls
# rescaledSDDD torch.Size([8, 8])
# tensor([[ 2.9405e-04,  3.0115e-05, -9.8571e-01,  9.8571e-01],
#         [ 3.0115e-05,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-9.8571e-01,  0.0000e+00,  8.7878e+01, -7.9464e+01],
#         [ 9.8571e-01,  0.0000e+00, -7.9464e+01,  8.7878e+01]],
#        grad_fn=<SliceBackward>)
# tensor([[ 7.1985e-03,  3.0115e-05, -9.8571e-01,  9.8571e-01],
#         [ 3.0115e-05,  4.3208e-01,  0.0000e+00,  0.0000e+00],
#         [-9.8571e-01,  0.0000e+00,  6.1970e+02, -7.9464e+01],
#         [ 9.8571e-01,  0.0000e+00, -7.9464e+01,  6.1970e+02]],
#        grad_fn=<SliceBackward>)
# example:
# tensor([[ 1.8736e-03,  1.9187e-04, -6.2805e+00,  6.2805e+00],
#         [ 1.9187e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-6.2805e+00,  0.0000e+00,  5.5992e+02, -5.0630e+02],
#         [ 6.2805e+00,  0.0000e+00, -5.0630e+02,  5.5992e+02]],
#        grad_fn=<SliceBackward>)
# tensor([[ 4.5865e-02,  1.9187e-04, -6.2805e+00,  6.2805e+00],
#         [ 1.9187e-04,  2.7530e+00,  0.0000e+00,  0.0000e+00],
#         [-6.2805e+00,  0.0000e+00,  3.9484e+03, -5.0630e+02],
#         [ 6.2805e+00,  0.0000e+00, -5.0630e+02,  3.9484e+03]],
#        grad_fn=<SliceBackward>)
# marginal
# tensor([[ 45959.8750, -11013.1143,  -5453.7715],
#         [-11013.1143,  30638.3477,  20825.7305],
#         [ -5453.7715,  20825.7305,  36197.6914]], grad_fn=<SliceBackward>)
# tensor([[  22511.0234,   -9857.9785,  -10730.6953],
#         [  -9857.9805, -144218.3281,  -98591.0156],
#         [ -10730.7012,  -98591.0000,  -90489.9531]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[  22511.0234,   -9857.9785,  -10730.6953],
#         [  -9857.9805, -144218.3281,  -98591.0156],
#         [ -10730.7012,  -98591.0000,  -90489.9531]], grad_fn=<SliceBackward>)
# tensor([[3092337.7500,   -9857.9795,  -10730.6953],
#         [  -9857.9805,   98899.6094,  -98591.0156],
#         [ -10730.7002,  -98591.0000,   98851.6719]], grad_fn=<SliceBackward>)
# guide:end
# model:begin tensor(6.3715) True
# model y tensor(6.3715) torch.Size([5, 3, 2]) tensor([[245.3193,  72.6807],
#         [161.4648, 160.5352]], grad_fn=<SliceBackward>)
# model:end
# scale tensor(6.6595)
# svi.step(... 14 tensor(6.6595)
# guide:begin tensor(6.6595) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(6.6595) True
# model y tensor(6.6595) torch.Size([5, 3, 2]) tensor([[152.5770, 156.4230],
#         [212.2683, 209.7317]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-31832.9609, grad_fn=<AddBackward0>) 361
# calc_lls
# rescaledSDDD torch.Size([8, 8])
# tensor([[ 3.3203e-04,  4.9375e-05, -9.8288e-01,  9.8288e-01],
#         [ 4.9375e-05,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-9.8288e-01,  0.0000e+00,  8.5722e+01, -7.7222e+01],
#         [ 9.8288e-01,  0.0000e+00, -7.7222e+01,  8.5722e+01]],
#        grad_fn=<SliceBackward>)
# tensor([[ 6.8990e-03,  4.9375e-05, -9.8288e-01,  9.8288e-01],
#         [ 4.9375e-05,  3.6552e-01,  0.0000e+00,  0.0000e+00],
#         [-9.8288e-01,  0.0000e+00,  5.7794e+02, -7.7222e+01],
#         [ 9.8288e-01,  0.0000e+00, -7.7222e+01,  5.7795e+02]],
#        grad_fn=<SliceBackward>)
# example:
# tensor([[ 2.2112e-03,  3.2882e-04, -6.5455e+00,  6.5455e+00],
#         [ 3.2882e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-6.5455e+00,  0.0000e+00,  5.7087e+02, -5.1426e+02],
#         [ 6.5455e+00,  0.0000e+00, -5.1426e+02,  5.7087e+02]],
#        grad_fn=<SliceBackward>)
# tensor([[ 4.5944e-02,  3.2882e-04, -6.5455e+00,  6.5455e+00],
#         [ 3.2882e-04,  2.4342e+00,  0.0000e+00,  0.0000e+00],
#         [-6.5455e+00,  0.0000e+00,  3.8488e+03, -5.1426e+02],
#         [ 6.5455e+00,  0.0000e+00, -5.1426e+02,  3.8488e+03]],
#        grad_fn=<SliceBackward>)
# marginal
# tensor([[ 45957.8203, -10138.4893,  -4973.8271],
#         [-10138.4893,  30608.8965,  20373.6934],
#         [ -4973.8271,  20373.6934,  35773.5586]], grad_fn=<SliceBackward>)
# tensor([[  21696.8203,  -10671.4150,  -14942.6260],
#         [ -10671.3945, -132237.3125,  -60866.8125],
#         [ -14942.6162,  -60866.8203,  -21769.0117]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[  21696.8203,  -10671.4150,  -14942.6260],
#         [ -10671.3945, -132237.3125,  -60866.8125],
#         [ -14942.6162,  -60866.8203,  -21769.0117]], grad_fn=<SliceBackward>)
# tensor([[3776863.7500,  -10671.4150,  -14942.6260],
#         [ -10671.3945,   61132.4688,  -60866.8125],
#         [ -14942.6162,  -60866.8203,   61051.0195]], grad_fn=<SliceBackward>)
# guide:end
# model:begin tensor(6.6595) True
# model y tensor(6.6595) torch.Size([5, 3, 2]) tensor([[ 74.5410, 234.4590],
#         [212.0555, 209.9445]], grad_fn=<SliceBackward>)
# model:end
# scale tensor(5.4732)
# svi.step(... 15 tensor(5.4732)
# guide:begin tensor(5.4732) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(5.4732) True
# model y tensor(5.4732) torch.Size([5, 3, 2]) tensor([[149.9511, 154.0489],
#         [262.2319, 259.7681]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-31828.1152, grad_fn=<AddBackward0>) 361
# calc_lls
# rescaledSDDD torch.Size([8, 8])
# tensor([[ 3.4235e-04,  5.4564e-05, -9.8148e-01,  9.8148e-01],
#         [ 5.4564e-05,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-9.8148e-01,  0.0000e+00,  8.4554e+01, -7.5970e+01],
#         [ 9.8148e-01,  0.0000e+00, -7.5970e+01,  8.4554e+01]],
#        grad_fn=<SliceBackward>)
# tensor([[ 6.5847e-03,  5.4564e-05, -9.8148e-01,  9.8148e-01],
#         [ 5.4564e-05,  3.2432e-01,  0.0000e+00,  0.0000e+00],
#         [-9.8148e-01,  0.0000e+00,  5.6503e+02, -7.5970e+01],
#         [ 9.8148e-01,  0.0000e+00, -7.5970e+01,  5.6503e+02]],
#        grad_fn=<SliceBackward>)
# example:
# tensor([[ 1.8738e-03,  2.9864e-04, -5.3718e+00,  5.3718e+00],
#         [ 2.9864e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-5.3718e+00,  0.0000e+00,  4.6278e+02, -4.1580e+02],
#         [ 5.3718e+00,  0.0000e+00, -4.1580e+02,  4.6278e+02]],
#        grad_fn=<SliceBackward>)
# tensor([[ 3.6039e-02,  2.9864e-04, -5.3718e+00,  5.3718e+00],
#         [ 2.9864e-04,  1.7751e+00,  0.0000e+00,  0.0000e+00],
#         [-5.3718e+00,  0.0000e+00,  3.0925e+03, -4.1580e+02],
#         [ 5.3718e+00,  0.0000e+00, -4.1580e+02,  3.0925e+03]],
#        grad_fn=<SliceBackward>)
# marginal
# tensor([[ 45949.4766, -13974.5664,  -6897.3984],
#         [-13974.5664,  30607.3672,  22290.9668],
#         [ -6897.3984,  22290.9668,  37684.5352]], grad_fn=<SliceBackward>)
# tensor([[ 20684.2812, -15320.6953, -16859.4531],
#         [-15320.6885, -94029.7891, -39401.5078],
#         [-16859.4492, -39401.5156, -10149.6406]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[ 20684.2812, -15320.6953, -16859.4531],
#         [-15320.6885, -94029.7891, -39401.5078],
#         [-16859.4492, -39401.5156, -10149.6406]], grad_fn=<SliceBackward>)
# tensor([[4632961.5000,  -15320.6953,  -16859.4531],
#         [ -15320.6885,   39641.5703,  -39401.5078],
#         [ -16859.4492,  -39401.5156,   39568.4258]], grad_fn=<SliceBackward>)
# guide:end
# model:begin tensor(5.4732) True
# model y tensor(5.4732) torch.Size([5, 3, 2]) tensor([[253.1736,  50.8264],
#         [262.3991, 259.6009]], grad_fn=<SliceBackward>)
# model:end
# scale tensor(5.6676)
# svi.step(... 16 tensor(5.6676)
# guide:begin tensor(5.6676) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(5.6676) True
# model y tensor(5.6676) torch.Size([5, 3, 2]) tensor([[151.8053, 151.1947],
#         [317.2200, 304.7800]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-31826.6973, grad_fn=<AddBackward0>) 361
# calc_lls
# rescaledSDDD torch.Size([8, 8])
# tensor([[ 3.6515e-04,  6.9373e-05, -9.7991e-01,  9.7991e-01],
#         [ 6.9373e-05,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-9.7991e-01,  0.0000e+00,  8.4407e+01, -7.5736e+01],
#         [ 9.7991e-01,  0.0000e+00, -7.5736e+01,  8.4407e+01]],
#        grad_fn=<SliceBackward>)
# tensor([[ 6.4917e-03,  6.9373e-05, -9.7991e-01,  9.7991e-01],
#         [ 6.9373e-05,  2.9536e-01,  0.0000e+00,  0.0000e+00],
#         [-9.7991e-01,  0.0000e+00,  5.4814e+02, -7.5736e+01],
#         [ 9.7991e-01,  0.0000e+00, -7.5736e+01,  5.4814e+02]],
#        grad_fn=<SliceBackward>)
# example:
# tensor([[ 2.0695e-03,  3.9317e-04, -5.5537e+00,  5.5537e+00],
#         [ 3.9317e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-5.5537e+00,  0.0000e+00,  4.7839e+02, -4.2924e+02],
#         [ 5.5537e+00,  0.0000e+00, -4.2924e+02,  4.7839e+02]],
#        grad_fn=<SliceBackward>)
# tensor([[ 3.6792e-02,  3.9317e-04, -5.5537e+00,  5.5537e+00],
#         [ 3.9317e-04,  1.6740e+00,  0.0000e+00,  0.0000e+00],
#         [-5.5537e+00,  0.0000e+00,  3.1066e+03, -4.2924e+02],
#         [ 5.5537e+00,  0.0000e+00, -4.2924e+02,  3.1066e+03]],
#        grad_fn=<SliceBackward>)
# marginal
# tensor([[ 45949.2109, -13255.7139,  -6569.6152],
#         [-13255.7139,  30628.6367,  21942.1758],
#         [ -6569.6152,  21942.1758,  37314.7344]], grad_fn=<SliceBackward>)
# tensor([[ 20568.0312, -13585.0205, -15876.4902],
#         [-13585.0186, -91329.5625, -38919.1289],
#         [-15876.4883, -38919.1250, -10345.5977]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[ 20568.0312, -13585.0205, -15876.4902],
#         [-13585.0186, -91329.5625, -38919.1289],
#         [-15876.4883, -38919.1250, -10345.5977]], grad_fn=<SliceBackward>)
# tensor([[4229637.5000,  -13585.0205,  -15876.4902],
#         [ -13585.0186,   39144.2266,  -38919.1289],
#         [ -15876.4883,  -38919.1250,   39079.2109]], grad_fn=<SliceBackward>)
# guide:end
# model:begin tensor(5.6676) True
# model y tensor(5.6676) torch.Size([5, 3, 2]) tensor([[ 59.8098, 243.1902],
#         [316.6427, 305.3573]], grad_fn=<SliceBackward>)
# model:end
# scale tensor(5.8762)
# svi.step(... 17 tensor(5.8762)
# guide:begin tensor(5.8762) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(5.8762) True
# model y tensor(5.8762) torch.Size([5, 3, 2]) tensor([[142.3835, 155.6165],
#         [351.4061, 370.5939]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-31823.9180, grad_fn=<AddBackward0>) 361
# calc_lls
# rescaledSDDD torch.Size([8, 8])
# tensor([[ 3.9015e-04,  7.6076e-05, -9.7817e-01,  9.7817e-01],
#         [ 7.6076e-05,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-9.7817e-01,  0.0000e+00,  8.3152e+01, -7.4394e+01],
#         [ 9.7817e-01,  0.0000e+00, -7.4394e+01,  8.3152e+01]],
#        grad_fn=<SliceBackward>)
# tensor([[ 6.5005e-03,  7.6076e-05, -9.7817e-01,  9.7817e-01],
#         [ 7.6076e-05,  2.7291e-01,  0.0000e+00,  0.0000e+00],
#         [-9.7817e-01,  0.0000e+00,  5.2721e+02, -7.4394e+01],
#         [ 9.7817e-01,  0.0000e+00, -7.4394e+01,  5.2721e+02]],
#        grad_fn=<SliceBackward>)
# example:
# tensor([[ 2.2926e-03,  4.4704e-04, -5.7480e+00,  5.7480e+00],
#         [ 4.4704e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-5.7480e+00,  0.0000e+00,  4.8862e+02, -4.3716e+02],
#         [ 5.7480e+00,  0.0000e+00, -4.3716e+02,  4.8862e+02]],
#        grad_fn=<SliceBackward>)
# tensor([[ 3.8198e-02,  4.4704e-04, -5.7480e+00,  5.7480e+00],
#         [ 4.4704e-04,  1.6037e+00,  0.0000e+00,  0.0000e+00],
#         [-5.7480e+00,  0.0000e+00,  3.0980e+03, -4.3716e+02],
#         [ 5.7480e+00,  0.0000e+00, -4.3716e+02,  3.0980e+03]],
#        grad_fn=<SliceBackward>)
# marginal
# tensor([[ 45947.9141, -12532.8438,  -6241.8984],
#         [-12532.8438,  30650.6035,  21591.7227],
#         [ -6241.8984,  21591.7227,  36941.5469]], grad_fn=<SliceBackward>)
# tensor([[ 20844.4746, -13007.0742, -15707.6152],
#         [-13007.0840, -96450.8047, -41771.3438],
#         [-15707.6240, -41771.3320, -11840.0234]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[ 20844.4746, -13007.0742, -15707.6152],
#         [-13007.0840, -96450.8047, -41771.3438],
#         [-15707.6240, -41771.3320, -11840.0234]], grad_fn=<SliceBackward>)
# tensor([[4150036.0000,  -13007.0742,  -15707.6152],
#         [ -13007.0850,   41999.7578,  -41771.3438],
#         [ -15707.6240,  -41771.3320,   41933.8633]], grad_fn=<SliceBackward>)
# guide:end
# model:begin tensor(5.8762) True
# model y tensor(5.8762) torch.Size([5, 3, 2]) tensor([[220.3617,  77.6383],
#         [353.0353, 368.9647]], grad_fn=<SliceBackward>)
# model:end
# scale tensor(6.1139)
# svi.step(... 18 tensor(6.1139)
# guide:begin tensor(6.1139) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(6.1139) True
# model y tensor(6.1139) torch.Size([5, 3, 2]) tensor([[159.1748, 163.8252],
#         [111.3573, 110.6427]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-31808.6641, grad_fn=<AddBackward0>) 361
# calc_lls
# rescaledSDDD torch.Size([8, 8])
# tensor([[ 1.0316e-03,  7.3517e-04, -9.7461e-01,  9.7461e-01],
#         [ 7.3517e-04,  4.3877e-04,  1.5607e-02, -1.5607e-02],
#         [-9.7461e-01,  1.5607e-02,  8.9551e+01, -8.0705e+01],
#         [ 9.7461e-01, -1.5607e-02, -8.0705e+01,  8.9551e+01]],
#        grad_fn=<SliceBackward>)
# tensor([[ 1.8022e-02,  7.3517e-04, -9.7461e-01,  9.7461e-01],
#         [ 7.3517e-04,  1.2422e-02,  1.5607e-02, -1.5607e-02],
#         [-9.7461e-01,  1.5607e-02,  3.7604e+02, -8.0705e+01],
#         [ 9.7461e-01, -1.5607e-02, -8.0705e+01,  3.7604e+02]],
#        grad_fn=<SliceBackward>)
# example:
# tensor([[ 6.3069e-03,  4.4947e-03, -5.9586e+00,  5.9586e+00],
#         [ 4.4947e-03,  2.6826e-03,  9.5416e-02, -9.5416e-02],
#         [-5.9586e+00,  9.5416e-02,  5.4750e+02, -4.9342e+02],
#         [ 5.9586e+00, -9.5416e-02, -4.9342e+02,  5.4750e+02]],
#        grad_fn=<SliceBackward>)
# tensor([[ 1.1018e-01,  4.4947e-03, -5.9586e+00,  5.9586e+00],
#         [ 4.4947e-03,  7.5948e-02,  9.5416e-02, -9.5416e-02],
#         [-5.9586e+00,  9.5416e-02,  2.2991e+03, -4.9342e+02],
#         [ 5.9586e+00, -9.5416e-02, -4.9342e+02,  2.2991e+03]],
#        grad_fn=<SliceBackward>)
# marginal
# tensor([[ 45936.5625, -11832.1592,  -5876.9121],
#         [-11832.1592,  30633.6289,  21232.8945],
#         [ -5876.9121,  21232.8945,  36588.8750]], grad_fn=<SliceBackward>)
# tensor([[ 21098.6914, -10734.6777, -11995.2256],
#         [-10734.6738, -79983.4844, -43575.3242],
#         [-11995.2188, -43575.3164, -26304.2461]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[ 21098.6914, -10734.6777, -11995.2256],
#         [-10734.6738, -79983.4844, -43575.3242],
#         [-11995.2188, -43575.3164, -26304.2461]], grad_fn=<SliceBackward>)
# tensor([[3305083.5000,  -10734.6768,  -11995.2246],
#         [ -10734.6738,   43772.8906,  -43575.3242],
#         [ -11995.2188,  -43575.3164,   43727.8789]], grad_fn=<SliceBackward>)
# guide:end
# model:begin tensor(6.1139) True
# model y tensor(6.1139) torch.Size([5, 3, 2]) tensor([[178.9592, 144.0408],
#         [139.7699,  82.2301]], grad_fn=<SliceBackward>)
# model:end
# scale tensor(6.3715)
# svi.step(... 19 tensor(6.3715)
# guide:begin tensor(6.3715) True
# ...
#         [ 4.5065e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-6.5459e+00,  0.0000e+00,  5.7806e+02, -5.1424e+02],
#         [ 6.5459e+00,  0.0000e+00, -5.1424e+02,  5.7806e+02]],
#        grad_fn=<SliceBackward>)
# tensor([[ 4.6693e-02,  4.5065e-04, -6.5459e+00,  6.5459e+00],
#         [ 4.5065e-04,  2.4294e+00,  0.0000e+00,  0.0000e+00],
#         [-6.5459e+00,  0.0000e+00,  3.7967e+03, -5.1424e+02],
#         [ 6.5459e+00,  0.0000e+00, -5.1424e+02,  3.7967e+03]],
#        grad_fn=<SliceBackward>)
# marginal
# tensor([[ 45957.0469, -10139.0977,  -4974.1465],
#         [-10139.0977,  30612.7578,  20375.9277],
#         [ -4974.1465,  20375.9277,  35777.7109]], grad_fn=<SliceBackward>)
# tensor([[  22698.7773,   -8669.9785,  -10537.8779],
#         [  -8669.9717, -127501.9922,  -80742.0859],
#         [ -10537.8750,  -80742.0781,  -63388.8125]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[  22698.7773,   -8669.9785,  -10537.8779],
#         [  -8669.9717, -127501.9922,  -80742.0859],
#         [ -10537.8750,  -80742.0781,  -63388.8125]], grad_fn=<SliceBackward>)
# tensor([[2896953.7500,   -8669.9785,  -10537.8779],
#         [  -8669.9717,   81007.9297,  -80742.0859],
#         [ -10537.8740,  -80742.0781,   80956.2344]], grad_fn=<SliceBackward>)
# guide:end
# model:begin tensor(6.6595) True
# model y tensor(6.6595) torch.Size([5, 3, 2]) tensor([[258.0259,  50.9741],
#         [212.7235, 209.2765]], grad_fn=<SliceBackward>)
# model:end
# scale tensor(5.4732)
# svi.step(... 27 tensor(5.4732)
# guide:begin tensor(5.4732) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(5.4732) True
# model y tensor(5.4732) torch.Size([5, 3, 2]) tensor([[150.4033, 153.5967],
#         [262.6202, 259.3798]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-31818.6543, grad_fn=<AddBackward0>) 361
# calc_lls
# rescaledSDDD torch.Size([8, 8])
# tensor([[ 2.7548e-04,  3.0164e-05, -9.8444e-01,  9.8444e-01],
#         [ 3.0164e-05,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-9.8444e-01,  0.0000e+00,  8.5656e+01, -7.5976e+01],
#         [ 9.8444e-01,  0.0000e+00, -7.5976e+01,  8.5656e+01]],
#        grad_fn=<SliceBackward>)
# tensor([[ 5.8986e-03,  3.0164e-05, -9.8444e-01,  9.8444e-01],
#         [ 3.0164e-05,  3.2244e-01,  0.0000e+00,  0.0000e+00],
#         [-9.8444e-01,  0.0000e+00,  6.2624e+02, -7.5976e+01],
#         [ 9.8444e-01,  0.0000e+00, -7.5976e+01,  6.2624e+02]],
#        grad_fn=<SliceBackward>)
# example:
# tensor([[ 1.5077e-03,  1.6510e-04, -5.3880e+00,  5.3880e+00],
#         [ 1.6510e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-5.3880e+00,  0.0000e+00,  4.6881e+02, -4.1583e+02],
#         [ 5.3880e+00,  0.0000e+00, -4.1583e+02,  4.6881e+02]],
#        grad_fn=<SliceBackward>)
# tensor([[ 3.2284e-02,  1.6510e-04, -5.3880e+00,  5.3880e+00],
#         [ 1.6510e-04,  1.7648e+00,  0.0000e+00,  0.0000e+00],
#         [-5.3880e+00,  0.0000e+00,  3.4275e+03, -4.1583e+02],
#         [ 5.3880e+00,  0.0000e+00, -4.1583e+02,  3.4275e+03]],
#        grad_fn=<SliceBackward>)
# marginal
# tensor([[ 45950.5156, -13973.0244,  -6896.7725],
#         [-13973.0244,  30612.5605,  22292.7930],
#         [ -6896.7725,  22292.7930,  37688.8125]], grad_fn=<SliceBackward>)
# tensor([[  21328.7969,  -17167.4629,  -18124.7715],
#         [ -17167.4648, -128014.5000,  -55488.4961],
#         [ -18124.7734,  -55488.5039,  -17585.5898]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[  21328.7969,  -17167.4629,  -18124.7715],
#         [ -17167.4648, -128014.5000,  -55488.4961],
#         [ -18124.7734,  -55488.5039,  -17585.5898]], grad_fn=<SliceBackward>)
# tensor([[5159538.0000,  -17167.4629,  -18124.7715],
#         [ -17167.4648,   55789.6875,  -55488.4961],
#         [ -18124.7734,  -55488.5039,   55685.8320]], grad_fn=<SliceBackward>)
# guide:end
# model:begin tensor(5.4732) True
# model y tensor(5.4732) torch.Size([5, 3, 2]) tensor([[ 64.5085, 239.4915],
#         [261.9152, 260.0848]], grad_fn=<SliceBackward>)
# model:end
# scale tensor(5.6676)
# svi.step(... 28 tensor(5.6676)
# guide:begin tensor(5.6676) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(5.6676) True
# model y tensor(5.6676) torch.Size([5, 3, 2]) tensor([[152.7326, 150.2674],
#         [318.7181, 303.2819]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-31817.6230, grad_fn=<AddBackward0>) 361
# calc_lls
# rescaledSDDD torch.Size([8, 8])
# tensor([[ 2.2376e-04,  5.7678e-06, -9.8590e-01,  9.8590e-01],
#         [ 5.7678e-06,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-9.8590e-01,  0.0000e+00,  8.5523e+01, -7.5746e+01],
#         [ 9.8590e-01,  0.0000e+00, -7.5746e+01,  8.5523e+01]],
#        grad_fn=<SliceBackward>)
# tensor([[ 5.0943e-03,  5.7678e-06, -9.8590e-01,  9.8590e-01],
#         [ 5.7678e-06,  2.9201e-01,  0.0000e+00,  0.0000e+00],
#         [-9.8590e-01,  0.0000e+00,  6.8664e+02, -7.5746e+01],
#         [ 9.8590e-01,  0.0000e+00, -7.5746e+01,  6.8664e+02]],
#        grad_fn=<SliceBackward>)
# example:
# tensor([[ 1.2682e-03,  3.2689e-05, -5.5876e+00,  5.5876e+00],
#         [ 3.2689e-05,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-5.5876e+00,  0.0000e+00,  4.8471e+02, -4.2930e+02],
#         [ 5.5876e+00,  0.0000e+00, -4.2930e+02,  4.8471e+02]],
#        grad_fn=<SliceBackward>)
# tensor([[ 2.8872e-02,  3.2689e-05, -5.5876e+00,  5.5876e+00],
#         [ 3.2689e-05,  1.6550e+00,  0.0000e+00,  0.0000e+00],
#         [-5.5876e+00,  0.0000e+00,  3.8916e+03, -4.2930e+02],
#         [ 5.5876e+00,  0.0000e+00, -4.2930e+02,  3.8916e+03]],
#        grad_fn=<SliceBackward>)
# marginal
# tensor([[ 45952.3516, -13252.3916,  -6567.5742],
#         [-13252.3916,  30634.9219,  21943.6562],
#         [ -6567.5742,  21943.6562,  37319.7422]], grad_fn=<SliceBackward>)
# tensor([[  22053.4570,  -17221.1738,  -18402.7383],
#         [ -17221.1719, -176993.2031,  -79992.3281],
#         [ -18402.7324,  -79992.3281,  -29611.0234]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[  22053.4570,  -17221.1738,  -18402.7383],
#         [ -17221.1719, -176993.2031,  -79992.3281],
#         [ -18402.7324,  -79992.3281,  -29611.0234]], grad_fn=<SliceBackward>)
# tensor([[5295762.0000,  -17221.1738,  -18402.7383],
#         [ -17221.1719,   80365.4219,  -79992.3281],
#         [ -18402.7324,  -79992.3281,   80226.0000]], grad_fn=<SliceBackward>)
# guide:end
# model:begin tensor(5.6676) True
# model y tensor(5.6676) torch.Size([5, 3, 2]) tensor([[ 88.4091, 214.5909],
#         [317.2397, 304.7603]], grad_fn=<SliceBackward>)
# model:end
# scale tensor(5.8762)
# svi.step(... 29 tensor(5.8762)
# guide:begin tensor(5.8762) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(5.8762) True
# model y tensor(5.8762) torch.Size([5, 3, 2]) tensor([[143.7399, 154.2601],
#         [354.2636, 367.7364]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-31814.5605, grad_fn=<AddBackward0>) 361
# calc_lls
# rescaledSDDD torch.Size([8, 8])
# tensor([[ 1.7080e-04, -2.7482e-05, -9.8749e-01,  9.8749e-01],
#         [-2.7482e-05,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-9.8749e-01,  0.0000e+00,  8.4318e+01, -7.4443e+01],
#         [ 9.8749e-01,  0.0000e+00, -7.4443e+01,  8.4318e+01]],
#        grad_fn=<SliceBackward>)
# tensor([[ 4.3352e-03, -2.7482e-05, -9.8749e-01,  9.8749e-01],
#         [-2.7482e-05,  2.7159e-01,  0.0000e+00,  0.0000e+00],
#         [-9.8749e-01,  0.0000e+00,  7.6972e+02, -7.4443e+01],
#         [ 9.8749e-01,  0.0000e+00, -7.4443e+01,  7.6972e+02]],
#        grad_fn=<SliceBackward>)
# example:
# tensor([[ 1.0037e-03, -1.6149e-04, -5.8027e+00,  5.8027e+00],
#         [-1.6149e-04,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#         [-5.8027e+00,  0.0000e+00,  4.9547e+02, -4.3745e+02],
#         [ 5.8027e+00,  0.0000e+00, -4.3745e+02,  4.9547e+02]],
#        grad_fn=<SliceBackward>)
# tensor([[ 2.5474e-02, -1.6149e-04, -5.8027e+00,  5.8027e+00],
#         [-1.6149e-04,  1.5959e+00,  0.0000e+00,  0.0000e+00],
#         [-5.8027e+00,  0.0000e+00,  4.5231e+03, -4.3745e+02],
#         [ 5.8027e+00,  0.0000e+00, -4.3745e+02,  4.5231e+03]],
#        grad_fn=<SliceBackward>)
# marginal
# tensor([[ 45952.4688, -12527.5664,  -6238.2881],
#         [-12527.5664,  30657.4844,  21592.5254],
#         [ -6238.2881,  21592.5254,  36946.7617]], grad_fn=<SliceBackward>)
# tensor([[  23360.9082,  -19113.2852,  -19799.7754],
#         [ -19113.2852, -279481.8125, -130376.1328],
#         [ -19799.7734, -130376.1328,  -53947.2617]], grad_fn=<SliceBackward>)
# rescaledSDDD torch.Size([3, 3])
# tensor([[  23360.9082,  -19113.2852,  -19799.7754],
#         [ -19113.2852, -279481.8125, -130376.1328],
#         [ -19799.7734, -130376.1328,  -53947.2617]], grad_fn=<SliceBackward>)
# tensor([[5953712.5000,  -19113.2852,  -19799.7754],
#         [ -19113.2852,  130911.1875, -130376.1328],
#         [ -19799.7715, -130376.1328,  130690.1406]], grad_fn=<SliceBackward>)
# guide:end
# model:begin tensor(5.8762) True
# model y tensor(5.8762) torch.Size([5, 3, 2]) tensor([[ 14.4037, 283.5963],
#         [352.2849, 369.7151]], grad_fn=<SliceBackward>)
# model:end
# scale tensor(6.1139)
# svi.step(... 30 tensor(6.1139)
# guide:begin tensor(6.1139) True
# sizes [torch.Size([1]), torch.Size([2, 1]), torch.Size([2]), torch.Size([3, 2])]
# model:begin tensor(6.1139) True
# model y tensor(6.1139) torch.Size([5, 3, 2]) tensor([[159.9272, 163.0728],
#         [111.7589, 110.2411]], grad_fn=<SliceBackward>)
# model:end
# lp:  tensor(-31799.7637, grad_fn=<AddBackward0>) 361
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-dbb8170092b2> in <module>
#       5 import cProfile as profile
#       6
# ----> 7 get_ipython().run_line_magic('prun', 'result = trainGuide()')
#
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2312                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2313             with self.builtin_trap:
# -> 2314                 result = fn(*args, **kwargs)
#    2315             return result
#    2316
#
# </anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-55> in prun(self, parameter_s, cell)
#
# /anaconda3/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /anaconda3/lib/python3.7/site-packages/IPython/core/magics/execution.py in prun(self, parameter_s, cell)
#     315             arg_str += '\n' + cell
#     316         arg_str = self.shell.transform_cell(arg_str)
# --> 317         return self._run_with_profiler(arg_str, opts, self.shell.user_ns)
#     318
#     319     def _run_with_profiler(self, code, opts, namespace):
#
# /anaconda3/lib/python3.7/site-packages/IPython/core/magics/execution.py in _run_with_profiler(self, code, opts, namespace)
#     337         prof = profile.Profile()
#     338         try:
# --> 339             prof = prof.runctx(code, namespace, namespace)
#     340             sys_exit = ''
#     341         except SystemExit:
#
# /anaconda3/lib/python3.7/cProfile.py in runctx(self, cmd, globals, locals)
#      98         self.enable()
#      99         try:
# --> 100             exec(cmd, globals, locals)
#     101         finally:
#     102             self.disable()
#
# <string> in <module>
#
# ~/Dropbox/eipython/eipython/ei2.py in trainGuide()
#     616         subset, scale = get_subset(processed_data,SUBSET_SIZE,i)
#     617         print("svi.step(...",i,scale)
# --> 618         loss = svi.step(subset,scale,True,do_print=(i % 10 == 0))
#     619         losses.append(loss)
#     620         if i % 10 == 0:
#
# /anaconda3/lib/python3.7/site-packages/pyro/infer/svi.py in step(self, *args, **kwargs)
#      96         # get loss and compute gradients
#      97         with poutine.trace(param_only=True) as param_capture:
# ---> 98             loss = self.loss_and_grads(self.model, self.guide, *args, **kwargs)
#      99
#     100         params = set(site["value"].unconstrained()
#
# /anaconda3/lib/python3.7/site-packages/pyro/infer/trace_elbo.py in loss_and_grads(self, model, guide, *args, **kwargs)
#     121         loss = 0.0
#     122         # grab a trace from the generator
# --> 123         for model_trace, guide_trace in self._get_traces(model, guide, *args, **kwargs):
#     124             loss_particle, surrogate_loss_particle = self._differentiable_loss_particle(model_trace, guide_trace)
#     125             loss += loss_particle / self.num_particles
#
# /anaconda3/lib/python3.7/site-packages/pyro/infer/elbo.py in _get_traces(self, model, guide, *args, **kwargs)
#     165         else:
#     166             for i in range(self.num_particles):
# --> 167                 yield self._get_trace(model, guide, *args, **kwargs)
#
# /anaconda3/lib/python3.7/site-packages/pyro/infer/trace_elbo.py in _get_trace(self, model, guide, *args, **kwargs)
#      48         """
#      49         model_trace, guide_trace = get_importance_trace(
# ---> 50             "flat", self.max_plate_nesting, model, guide, *args, **kwargs)
#      51         if is_validation_enabled():
#      52             check_if_enumerated(guide_trace)
#
# /anaconda3/lib/python3.7/site-packages/pyro/infer/enum.py in get_importance_trace(graph_type, max_plate_nesting, model, guide, *args, **kwargs)
#      38     against it.
#      39     """
# ---> 40     guide_trace = poutine.trace(guide, graph_type=graph_type).get_trace(*args, **kwargs)
#      41     model_trace = poutine.trace(poutine.replay(model, trace=guide_trace),
#      42                                 graph_type=graph_type).get_trace(*args, **kwargs)
#
# /anaconda3/lib/python3.7/site-packages/pyro/poutine/trace_messenger.py in get_trace(self, *args, **kwargs)
#     161         Calls this poutine and returns its trace instead of the function's return value.
#     162         """
# --> 163         self(*args, **kwargs)
#     164         return self.msngr.get_trace()
#
# /anaconda3/lib/python3.7/site-packages/pyro/poutine/trace_messenger.py in __call__(self, *args, **kwargs)
#     141                                       args=args, kwargs=kwargs)
#     142             try:
# --> 143                 ret = self.fn(*args, **kwargs)
#     144             except (ValueError, RuntimeError):
#     145                 exc_type, exc_value, traceback = sys.exc_info()
#
# ~/Dropbox/eipython/eipython/ei2.py in guide(data, scale, include_nuisance, do_print)
#     397                     len(gamma_star_data), #tensors, not elements=gamma_dims
#     398                     tensors_per_unit,
# --> 399                     return_grad=True)
#     400
#     401
#
# ~/Dropbox/eipython/eipython/utilities/myhessian.py in arrowhead_hessian_precision(output_raw, inputs, headsize, blocksize, allow_unused, create_graph, return_grad)
#     270             if elem.requires_grad:
#     271                 #print(f"arrow {i},{maxi},{headsize},{blocksize}")
# --> 272                 row = gradient(elem, unitTensors, retain_graph=True, create_graph=True)
#     273             else:
#     274                 row = elem.new_zeros(sum(x.numel() for x in unitTensors))
#
# /anaconda3/lib/python3.7/site-packages/hessian-0.0.0-py3.7.egg/hessian/gradient.py in gradient(outputs, inputs, grad_outputs, retain_graph, create_graph)
#      20                                 allow_unused=True,
#      21                                 retain_graph=retain_graph,
# ---> 22                                 create_graph=create_graph)
#      23     grads = [x if x is not None else torch.zeros_like(y) for x, y in zip(grads, inputs)]
#      24     return torch.cat([x.contiguous().view(-1) for x in grads])
#
# /anaconda3/lib/python3.7/site-packages/torch/autograd/__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused)
#     147     return Variable._execution_engine.run_backward(
#     148         outputs, grad_outputs, retain_graph, create_graph,
# --> 149         inputs, allow_unused)
#     150
#     151
#
# KeyboardInterrupt:

# %% [markdown]
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# .
#
# Now, "toypyro", a minimal model to narrow in on and reproduce any bugs.

# %%
from importlib import reload
import demo #import *
reload(demo)
from demo import *
import cProfile as profile


result = trainGuide()
# Out:
# epoch 0 loss = 9970.42696261406
# epoch 10 loss = 8222.381203889847
# epoch 20 loss = 60.06933152675629
# epoch 30 loss = 1137.6531113386154
# epoch 40 loss = 1467.7961308956146
# epoch 50 loss = 503.1370403766632
# epoch 60 loss = 5752.136534690857
# epoch 70 loss = 1244.33548527956
# epoch 80 loss = 8540.950506448746
# epoch 90 loss = 569.7613765001297
# epoch 100 loss = 6894.649996995926
# epoch 110 loss = 4175.3235194683075
# epoch 120 loss = 472.6241273880005
# epoch 130 loss = 1902.5091660022736
# epoch 140 loss = 913.3949070572853
# epoch 150 loss = 120.05118358135223
# epoch 160 loss = 24.606423556804657
# epoch 170 loss = 110.1393538415432
# epoch 180 loss = 74.07718658447266
# epoch 190 loss = 5440.085318565369
# epoch 200 loss = 516.0992064476013
# epoch 210 loss = 593.9815967679024
# epoch 220 loss = 344.73766988515854
# epoch 230 loss = 933.6469010710716
# epoch 240 loss = 190.28482508659363
# epoch 250 loss = 852.1514495611191
# epoch 260 loss = 223.10303181409836
# epoch 270 loss = 1054.054571211338
# epoch 280 loss = 67.37258738279343
# epoch 290 loss = 425.1358232498169
# epoch 300 loss = 1052.9819769859314
# epoch 310 loss = 1674.3172267079353
# epoch 320 loss = 434.36263167858124
# epoch 330 loss = 371.0104421377182
# epoch 340 loss = 534.7153202295303
# epoch 350 loss = 76.14917385578156
# epoch 360 loss = 1898.6710789203644
# epoch 370 loss = 190.43798637390137
# epoch 380 loss = 499.90254777669907
# epoch 390 loss = 227.2196364402771
# epoch 400 loss = 549.3110811710358
# epoch 410 loss = 840.1415543556213
# epoch 420 loss = 187.75638806819916
# epoch 430 loss = 8.163513362407684
# epoch 440 loss = 36.8250629901886
# epoch 450 loss = 282.2171347141266
# epoch 460 loss = 88.93707716464996
# epoch 470 loss = -8.457634627819061
# epoch 480 loss = 415.9394348859787
# epoch 490 loss = 27.139925122261047
# epoch 500 loss = 238.95548915863037
# epoch 510 loss = 308.2312113046646
# epoch 520 loss = -13.960336089134216
# epoch 530 loss = 211.98778748512268
# epoch 540 loss = 214.59208965301514
# epoch 550 loss = 434.7178844213486
# epoch 560 loss = 216.3488790988922
# epoch 570 loss = 1302.4268074035645
# epoch 580 loss = 156.7089728116989
# epoch 590 loss = 215.6293957233429
# epoch 600 loss = 417.47256302833557
# epoch 610 loss = 323.62663531303406
# epoch 620 loss = 898.4031736850739
# epoch 630 loss = 69.56500446796417
# epoch 640 loss = -21.20420789718628
# epoch 650 loss = -14.589676976203918
# epoch 660 loss = 32.44058358669281
# epoch 670 loss = 18.092478275299072
# epoch 680 loss = -8.768603086471558
# epoch 690 loss = 0.3066471815109253
# epoch 700 loss = -17.7206848859787
# epoch 710 loss = 10.318970441818237
# epoch 720 loss = 27.703640580177307
# epoch 730 loss = -8.549628853797913
# epoch 740 loss = 97.89159786701202
# epoch 750 loss = -23.435295581817627
# epoch 760 loss = 80.2417802810669
# epoch 770 loss = 191.0366222858429
# epoch 780 loss = 1.0039712190628052
# epoch 790 loss = -14.158635020256042
# epoch 800 loss = 101.04626989364624
# epoch 810 loss = -4.6242356300354
# epoch 820 loss = 67.7615761756897
# epoch 830 loss = 204.67140352725983
# epoch 840 loss = 24.472697854042053
# epoch 850 loss = -9.110898852348328
# epoch 860 loss = -10.40952980518341
# epoch 870 loss = 12.897611021995544
# epoch 880 loss = 81.61308634281158
# epoch 890 loss = -16.697559475898743
# epoch 900 loss = 10.683896660804749
# epoch 910 loss = 58.94023394584656
# epoch 920 loss = -20.48142147064209
# epoch 930 loss = 36.798425793647766
# epoch 940 loss = -4.461576581001282
# epoch 950 loss = 32.648712038993835
# epoch 960 loss = -20.80633819103241
# epoch 970 loss = 13.59885823726654
# epoch 980 loss = 27.542380213737488
# epoch 990 loss = -20.179308533668518
# epoch 1000 loss = -19.005021929740906
# epoch 1010 loss = -18.2170547246933
# epoch 1020 loss = -19.43075668811798
# epoch 1030 loss = -4.924235939979553
# epoch 1040 loss = -21.92120921611786
# epoch 1050 loss = 16.83372700214386
# epoch 1060 loss = -11.871260285377502
# epoch 1070 loss = -10.325113654136658
# epoch 1080 loss = -18.82685911655426
# epoch 1090 loss = 10.077147364616394
# epoch 1100 loss = -27.32503378391266
# epoch 1110 loss = -5.696203827857971
# epoch 1120 loss = -13.577538132667542
# epoch 1130 loss = -19.523112654685974
# epoch 1140 loss = -12.977255702018738
# epoch 1150 loss = -23.81832444667816
# epoch 1160 loss = -16.85115420818329
# epoch 1170 loss = -6.799846529960632
# epoch 1180 loss = -20.49998939037323
# epoch 1190 loss = -15.655739068984985
# epoch 1200 loss = -9.904370427131653
# epoch 1210 loss = -29.566373586654663
# epoch 1220 loss = 5.4111088514328
# epoch 1230 loss = -28.05242884159088
# epoch 1240 loss = -21.681487321853638
# epoch 1250 loss = -13.319893598556519
# epoch 1260 loss = -12.41371762752533
# epoch 1270 loss = -21.702600359916687
# epoch 1280 loss = -22.059823989868164
# epoch 1290 loss = -25.3575279712677
# epoch 1300 loss = -26.640719413757324
# epoch 1310 loss = -24.549542903900146
# epoch 1320 loss = -19.065369606018066
# epoch 1330 loss = -19.86486268043518
# epoch 1340 loss = -20.076615929603577
# epoch 1350 loss = -26.849024534225464
# epoch 1360 loss = -22.73797631263733
# epoch 1370 loss = -19.59937858581543
# epoch 1380 loss = -28.688270330429077
# epoch 1390 loss = -25.230886578559875
# epoch 1400 loss = -19.165393352508545
# epoch 1410 loss = -21.86486506462097
# epoch 1420 loss = -17.583155870437622
# epoch 1430 loss = -18.787638187408447
# epoch 1440 loss = -21.011450052261353
# epoch 1450 loss = -22.13494110107422
# epoch 1460 loss = -13.651560068130493
# epoch 1470 loss = -21.351763010025024
# epoch 1480 loss = -20.056892037391663
# epoch 1490 loss = -15.752094388008118
# epoch 1500 loss = -26.150632858276367
# epoch 1510 loss = -30.08116364479065
# epoch 1520 loss = -13.490179896354675
# epoch 1530 loss = -11.820260643959045
# epoch 1540 loss = -27.708999156951904
# epoch 1550 loss = -21.760513305664062
# epoch 1560 loss = -25.024082899093628
# epoch 1570 loss = -30.239800810813904
# epoch 1580 loss = -24.265573501586914
# epoch 1590 loss = -12.849509716033936
# epoch 1600 loss = -21.990947246551514
# epoch 1610 loss = -25.473822593688965
# epoch 1620 loss = -21.74608302116394
# epoch 1630 loss = -29.68125820159912
# epoch 1640 loss = -16.449406623840332
# epoch 1650 loss = -22.486225843429565
# epoch 1660 loss = -21.300263166427612
# epoch 1670 loss = -23.194011330604553
# epoch 1680 loss = -20.318111419677734
# epoch 1690 loss = -25.038808345794678
# epoch 1700 loss = -23.52825403213501
# epoch 1710 loss = -11.93352997303009
# epoch 1720 loss = -20.955570459365845
# epoch 1730 loss = -24.713982343673706
# epoch 1740 loss = -22.206504344940186
# epoch 1750 loss = -18.968297481536865
# epoch 1760 loss = -27.074164748191833
# epoch 1770 loss = -21.310234308242798
# epoch 1780 loss = -21.19845724105835
# epoch 1790 loss = -24.367520809173584
# epoch 1800 loss = -26.015806794166565
# epoch 1810 loss = -23.054303884506226
# epoch 1820 loss = -25.64688992500305
# epoch 1830 loss = -13.319884181022644
# epoch 1840 loss = -17.32163166999817
# epoch 1850 loss = -23.7455712556839
# epoch 1860 loss = -25.545387268066406
# epoch 1870 loss = -27.497881412506104
# epoch 1880 loss = -24.89391028881073
# epoch 1890 loss = -24.854057788848877
# epoch 1900 loss = -23.371911883354187
# epoch 1910 loss = -26.387003779411316
# epoch 1920 loss = -22.207335233688354
# epoch 1930 loss = -22.02166199684143
# epoch 1940 loss = -23.83713984489441
# epoch 1950 loss = -25.31385374069214
# epoch 1960 loss = -16.196258068084717
# epoch 1970 loss = -22.292989253997803
# epoch 1980 loss = -23.85995388031006
# epoch 1990 loss = -28.101629972457886
# epoch 2000 loss = -22.794631123542786
# epoch 2010 loss = -22.766714811325073
# epoch 2020 loss = -25.436706066131592
# epoch 2030 loss = -25.03978204727173
# epoch 2040 loss = -26.8535076379776
# epoch 2050 loss = -22.176397800445557
# epoch 2060 loss = -16.28916573524475
# epoch 2070 loss = -19.07245898246765
# epoch 2080 loss = -22.417195081710815
# epoch 2090 loss = -29.459009885787964
# epoch 2100 loss = -15.73995041847229
# epoch 2110 loss = -21.550569772720337
# epoch 2120 loss = -19.20262575149536
# epoch 2130 loss = -25.475621461868286
# epoch 2140 loss = -25.69290542602539
# epoch 2150 loss = -26.19874334335327
# epoch 2160 loss = -25.563206911087036
# epoch 2170 loss = -27.548903465270996
# epoch 2180 loss = -22.519362926483154
# epoch 2190 loss = -20.045663595199585
# epoch 2200 loss = -22.438573360443115
# epoch 2210 loss = -25.288503170013428
# epoch 2220 loss = -21.962993383407593
# epoch 2230 loss = -16.933046579360962
# epoch 2240 loss = -19.901620388031006
# epoch 2250 loss = -15.773172616958618
# epoch 2260 loss = -16.03392219543457
# epoch 2270 loss = -27.897440671920776
# epoch 2280 loss = -20.802294731140137
# epoch 2290 loss = -24.83900547027588
# epoch 2300 loss = -30.2585289478302
# epoch 2310 loss = -20.315150022506714
# epoch 2320 loss = -22.15317392349243
# epoch 2330 loss = -25.159435987472534
# epoch 2340 loss = -20.672945022583008
# epoch 2350 loss = -23.544315814971924
# epoch 2360 loss = -21.54719305038452
# epoch 2370 loss = -22.543355226516724
# epoch 2380 loss = -23.42118239402771
# epoch 2390 loss = -21.949904322624207
# epoch 2400 loss = -31.188451051712036
# epoch 2410 loss = -18.388630628585815
# epoch 2420 loss = -18.03581702709198
# epoch 2430 loss = -27.299959778785706
# epoch 2440 loss = -27.348795413970947
# epoch 2450 loss = -21.49933934211731
# epoch 2460 loss = -24.72176694869995
# epoch 2470 loss = -20.447677612304688
# epoch 2480 loss = -27.689104080200195
# epoch 2490 loss = -24.22283685207367
# epoch 2500 loss = -22.203494548797607
# epoch 2510 loss = -19.911522388458252
# epoch 2520 loss = -22.637953996658325
# epoch 2530 loss = -18.87294626235962
# epoch 2540 loss = -31.51684594154358
# epoch 2550 loss = -21.241424798965454
# epoch 2560 loss = -18.018275499343872
# epoch 2570 loss = -20.61366891860962
# epoch 2580 loss = -26.1727454662323
# epoch 2590 loss = -20.367342233657837
# epoch 2600 loss = -21.66036605834961
# epoch 2610 loss = -20.375153064727783
# epoch 2620 loss = -28.787466764450073
# epoch 2630 loss = -26.659034252166748
# epoch 2640 loss = -27.07300877571106
# epoch 2650 loss = -20.351962089538574
# epoch 2660 loss = -21.9063138961792
# epoch 2670 loss = -21.56492280960083
# epoch 2680 loss = -27.147707223892212
# epoch 2690 loss = -23.924439072608948
# epoch 2700 loss = -21.84794807434082
# epoch 2710 loss = -25.21865200996399
# epoch 2720 loss = -23.206295013427734
# epoch 2730 loss = -31.85695791244507
# epoch 2740 loss = -21.257530689239502
# epoch 2750 loss = -16.897451639175415
# epoch 2760 loss = -17.47722029685974
# epoch 2770 loss = -20.478862285614014
# epoch 2780 loss = -27.533504486083984
# epoch 2790 loss = -23.544565200805664
# epoch 2800 loss = -17.046606063842773
# epoch 2810 loss = -25.670005321502686
# epoch 2820 loss = -25.69626784324646
# epoch 2830 loss = -27.408512592315674
# epoch 2840 loss = -24.09447407722473
# epoch 2850 loss = -15.136472463607788
# epoch 2860 loss = -18.049262523651123
# epoch 2870 loss = -19.774412989616394
# epoch 2880 loss = -20.50040626525879
# epoch 2890 loss = -25.857336282730103
# epoch 2900 loss = -18.43021249771118
# epoch 2910 loss = -21.843361854553223
# epoch 2920 loss = -21.852466821670532
# epoch 2930 loss = -25.457306385040283
# epoch 2940 loss = -35.21738600730896
# epoch 2950 loss = -17.756343126296997
# epoch 2960 loss = -17.89638376235962
# epoch 2970 loss = -22.20802640914917
# epoch 2980 loss = -17.484975576400757
# epoch 2990 loss = -20.95511245727539
# epoch 3000 loss = -15.643475770950317
# logScaleHat:
# -3.4726879596710205
# logTailHat:
# 0.29934072494506836
# meanHat:
# -0.034671951085329056
# meanSig:
# 0.015605974942445755
# truthHat:
# tensor([-0.0286, -0.0322, -0.0375, -0.0357, -0.0525, -0.0504, -0.0500, -0.0541,
#         -0.0367, -0.0450, -0.0574, -0.0379, -0.0411, -0.0153, -0.0267, -0.0459,
#         -0.0555, -0.0385, -0.0429, -0.0377, -0.0214, -0.0371, -0.0546, -0.0285,
#         -0.0435, -0.0514, -0.0516, -0.0364, -0.0439, -0.0525, -0.0455, -0.0388,
#         -0.0331, -0.0612, -0.0482, -0.0386, -0.0361, -0.0341, -0.0338, -0.0455,
#         -0.0555, -0.0040, -0.0210, -0.0291], requires_grad=True)
# truthRho:
# 0.008846916258335114
# truthSEmult:
# 0.28036901354789734

# %% [markdown]
# Next, run "polytopize", which has all of my pre-Fritz attempts to code.

# %%
import torch
ts = torch.tensor
import pyro.distributions as dist
import pyro
import cmult

t1 = ts([3.,4.])
t2 = ts([2.,5.])

m = t1.view(-1,1).mm(t1.view(1,-1))

print(m)

#means = torch.zeros(3,2)
#means[1,1] = 100.
with pyro.plate('dumb',3):
    #t3 = pyro.sample('irrelevant',dist.Normal(means,ts(1.)).to_event(1))
    t3 = pyro.sample('irrelevant',cmult.CMult(50,torch.ones(3,3,3)/3).to_event(2))

#print(t3)

mult = cmult.CMult(50,torch.ones(3)/3)
print(mult.log_prob(ts([0.,50,0])))
print(mult.log_prob(ts([0.,1,0])))
# Out:
# tensor([[ 9., 12.],
#         [12., 16.]])
# tensor(-54.9306)
# tensor(-1.0986)

# %%
yhat1 = polytopize(4,3,pyro.get_param_store()["what_0"],
                 get_indep(4,3,ts([68.,20,25,56]),ts([63.,32,74])))

erchat = pyro.get_param_store()["erchat"]

print(pyro.get_param_store()["what_0"])
print(erchat)
print(recenter_rc(erchat))
print(pyro.get_param_store()["logsdrchat"])
# Out:
# tensor([[-0.3764, -0.7578],
#         [-0.0823,  0.0420],
#         [ 0.0860,  0.2053]], requires_grad=True)
# tensor([[-0.0440, -0.0448,  0.1284],
#         [-0.0490, -0.0334,  0.1120],
#         [-0.0486, -0.0243,  0.0850],
#         [-0.0567, -0.0134,  0.0715]], requires_grad=True)
# tensor([[ 0.0031, -0.0173,  0.0341],
#         [-0.0019, -0.0059,  0.0177],
#         [-0.0015,  0.0032, -0.0093],
#         [-0.0096,  0.0141, -0.0227]], grad_fn=<SubBackward0>)
# tensor(-3.1610, requires_grad=True)

# %% [markdown]
# # Testing hessian transparency

# %%
import torch
ts = torch.tensor
os = torch.ones
zs = torch.zeros
from importlib import reload
import myhessian
reload(myhessian)

t1 = os(2,2,requires_grad=True)
r = torch.sum(t1 * t1 * t1)

h = myhessian.hessian(r,t1)
print("hess",h)
r2 = torch.sum(h * h)
[r3] = torch.autograd.grad(r,t1,create_graph=True,retain_graph=True)
print("d ",r3)
print("Σd ",torch.sum(r3))
[r4] = torch.autograd.grad(torch.sum(r3),t1,create_graph=True,retain_graph=True)
print("dΣdΣd ",torch.autograd.grad(torch.sum(r4),t1,create_graph=True,retain_graph=True))
print(torch.autograd.grad(r2,t1))
# Out:
# hess tensor([[6., 0., 0., 0.],
#         [0., 6., 0., 0.],
#         [0., 0., 6., 0.],
#         [0., 0., 0., 6.]], grad_fn=<CopySlices>)
# d  tensor([[3., 3.],
#         [3., 3.]], grad_fn=<AddBackward0>)
# Σd  tensor(12., grad_fn=<SumBackward0>)
# dΣdΣd  (tensor([[6., 6.],
#         [6., 6.]]),)
# (tensor([[72., 72.],
#         [72., 72.]]),)

# %%
import sys
import hessian

from importlib import reload
import polytopize #import *
reload(polytopize)
from polytopize import *

import tests
# Out:
# Yes, I will run.
# Yes, I will run.
# ge fail
# loc tensor([[ 0.3147],
#         [ 2.4440],
#         [-4.0535],
#         [ 2.2007]])
# polytopedLoc tensor([[ 2.1063e-01,  2.1136e-02],
#         [ 2.8514e-01, -1.8626e-09],
#         [ 3.4959e-01,  9.9957e-02],
#         [ 3.5462e-01,  1.1892e-02],
#         [ 2.5462e+00,  3.2228e-01]])
# ge fail
# loc tensor([[-5.8855],
#         [-5.2805],
#         [ 5.4654],
#         [ 0.1889]])
# polytopedLoc tensor([[ 2.8885e-01,  1.1871e+00],
#         [ 8.5629e-01,  2.0505e+00],
#         [ 3.9984e-01, -1.4901e-08],
#         [ 9.5542e-01,  1.5538e+00],
#         [ 1.0063e+00,  9.9522e-01]])
# Reloading cmult...
# callable? <bound method TorchDistributionMixin.__call__ of Multinomial()>
# callable? <bound method TorchDistributionMixin.__call__ of TorchCMult()>
# Sampling multinomial: tensor([1., 2.])
# Sampling cm2: tensor([0., 3.])
# tensor(5.6022, grad_fn=<NegBackward>) tensor([[112.2500]])

# %% [markdown]
# # Test rank1torch (to get yhat from pi,n,v)

# %%
from importlib import reload
import rank1torch #import *
reload(rank1torch)
from rank1torch import *

test_solver()
# Out:
# Testing optimize_Q (50 tests):
# R=3, C=5, tolerance=0.001
# ==================================================
# Oh no! In test 3, Q has some negative entries:
# 	 trueQ[2][4]=0.00010659269901225343,
# 	     Q[2][4]=-0.00021605131041724235
# Oh no! In test 5, Q has some negative entries:
# 	 trueQ[1][4]=0.00011974151857430115,
# 	     Q[1][4]=-1.1631345842033625e-06
# Oh no! In test 8, Q has some negative entries:
# 	 trueQ[0][1]=2.882161788875237e-05,
# 	     Q[0][1]=-0.0004783869662787765
# Oh no! In test 15, Q has some negative entries:
# 	 trueQ[2][3]=0.0007846675580367446,
# 	     Q[2][3]=-6.166117964312434e-05
# Oh no! In test 28, Q has some negative entries:
# 	 trueQ[0][4]=8.13114020274952e-05,
# 	     Q[0][4]=-0.00018321917741559446
# Oh no! In test 40, Q has some negative entries:
# 	 trueQ[2][3]=0.00032634526723995805,
# 	     Q[2][3]=-0.000617634505033493
# Oh no! In test 47, Q has some negative entries:
# 	 trueQ[2][1]=0.00017936740186996758,
# 	     Q[2][1]=-0.00041433278238400817
# Oh no! In test 48, Q has some negative entries:
# 	 trueQ[0][0]=4.524858377408236e-05,
# 	     Q[0][0]=-0.0006647921400144696
#
# Cumulative results for the 50 tests
# (R=3, C=5, tolerance=0.001):
# -------------------------------------------
# Worst error in entry of Q: 0.0019194334745407104
#
# To get within tolerance, it took us:
# 002 iterations: ***** 5.0 times
# 003 iterations: ********** 10.0 times
# 004 iterations: *********** 11.0 times
# 005 iterations: ****** 6.0 times
# 006 iterations: **** 4.0 times
# 007 iterations: **** 4.0 times
# 008 iterations: ****** 6.0 times
# 010 iterations: *** 3.0 times
# 013 iterations: * 1.0 times

# %% [markdown]
# Finally, this is a cell for directly experimenting with pytorch and/or pyro. Basically, for getting the tensor syntax right.

# %%
import torch
import cmult
import pyro
from importlib import reload
reload(cmult)
from cmult import CMult

#print(CMult(probs=torch.tensor([1., 1., 1., 1.])).log_prob(torch.tensor([1.2, 1.5, 1., 1.])))

#print(CMult(100, torch.tensor([ 1., 1., 1., 1.])).sample())

R, C = (3,4)

y = pyro.distributions.Normal(0.,4.).sample(torch.Size([R-1,C-1]))


w = torch.cat((y,-y.sum(1).unsqueeze(1)),1)
w = torch.cat((w,-w.sum(0).unsqueeze(0)),0)

#print(w)
b = w.argmax()
print(b)
print(w,w[b//C,b % C])

tt = torch.zeros(R,C)
print(tt,R,C,tt[:(R-1),:(C-1)])

# %% [markdown]
# ## Overview
#
# Most SVI problems in pyro are coded as a model, a generic guide (such as: multivariate Gaussian in all parameters), and specific observations/data (passed as arguments to svi.step). For EI, that's going to be different; the observations are going to be built into the guide function, leaving nothing to include in the "data" argument to svi.step.
#
# That means there is a lot of work for the guide to do. As usual, it must establish reasonable distributional families for the posterior of each of the hyperparameters. But for the latent parameters, the job of the guide is to take a "relative strength" number for each race/candidate/precinct combo, and turn that into a number of votes for each combo, such that those numbers obey all the constraints set by observations. This means that for each precinct (considered separately), the latent guide must:
#
# -Find the "center point" where candidate preference is independent of race.
#
# -Find the "basis vectors" (actually, there are more than enough of them to form a basis) which determine the directions to move in the space.
#
# -For any given set of "relative strengths" which is a distance $d$ in a direction $\theta$, find the first constraint violated when moving in that direction, and the distance $r$ between the origin and that constraint.
#
# -Project the "relative strengths" onto the numbers of votes, by moving $r(1-e^{-d})$ in direction $\theta$.

# %% [markdown]
# #### a = zs(2,2,2,2)
# a[0,1,1,1] = 2
# print(a[1,1])
# print(a[0,1])
# print(torch.max(a))
# print(torch.distributions.exponential.Exponential(ts([1])).sample(4))

# %%
print("hi","world")
a = zs(2,2,2,2)
a[0,1,1,1] = 2 
print(torch.max(a[0,1])) 
print(pyro.distributions.Exponential(1.).sample(torch.Size([3])))
a.add_(torch.ones(2,2,2))
print(torch.exp)
