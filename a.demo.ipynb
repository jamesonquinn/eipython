# %% [markdown]
# # Quick intro
#
# One pair of ts, with pictures:

# %%
from importlib import reload
import twoT #import *
reload(twoT)
from twoT import *
import cProfile as profile

#vals = MIDDF35
guidenames = ["laplace","meanfield"]#,"MLE"]
if True:

    for aniter in range(1):
        
        
        for nparticles in [1]:#,5]:
                for vals in [LOWDF0,LOWDFM,LOWDFP,MIDDFP,HIDF0,HIDFP]:
                    #

                    print(aniter,nparticles,guidenames,)
                    result = trainGuides(guidenames,nparticles,vals,filebase="testresults/demo_amortized_laplace")
                    print(aniter,nparticles,guidenames)
                    for line in range(10):
                        print()
                    
else:
    plt.plot([getMLE(.01 + x/100,1.,0,1.) for x in range(500)])
# Out:
# 0 1 ['laplace', 'meanfield']
# laplace vals OrderedDict([('obs', tensor(0.)), ('df', tensor(2.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 0.9636330604553223;
# epoch 100 loss = 1.7359328269958496;
# epoch 200 loss = 2.180041790008545;
# epoch 300 loss = 1.8115259408950806;
# epoch 400 loss = 2.0111188888549805;
# epoch 500 loss = 1.8957527875900269;
# epoch 600 loss = 1.81148362159729;
# eff_hat:
# tensor([ 0.1725, -0.0343], requires_grad=True)
# psi:
# tensor([0.0183, 0.0176], grad_fn=<AddBackward0>)
# mean_loss: 1.6596159293915524
# meanfield vals OrderedDict([('obs', tensor(0.)), ('df', tensor(2.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 10.868061065673828;
# epoch 100 loss = 5.208637118339539;
# epoch 200 loss = 2.781868815422058;
# epoch 300 loss = 1.2493135333061218;
# epoch 400 loss = 1.383462905883789;
# epoch 500 loss = 0.05153161287307739;
# epoch 600 loss = 3.0010021328926086;
# epoch 700 loss = 3.811059534549713;
# epoch 800 loss = 1.9777496457099915;
# epoch 900 loss = 2.7787196040153503;
# epoch 1000 loss = 1.5434611439704895;
# epoch 1100 loss = 2.2454671263694763;
# epoch 1200 loss = 2.9971007108688354;
# epoch 1300 loss = 1.9096896648406982;
# epoch 1400 loss = 2.256395697593689;
# epoch 1500 loss = 2.387739658355713;
# epoch 1600 loss = 1.6846145987510681;
# epoch 1700 loss = 2.8033722639083862;
# epoch 1800 loss = 1.8126968741416931;
# epoch 1900 loss = 3.2505634427070618;
# epoch 2000 loss = 2.4156822562217712;
# epoch 2100 loss = 1.961604118347168;
# epoch 2200 loss = 2.096834897994995;
# epoch 2300 loss = 2.853636622428894;
# epoch 2400 loss = 1.9749298691749573;
# epoch 2500 loss = 1.1364775598049164;
# epoch 2600 loss = 0.7297510504722595;
# eff_hat:
# tensor([0.0817, 0.0670], requires_grad=True)
# sig:
# tensor([0.3706, 0.2690], grad_fn=<AddBackward0>)
# mean_loss: 2.5259505685069508
# max tensor([-2.0830], grad_fn=<AddBackward0>)
# KLdivs
# sample: 100%|████████████████████████████████| 1050/1050 [00:04<00:00, 222.24it/s, step size=5.79e-01, acc. prob=0.643]
#                 mean       std    median     25.0%     75.0%     n_eff     r_hat
# effects[0]     -0.07      0.75     -0.07     -0.56      0.30    185.53      1.00
# effects[1]      0.07      0.76      0.08     -0.31      0.56    166.93      1.00
#
#
# KLdivs testresults/demo_amortized_laplace.fitted.csv torch.Size([1000, 2])
# 0 1 ['laplace', 'meanfield']
#
#
#
#
#
#
#
#
#
#
# 0 1 ['laplace', 'meanfield']
# laplace vals OrderedDict([('obs', tensor(3.)), ('df', tensor(2.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 16.530412197113037;
# epoch 100 loss = 1.3006236553192139;
# epoch 200 loss = 2.8698136806488037;
# epoch 300 loss = 2.6913354992866516;
# epoch 400 loss = 2.6543455719947815;
# epoch 500 loss = 3.095806121826172;
# epoch 600 loss = 3.128820538520813;
# epoch 700 loss = 2.8592464923858643;
# epoch 800 loss = 3.144948720932007;
# epoch 900 loss = 2.7656179070472717;
# epoch 1000 loss = 2.4287582635879517;
# epoch 1100 loss = 2.920805513858795;
# epoch 1200 loss = 3.8988248109817505;
# epoch 1300 loss = 4.2768625020980835;
# epoch 1400 loss = 2.7364394068717957;
# epoch 1500 loss = 3.9206206798553467;
# epoch 1600 loss = 3.231695830821991;
# epoch 1700 loss = 3.014880061149597;
# epoch 1800 loss = 3.402374744415283;
# epoch 1900 loss = 2.8129196166992188;
# epoch 2000 loss = 2.5473597049713135;
# epoch 2100 loss = 3.7929173409938812;
# epoch 2200 loss = 3.453556478023529;
# epoch 2300 loss = 2.8226255774497986;
# epoch 2400 loss = 2.6596771478652954;
# eff_hat:
# tensor([1.4864, 1.3822], requires_grad=True)
# psi:
# tensor([0.0390, 0.0714], grad_fn=<AddBackward0>)
# mean_loss: 3.105969284873548
# meanfield vals OrderedDict([('obs', tensor(3.)), ('df', tensor(2.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 26.5936861038208;
# epoch 100 loss = 3.9354962408542633;
# epoch 200 loss = 4.591604828834534;
# epoch 300 loss = 4.350673019886017;
# epoch 400 loss = 4.290747761726379;
# epoch 500 loss = 2.812734842300415;
# epoch 600 loss = 3.99741131067276;
# epoch 700 loss = 4.060411095619202;
# epoch 800 loss = 3.751889407634735;
# epoch 900 loss = 4.685402035713196;
# epoch 1000 loss = 4.229618668556213;
# epoch 1100 loss = 4.940620541572571;
# epoch 1200 loss = 11.223374366760254;
# epoch 1300 loss = 3.365600883960724;
# epoch 1400 loss = 4.176389753818512;
# epoch 1500 loss = 3.7131527066230774;
# epoch 1600 loss = 4.369802832603455;
# epoch 1700 loss = 4.927840530872345;
# epoch 1800 loss = 4.415974676609039;
# epoch 1900 loss = 4.037509799003601;
# epoch 2000 loss = 1.861344337463379;
# epoch 2100 loss = 4.438625514507294;
# epoch 2200 loss = 4.712053179740906;
# epoch 2300 loss = 4.879880666732788;
# epoch 2400 loss = 3.1697068214416504;
# epoch 2500 loss = 5.287231922149658;
# eff_hat:
# tensor([1.4208, 1.4910], requires_grad=True)
# sig:
# tensor([0.3241, 0.2524], grad_fn=<AddBackward0>)
# mean_loss: 4.5543223385035745
# max tensor([-4.2534], grad_fn=<AddBackward0>)
# KLdivs
# sample: 100%|█████████████████████████████████| 1050/1050 [00:16<00:00, 62.04it/s, step size=1.56e-01, acc. prob=0.977]
#                 mean       std    median     25.0%     75.0%     n_eff     r_hat
# effects[0]      1.30      1.27      1.15      0.03      1.68    171.79      1.01
# effects[1]      1.56      1.28      1.61      0.96      2.65    186.49      1.01
#
#
# KLdivs testresults/demo_amortized_laplace.fitted.csv torch.Size([1000, 2])
# 0 1 ['laplace', 'meanfield']
#
#
#
#
#
#
#
#
#
#
# 0 1 ['laplace', 'meanfield']
# laplace vals OrderedDict([('obs', tensor(7.)), ('df', tensor(2.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 161.22091341018677;
# epoch 100 loss = 6.89273464679718;
# epoch 200 loss = 5.879998564720154;
# epoch 300 loss = 5.63787579536438;
# epoch 400 loss = 4.242991089820862;
# epoch 500 loss = 4.426238596439362;
# epoch 600 loss = 5.80749785900116;
# epoch 700 loss = 3.962967872619629;
# epoch 800 loss = 5.216671645641327;
# epoch 900 loss = 4.813596844673157;
# epoch 1000 loss = 5.356595516204834;
# epoch 1100 loss = 6.473368883132935;
# epoch 1200 loss = 4.623905181884766;
# epoch 1300 loss = 7.815218448638916;
# epoch 1400 loss = 6.513238430023193;
# epoch 1500 loss = 5.215121030807495;
# epoch 1600 loss = 6.9057958126068115;
# epoch 1700 loss = 5.546969175338745;
# epoch 1800 loss = 5.350637912750244;
# epoch 1900 loss = 4.881509780883789;
# epoch 2000 loss = 5.560583591461182;
# epoch 2100 loss = 6.173521399497986;
# epoch 2200 loss = 5.818684875965118;
# epoch 2300 loss = 4.459055006504059;
# epoch 2400 loss = 5.227785527706146;
# epoch 2500 loss = 4.561504006385803;
# epoch 2600 loss = 6.000110387802124;
# epoch 2700 loss = 5.625594526529312;
# epoch 2800 loss = 4.619912803173065;
# epoch 2900 loss = 6.087575793266296;
# epoch 3000 loss = 5.964524447917938;
# eff_hat:
# tensor([3.4071, 3.5276], requires_grad=True)
# psi:
# tensor([0.0229, 0.0123], grad_fn=<AddBackward0>)
# mean_loss: 5.396613205767367
# meanfield vals OrderedDict([('obs', tensor(7.)), ('df', tensor(2.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 144.86632752418518;
# epoch 100 loss = 7.097714364528656;
# epoch 200 loss = 7.546949148178101;
# epoch 300 loss = 6.051462650299072;
# epoch 400 loss = 6.523915708065033;
# epoch 500 loss = 6.653438627719879;
# epoch 600 loss = 6.92015153169632;
# epoch 700 loss = 6.147492945194244;
# epoch 800 loss = 7.329335927963257;
# epoch 900 loss = 7.661791145801544;
# epoch 1000 loss = 6.757811665534973;
# epoch 1100 loss = 6.404221892356873;
# epoch 1200 loss = 5.793721675872803;
# epoch 1300 loss = 5.740090072154999;
# epoch 1400 loss = 6.338353276252747;
# epoch 1500 loss = 5.347405195236206;
# epoch 1600 loss = 6.130810797214508;
# epoch 1700 loss = 7.203851878643036;
# epoch 1800 loss = 7.423727989196777;
# epoch 1900 loss = 10.630982160568237;
# epoch 2000 loss = 7.415477275848389;
# epoch 2100 loss = 7.288662016391754;
# epoch 2200 loss = 6.945664167404175;
# epoch 2300 loss = 6.4573668241500854;
# epoch 2400 loss = 10.347209215164185;
# epoch 2500 loss = 7.315256476402283;
# epoch 2600 loss = 6.721181213855743;
# epoch 2700 loss = 6.944208920001984;
# epoch 2800 loss = 6.910342514514923;
# epoch 2900 loss = 8.62616902589798;
# eff_hat:
# tensor([0.3204, 6.5692], requires_grad=True)
# sig:
# tensor([0.2972, 0.3810], grad_fn=<AddBackward0>)
# mean_loss: 7.229951398404471
# max tensor([-6.8653], grad_fn=<AddBackward0>)
# KLdivs
# sample: 100%|█████████████████████████████████| 1050/1050 [00:10<00:00, 99.72it/s, step size=9.82e-02, acc. prob=0.874]
#                 mean       std    median     25.0%     75.0%     n_eff     r_hat
# effects[0]      3.80      3.20      4.29      2.72      7.50     41.11      1.00
# effects[1]      3.14      3.21      2.55     -0.79      3.71     40.75      1.00
#
#
# KLdivs testresults/demo_amortized_laplace.fitted.csv torch.Size([1000, 2])
# 0 1 ['laplace', 'meanfield']
#
#
#
#
#
#
#
#
#
#
# 0 1 ['laplace', 'meanfield']
# laplace vals OrderedDict([('obs', tensor(4.)), ('df', tensor(5.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 40.639318227767944;
# epoch 100 loss = 2.1810598969459534;
# epoch 200 loss = 4.304805517196655;
# epoch 300 loss = 3.7818199396133423;
# epoch 400 loss = 3.4596887826919556;
# epoch 500 loss = 3.616652488708496;
# epoch 600 loss = 3.075850784778595;
# epoch 700 loss = 3.9176833629608154;
# epoch 800 loss = 5.089375972747803;
# epoch 900 loss = 3.6512980461120605;
# epoch 1000 loss = 4.089858055114746;
# epoch 1100 loss = 5.2636895179748535;
# epoch 1200 loss = 3.8316010236740112;
# epoch 1300 loss = 4.155180215835571;
# epoch 1400 loss = 4.397407293319702;
# epoch 1500 loss = 5.4289937019348145;
# epoch 1600 loss = 4.433335363864899;
# epoch 1700 loss = 5.268096446990967;
# epoch 1800 loss = 4.187796950340271;
# epoch 1900 loss = 3.513862669467926;
# epoch 2000 loss = 4.569210708141327;
# epoch 2100 loss = 3.8107287883758545;
# epoch 2200 loss = 3.988607406616211;
# epoch 2300 loss = 3.561253786087036;
# epoch 2400 loss = 4.725037455558777;
# epoch 2500 loss = 4.857093274593353;
# epoch 2600 loss = 4.351434797048569;
# epoch 2700 loss = 3.893160820007324;
# epoch 2800 loss = 3.992939829826355;
# epoch 2900 loss = 3.771851658821106;
# epoch 3000 loss = 3.8676172494888306;
# eff_hat:
# tensor([1.8283, 2.1377], requires_grad=True)
# psi:
# tensor([0.0503, 0.0014], grad_fn=<AddBackward0>)
# mean_loss: 4.1560857666111675
# meanfield vals OrderedDict([('obs', tensor(4.)), ('df', tensor(5.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 62.590094208717346;
# epoch 100 loss = 5.009020745754242;
# epoch 200 loss = 6.114228367805481;
# epoch 300 loss = 5.2229167222976685;
# epoch 400 loss = 5.6542298793792725;
# epoch 500 loss = 5.558918535709381;
# epoch 600 loss = 3.580362379550934;
# epoch 700 loss = 5.462742567062378;
# epoch 800 loss = 3.993237614631653;
# epoch 900 loss = 5.757278084754944;
# epoch 1000 loss = 5.325265109539032;
# epoch 1100 loss = 5.287859797477722;
# epoch 1200 loss = 5.587158977985382;
# epoch 1300 loss = 5.824092507362366;
# epoch 1400 loss = 6.604424357414246;
# epoch 1500 loss = 6.038645565509796;
# epoch 1600 loss = 6.26776784658432;
# epoch 1700 loss = 5.851628482341766;
# epoch 1800 loss = 2.854808211326599;
# epoch 1900 loss = 5.507843613624573;
# epoch 2000 loss = 5.322094678878784;
# epoch 2100 loss = 5.089593410491943;
# epoch 2200 loss = 5.093392729759216;
# epoch 2300 loss = 4.785328149795532;
# epoch 2400 loss = 6.298490345478058;
# epoch 2500 loss = 4.116266131401062;
# epoch 2600 loss = 6.12449312210083;
# epoch 2700 loss = 4.794579565525055;
# epoch 2800 loss = 4.973162889480591;
# epoch 2900 loss = 4.301764249801636;
# epoch 3000 loss = 5.452668011188507;
# eff_hat:
# tensor([1.8119, 1.8194], requires_grad=True)
# sig:
# tensor([0.3988, 0.4437], grad_fn=<AddBackward0>)
# mean_loss: 5.581585811281414
# max tensor([-5.3253], grad_fn=<AddBackward0>)
# KLdivs
# sample: 100%|████████████████████████████████| 1050/1050 [00:10<00:00, 102.93it/s, step size=3.75e-01, acc. prob=0.933]
#                 mean       std    median     25.0%     75.0%     n_eff     r_hat
# effects[0]      1.91      1.43      1.89      0.72      2.81    154.38      1.00
# effects[1]      1.94      1.44      1.91      1.41      3.56    148.58      1.00
#
#
# KLdivs testresults/demo_amortized_laplace.fitted.csv torch.Size([1000, 2])
# 0 1 ['laplace', 'meanfield']
#
#
#
#
#
#
#
#
#
#
# 0 1 ['laplace', 'meanfield']
# laplace vals OrderedDict([('obs', tensor(0.)), ('df', tensor(30.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 11.779757738113403;
# epoch 100 loss = 1.4122772216796875;
# epoch 200 loss = 0.5157275199890137;
# epoch 300 loss = 2.04044109582901;
# epoch 400 loss = 1.9591374397277832;
# epoch 500 loss = 1.620349109172821;
# epoch 600 loss = 1.3341783285140991;
# epoch 700 loss = 0.8999028205871582;
# epoch 800 loss = 1.124360978603363;
# epoch 900 loss = 2.054124116897583;
# epoch 1000 loss = 1.3416109681129456;
# epoch 1100 loss = 1.869182050228119;
# epoch 1200 loss = 1.068052887916565;
# epoch 1300 loss = 1.6205153465270996;
# epoch 1400 loss = 1.1526122689247131;
# epoch 1500 loss = 2.879456043243408;
# epoch 1600 loss = 1.5367741584777832;
# epoch 1700 loss = 1.3286514282226562;
# epoch 1800 loss = 1.4483957886695862;
# epoch 1900 loss = 1.7079226970672607;
# epoch 2000 loss = 1.4637233018875122;
# epoch 2100 loss = 1.0830938220024109;
# epoch 2200 loss = 3.1455256938934326;
# epoch 2300 loss = 0.9410867691040039;
# epoch 2400 loss = 1.2049647867679596;
# epoch 2500 loss = 1.1276702880859375;
# epoch 2600 loss = 0.9059388041496277;
# epoch 2700 loss = 1.6804233193397522;
# epoch 2800 loss = 1.4183849692344666;
# epoch 2900 loss = 1.2287795543670654;
# epoch 3000 loss = 1.4478653073310852;
# eff_hat:
# tensor([-0.0275, -0.0380], requires_grad=True)
# psi:
# tensor([0.0087, 0.0085], grad_fn=<AddBackward0>)
# mean_loss: 1.452987447914418
# meanfield vals OrderedDict([('obs', tensor(0.)), ('df', tensor(30.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 6.521759748458862;
# epoch 100 loss = 2.246265470981598;
# epoch 200 loss = 1.7312995791435242;
# epoch 300 loss = 2.3262544870376587;
# epoch 400 loss = 2.9496549367904663;
# epoch 500 loss = 1.5568377375602722;
# epoch 600 loss = 2.3775642216205597;
# epoch 700 loss = 2.0892982482910156;
# epoch 800 loss = 2.3741608262062073;
# epoch 900 loss = 5.889057874679565;
# epoch 1000 loss = 0.8620960712432861;
# epoch 1100 loss = 1.9301000237464905;
# epoch 1200 loss = 2.4891810417175293;
# epoch 1300 loss = 2.379136621952057;
# epoch 1400 loss = 1.4086840152740479;
# epoch 1500 loss = 3.566583752632141;
# epoch 1600 loss = 1.6840338706970215;
# epoch 1700 loss = 1.4951294660568237;
# epoch 1800 loss = 1.4824697375297546;
# epoch 1900 loss = 2.490079164505005;
# epoch 2000 loss = 2.6282671093940735;
# eff_hat:
# tensor([0.0107, 0.0581], requires_grad=True)
# sig:
# tensor([0.2639, 0.3022], grad_fn=<AddBackward0>)
# mean_loss: 2.2982999359532057
# max tensor([-1.8578], grad_fn=<AddBackward0>)
# KLdivs
# sample: 100%|████████████████████████████████| 1050/1050 [00:09<00:00, 109.90it/s, step size=2.21e-01, acc. prob=0.962]
#                 mean       std    median     25.0%     75.0%     n_eff     r_hat
# effects[0]      0.03      0.68      0.09     -0.37      0.53    230.07      1.00
# effects[1]     -0.03      0.68     -0.04     -0.57      0.30    211.89      1.00
#
#
# KLdivs testresults/demo_amortized_laplace.fitted.csv torch.Size([1000, 2])
# 0 1 ['laplace', 'meanfield']
#
#
#
#
#
#
#
#
#
#
# 0 1 ['laplace', 'meanfield']
# laplace vals OrderedDict([('obs', tensor(3.)), ('df', tensor(30.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 25.93789315223694;
# epoch 100 loss = 3.6790934205055237;
# epoch 200 loss = 3.0322042107582092;
# epoch 300 loss = 3.364732325077057;
# epoch 400 loss = 3.194660246372223;
# epoch 500 loss = 3.0656065940856934;
# epoch 600 loss = 3.605570614337921;
# epoch 700 loss = 3.5831785202026367;
# epoch 800 loss = 4.0000521540641785;
# epoch 900 loss = 2.6703855991363525;
# epoch 1000 loss = 3.1215046644210815;
# epoch 1100 loss = 3.4215630292892456;
# epoch 1200 loss = 3.40244323015213;
# epoch 1300 loss = 4.481929302215576;
# epoch 1400 loss = 2.2433326840400696;
# epoch 1500 loss = 3.653831422328949;
# epoch 1600 loss = 3.335180878639221;
# epoch 1700 loss = 3.672703742980957;
# epoch 1800 loss = 2.758844494819641;
# epoch 1900 loss = 3.2880491614341736;
# epoch 2000 loss = 3.7906293869018555;
# epoch 2100 loss = 3.1960902214050293;
# epoch 2200 loss = 3.197446823120117;
# epoch 2300 loss = 3.483944296836853;
# epoch 2400 loss = 3.369956135749817;
# epoch 2500 loss = 3.8217612504959106;
# epoch 2600 loss = 2.8953170776367188;
# epoch 2700 loss = 3.265066146850586;
# epoch 2800 loss = 3.1767407059669495;
# epoch 2900 loss = 3.4535282254219055;
# epoch 3000 loss = 4.877570390701294;
# eff_hat:
# tensor([1.1451, 1.4924], requires_grad=True)
# psi:
# tensor([0.0047, 0.0060], grad_fn=<AddBackward0>)
# mean_loss: 3.432206819594053
# meanfield vals OrderedDict([('obs', tensor(3.)), ('df', tensor(30.)), ('sig', tensor(0.4000)), ('assymmetry', 2.0)])
# epoch 0 loss = 53.0392050743103;
# epoch 100 loss = 3.957865834236145;
# epoch 200 loss = 3.9574897289276123;
# epoch 300 loss = 4.533994138240814;
# epoch 400 loss = 3.250217616558075;
# epoch 500 loss = 5.461906254291534;
# epoch 600 loss = 4.293791055679321;
# epoch 700 loss = 3.556204080581665;
# epoch 800 loss = 3.8659669756889343;
# epoch 900 loss = 5.498614847660065;
# epoch 1000 loss = 2.7849926948547363;
# epoch 1100 loss = 4.099358081817627;
# epoch 1200 loss = 4.227285802364349;
# epoch 1300 loss = 4.180960178375244;
# epoch 1400 loss = 4.083131194114685;
# epoch 1500 loss = 4.224640309810638;
# epoch 1600 loss = 3.7637560963630676;
# epoch 1700 loss = 3.553331136703491;
# epoch 1800 loss = 4.402702689170837;
# epoch 1900 loss = 6.080278396606445;
# epoch 2000 loss = 4.8556095361709595;
# epoch 2100 loss = 4.144464671611786;
# epoch 2200 loss = 3.35939621925354;
# epoch 2300 loss = 3.3976197242736816;
# epoch 2400 loss = 5.181836843490601;
# epoch 2500 loss = 4.548625826835632;
# epoch 2600 loss = 3.2639718055725098;
# epoch 2700 loss = 5.005032032728195;
# epoch 2800 loss = 3.570392370223999;
# eff_hat:
# tensor([1.4749, 1.5616], requires_grad=True)
# sig:
# tensor([0.3293, 0.3445], grad_fn=<AddBackward0>)
# mean_loss: 4.372695577488792
# max tensor([-3.9437], grad_fn=<AddBackward0>)
# KLdivs
# sample: 100%|████████████████████████████████| 1050/1050 [00:04<00:00, 222.46it/s, step size=9.06e-01, acc. prob=0.694]
#                 mean       std    median     25.0%     75.0%     n_eff     r_hat
# effects[0]      1.44      0.73      1.46      1.08      1.98    195.16      1.00
# effects[1]      1.36      0.74      1.34      0.82      1.78    205.02      1.00
#
#
# KLdivs testresults/demo_amortized_laplace.fitted.csv torch.Size([1000, 2])
# 0 1 ['laplace', 'meanfield']

# %% [markdown]
# playing with twoT: MCMC?

# %%
from importlib import reload
import twoT #import *
reload(twoT)
from twoT import *
import cProfile as profile

from pyro.infer.mcmc import NUTS
from pyro.infer.mcmc.api import MCMC


print(model_lps(ts([3.5,3.5]),LOWDFP))

print(model_lps(ts([7.0,0.]),LOWDFP))
print(model_lps(ts([6.0,0.]),LOWDFP))

def conditioned_model(model, *args):
    return poutine.condition(model, data={})(*args)

nuts_kernel = NUTS(conditioned_model, jit_compile=False,)
mcmc = MCMC(nuts_kernel,
            num_samples=10,
            warmup_steps=50,
            num_chains=1)
mcmc.run(model, ts(7.),ts(2.))
mcmc.summary(prob=0.5)

mcmc._samples["effects"].size()
# Out:
# tensor(-7.9729)
# tensor(-6.9401)
# tensor(-9.6237)
# sample: 100%|█████████████████████████████████████| 60/60 [00:00<00:00, 78.13it/s, step size=2.03e-01, acc. prob=0.953]
#                 mean       std    median     25.0%     75.0%     n_eff     r_hat
# effects[0]      2.28      3.22      0.89     -1.21      1.14      4.46      0.90
# effects[1]      4.70      3.11      5.51      5.51      7.88      4.51      0.90
# torch.Size([10, 2])

# %% [markdown]
# Amortizable hierarchical t model:

# %%
from importlib import reload
import demoT #import *
reload(demoT)
from demoT import *
import cProfile as profile

#vals = MIDDF35
guidenames = ["amortized_laplace","amortized_deterministic_laplace",]#,"meanfield",]#,"MLE"]#,"laplace"
if True:

    for aniter in range(1):
        for nparticles in [1]:#,5]:
            for trueparams in [tdom_norm_params,ndom_norm_params,tdom_fat_params,ndom_fat_params,]:
                for guidename in guidenames:
                    #

                    print(aniter,nparticles,guidenames,trueparams)
                    result = trainGuide(guidename,nparticles,trueparams,filename="testresults/demoT_2.csv")
                    print(aniter,nparticles,guidenames)
                    for line in range(10):
                        print()
                    
else:
    plt.plot([getMLE(.01 + x/100,1.,0,1.) for x in range(500)])
# Out:
# 0 1 ['amortized_laplace', 'amortized_deterministic_laplace'] {'modal_effect': tensor(1.), 'df': tensor(3.), 't_scale': tensor(2.)}
# generating data {'modal_effect': tensor(1.), 'df': tensor(3.), 't_scale': tensor(2.)}
# creating torch.Size([]) torch.Size([44]) torch.Size([]) torch.Size([44]) torch.Size([44])
# Not none - creating data.
# guidename amortized_laplace
# trueparams {'modal_effect': tensor(1.), 'df': tensor(3.), 't_scale': tensor(2.)}
# esize torch.Size([44])
# epoch 0 loss = 257.47677397727966;
# mode_hat tensor(-0.0050, requires_grad=True)
# ltscale_hat tensor(0.0050, requires_grad=True)
# ldfraw_hat tensor(-0.0050, requires_grad=True)
# complaint 9 assert approx_eq( tensor([-4.1258e+00,  5.4003e+01,  1.4228e+02, -3.9691e-01,  8.5798e-02,
#          1.5827e+02, -3.9142e+01,  1.4334e+02, -2.2877e+02, -8.1054e+02,
#          3.0888e+02,  9.1695e+02, -2.5313e-02, -8.7465e+00,  1.5288e+02,
#         -7.6804e+01,  9.9370e+01, -3.4312e-02,  2.0037e+03,  2.4101e+01,
#          1.9645e+01,  4.3910e+02,  1.5797e-05,  4.8168e-02,  4.1783e+02,
#          9.6623e+02,  3.1752e+03,  7.2010e+00, -1.7388e-01, -1.7089e+00,
#          2.7563e+02, -7.3497e+00,  1.2755e+01, -2.2216e+01, -4.9741e+01,
#         -6.6355e+01, -1.5461e+03, -2.2583e+02,  3.8170e+03, -5.2850e+01,
#         -5.3396e+02,  8.2826e+00,  1.6243e-01, -2.7414e+01],
#        grad_fn=<PowBackward0>) tensor([ 4.1924e+00, -5.4232e+01, -1.4293e+02,  3.9954e-01, -8.6207e-02,
#         -1.5846e+02,  3.9278e+01, -1.4353e+02,  2.2893e+02,  8.1110e+02,
#         -3.0968e+02, -9.1880e+02,  2.5885e-02,  8.9981e+00, -1.5350e+02,
#          7.7114e+01, -9.9724e+01,  3.4834e-02, -2.0066e+03, -2.4177e+01,
#         -1.9850e+01, -4.3945e+02, -1.6847e-05, -4.9045e-02, -4.1790e+02,
#         -9.6660e+02, -3.1774e+03, -7.4369e+00,  1.7440e-01,  1.7970e+00,
#         -2.7669e+02,  7.3534e+00, -1.3094e+01,  2.2288e+01,  4.9888e+01,
#          6.6411e+01,  1.5462e+03,  2.2604e+02, -3.8173e+03,  5.3526e+01,
#          5.3614e+02, -8.4546e+00, -1.6326e-01,  2.7459e+01],
#        grad_fn=<MulBackward0>) tensor([ -7.3469,  17.1870,  24.0815,  -3.3072,   1.9800,  24.3918, -15.3557,
#          23.6006, -27.4987, -42.2379,  31.0824,  45.3357,  -1.3418,  -9.7201,
#          24.6075, -19.3741,  21.1171,  -1.4742,  59.2567,  13.0202,  12.3829,
#          34.3295,   0.1195,   1.6558,  33.4649,  44.5396,  67.9326,   9.1444,
#          -2.5012,  -5.7041,  30.2409,  -8.6929,  11.0531, -12.6703, -16.5140,
#         -18.1565, -51.8331, -27.4359,  70.1530, -17.6517, -38.5727,   9.3976,
#           2.4505, -13.5352], grad_fn=<MulBackward0>) tensor([  7.2802, -16.9561, -23.4273,   3.3045,  -1.9796, -24.1929,  15.2196,
#         -23.4090,  27.3390,  41.6779, -30.2745, -43.4849,   1.3412,   9.4684,
#         -23.9828,  19.0644, -20.7639,   1.4736, -56.3958, -12.9439, -12.1785,
#         -33.9794,  -0.1195,  -1.6549, -33.4003, -44.1779, -65.7016,  -8.9086,
#           2.5007,   5.6160, -29.1824,   8.6893, -10.7143,  12.5983,  16.4766,
#          18.0999,  51.6583,  27.2276, -69.8167,  16.9777,  36.3880,  -9.2256,
#          -2.4497,  13.4909], grad_fn=<MulBackward0>)
# complaint 8 assert2 approx_eq( tensor([ 4.7684e-07,  1.7471e-03, -3.8147e-06,  7.1526e-07,  1.1921e-07,
#          0.0000e+00,  1.1539e-04, -3.8147e-06,  1.7166e-05, -2.2888e-05,
#          7.0572e-05,  4.9591e-05, -4.7684e-07,  0.0000e+00,  1.3351e-05,
#         -1.9073e-06,  7.6294e-06, -3.5763e-07, -2.6703e-05, -9.5367e-06,
#          7.6294e-06, -5.7220e-05, -3.2783e-07, -1.1921e-07, -1.5259e-05,
#          5.7220e-05,  3.2806e-04,  1.9073e-06, -7.1526e-07, -4.7684e-07,
#         -2.8610e-05,  0.0000e+00, -1.9073e-06, -4.7684e-06,  1.0954e-01,
#         -1.1063e-04, -4.5776e-05,  3.8147e-06,  3.4332e-04,  1.6785e-03,
#         -3.8147e-05, -1.9073e-06,  2.3842e-07,  1.6212e-05],
#        grad_fn=<AddBackward0>)
# complaint 7 dm.grad
# complaint 6 dtr.grad
# complaint 5 ddfr.grad
# complaint 4 assert approx_eq( tensor([-4.1535e+00,  5.3853e+01,  1.4200e+02, -4.0255e-01,  8.3819e-02,
#          1.5796e+02, -3.9263e+01,  1.4306e+02, -2.2915e+02, -8.1144e+02,
#          3.0841e+02,  9.1598e+02, -2.6211e-02, -8.7942e+00,  1.5258e+02,
#         -7.6994e+01,  9.9151e+01, -3.5414e-02,  2.0021e+03,  2.4015e+01,
#          1.9572e+01,  4.3851e+02,  1.0458e-05,  4.6854e-02,  4.1726e+02,
#          9.6522e+02,  3.1729e+03,  7.1663e+00, -1.7712e-01, -1.7251e+00,
#          2.7519e+02, -7.3890e+00,  1.2703e+01, -2.2299e+01, -5.0017e+01,
#         -6.6525e+01, -1.5475e+03, -2.2622e+02,  3.8144e+03, -5.3032e+01,
#         -5.3465e+02,  8.2429e+00,  1.5940e-01, -2.7509e+01],
#        grad_fn=<PowBackward0>) tensor([ 4.2201e+00, -5.4083e+01, -1.4265e+02,  4.0520e-01, -8.4215e-02,
#         -1.5816e+02,  3.9399e+01, -1.4325e+02,  2.2931e+02,  8.1200e+02,
#         -3.0921e+02, -9.1783e+02,  2.6798e-02,  9.0455e+00, -1.5321e+02,
#          7.7303e+01, -9.9503e+01,  3.5948e-02, -2.0049e+03, -2.4091e+01,
#         -1.9775e+01, -4.3885e+02, -1.1147e-05, -4.7701e-02, -4.1732e+02,
#         -9.6559e+02, -3.1752e+03, -7.4001e+00,  1.7765e-01,  1.8133e+00,
#         -2.7625e+02,  7.3926e+00, -1.3040e+01,  2.2371e+01,  5.0119e+01,
#          6.6582e+01,  1.5476e+03,  2.2642e+02, -3.8148e+03,  5.3697e+01,
#          5.3684e+02, -8.4134e+00, -1.6021e-01,  2.7553e+01],
#        grad_fn=<MulBackward0>) tensor([ -7.4158,  17.2946,  24.2360,  -3.3470,   1.9790,  24.5533, -15.4828,
#          23.7564, -27.7148, -42.5589,  31.2872,  45.6361,  -1.3672,  -9.8048,
#          24.7663, -19.5292,  21.2529,  -1.5005,  59.6506,  13.0993,  12.4556,
#          34.5627,   0.1049,   1.6524,  33.6945,  44.8478,  68.3961,   9.1923,
#          -2.5351,  -5.7610,  30.4371,  -8.7723,  11.1139, -12.7783, -16.6652,
#         -18.3048, -52.2278, -27.6511,  70.6497, -17.7942, -38.8530,   9.4484,
#           2.4530, -13.6497], grad_fn=<MulBackward0>) tensor([  7.3492, -17.0651, -23.5838,   3.3443,  -1.9786, -24.3551,  15.3469,
#         -23.5654,  27.5553,  41.9995, -30.4813, -43.7888,   1.3666,   9.5535,
#         -24.1434,  19.2200, -20.9008,   1.5000, -56.7944, -13.0234, -12.2524,
#         -34.2134,  -0.1049,  -1.6515, -33.6300, -44.4868, -66.1686,  -8.9585,
#           2.5346,   5.6727, -29.3812,   8.7687, -10.7775,  12.7063,  16.6132,
#          18.2483,  52.0532,  27.4431, -70.3139,  17.1180,  36.6707,  -9.2779,
#          -2.4521,  13.6055], grad_fn=<MulBackward0>)
# complaint 3 assert2 approx_eq( tensor([-9.5367e-07, -2.0981e-05,  1.5259e-05, -4.7684e-07, -1.1921e-07,
#         -7.6294e-06,  5.2452e-05, -2.2888e-05, -1.1444e-05,  5.3406e-05,
#         -2.0981e-05,  5.3406e-05, -1.1921e-07,  0.0000e+00, -1.1444e-05,
#         -1.7166e-05,  5.3406e-05, -1.1921e-07,  1.4496e-04,  3.8147e-06,
#          9.5367e-07,  6.1035e-05, -3.9488e-07,  0.0000e+00,  2.2888e-05,
#         -7.6294e-06,  2.7466e-04, -9.5367e-07, -2.3842e-07,  0.0000e+00,
#          3.0518e-05, -9.5367e-07,  3.8147e-06, -1.1444e-05,  5.0184e-02,
#         -9.5367e-05,  2.6703e-05, -7.6294e-06,  3.2043e-04, -1.1133e-02,
#          1.5259e-05,  0.0000e+00,  0.0000e+00, -1.4305e-05],
#        grad_fn=<AddBackward0>)
# complaint 2 dm.grad
# complaint 1 dtr.grad
# complaint 0 ddfr.grad
# complaint 0
# complaint -20
# complaint -40
# complaint -60
# complaint -80
# complaint -100
# complaint -120
# complaint -140
# epoch 100 loss = 235.59264135360718;
# mode_hat tensor(0.0998, requires_grad=True)
# ltscale_hat tensor(0.3949, requires_grad=True)
# ldfraw_hat tensor(-0.4941, requires_grad=True)
# complaint -160
# sample:  76%|█████████████████████████        | 798/1050 [00:19<00:01, 246.48it/s, step size=5.79e-01, acc. prob=0.635]
# complaint -180
# complaint -200
# complaint -220
# complaint -240
# complaint -260
# complaint -280
# epoch 200 loss = 206.11843144893646;
# mode_hat tensor(0.1586, requires_grad=True)
# ltscale_hat tensor(0.7829, requires_grad=True)
# ldfraw_hat tensor(-0.9570, requires_grad=True)
# complaint -300
# complaint -320
# complaint -340
# complaint -360
# complaint -380
# complaint -400
# complaint -420
# complaint -440
# complaint -460
# complaint -480
# complaint -500
# complaint -520
# complaint -540
# complaint -560
# complaint -580
# complaint -600
# complaint -620
# complaint -640
# complaint -660
# complaint -680
# complaint -700
# complaint -720
# epoch 300 loss = 201.22901892662048;
# mode_hat tensor(0.1607, requires_grad=True)
# ltscale_hat tensor(0.8142, requires_grad=True)
# ldfraw_hat tensor(-1.4344, requires_grad=True)
# complaint -740
# complaint -760
# complaint -780
# complaint -800
# complaint -820
# complaint -840
# complaint -860
# complaint -880
# complaint -900
# complaint -920
# complaint -940
# complaint -960
# complaint -980
# complaint -1000
# complaint -1020
# complaint -1040
# complaint -1060
# epoch 400 loss = 202.0620892047882;
# mode_hat tensor(0.2398, requires_grad=True)
# ltscale_hat tensor(0.9828, requires_grad=True)
# ldfraw_hat tensor(-1.9048, requires_grad=True)
# complaint -1080
# complaint -1100
# complaint -1120
# complaint -1140
# complaint -1160
# complaint -1180
# complaint -1200
# complaint -1220
# complaint -1240
# epoch 500 loss = 191.97738814353943;
# mode_hat tensor(0.3202, requires_grad=True)
# ltscale_hat tensor(1.3345, requires_grad=True)
# ldfraw_hat tensor(-1.9363, requires_grad=True)
# complaint -1260
# complaint -1280
# complaint -1300
# complaint -1320
# complaint -1340
# complaint -1360
# complaint -1380
# complaint -1400
# complaint -1420
# complaint -1440
# epoch 600 loss = 185.02017211914062;
# mode_hat tensor(0.4270, requires_grad=True)
# ltscale_hat tensor(1.5650, requires_grad=True)
# ldfraw_hat tensor(-1.4235, requires_grad=True)
# complaint -1460
# complaint -1480
# complaint -1500
# complaint -1520
# complaint -1540
# complaint -1560
# complaint -1580
# complaint -1600
# epoch 700 loss = 174.57563161849976;
# mode_hat tensor(0.5909, requires_grad=True)
# ltscale_hat tensor(1.6342, requires_grad=True)
# ldfraw_hat tensor(-0.9117, requires_grad=True)
# complaint -1620
# complaint -1640
# complaint -1660
# complaint -1680
# complaint -1700
# complaint -1720
# complaint -1740
# complaint -1760
# complaint -1780
# complaint -1800
# epoch 800 loss = 177.90494418144226;
# mode_hat tensor(0.6861, requires_grad=True)
# ltscale_hat tensor(1.6707, requires_grad=True)
# ldfraw_hat tensor(-0.4056, requires_grad=True)
# complaint -1820
# complaint -1840
# complaint -1860
# epoch 900 loss = 190.46340107917786;
# mode_hat tensor(0.9078, requires_grad=True)
# ltscale_hat tensor(1.6611, requires_grad=True)
# ldfraw_hat tensor(0.0975, requires_grad=True)
# epoch 1000 loss = 196.106023311615;
# mode_hat tensor(0.9729, requires_grad=True)
# ltscale_hat tensor(1.6947, requires_grad=True)
# ldfraw_hat tensor(0.5980, requires_grad=True)
# epoch 1100 loss = 179.34744834899902;
# mode_hat tensor(1.0215, requires_grad=True)
# ltscale_hat tensor(1.7235, requires_grad=True)
# ldfraw_hat tensor(1.0910, requires_grad=True)
# epoch 1200 loss = 188.5144612789154;
# mode_hat tensor(1.1241, requires_grad=True)
# ltscale_hat tensor(1.7617, requires_grad=True)
# ldfraw_hat tensor(1.5715, requires_grad=True)
# epoch 1300 loss = 187.83086776733398;
# mode_hat tensor(1.2041, requires_grad=True)
# ltscale_hat tensor(1.7546, requires_grad=True)
# ldfraw_hat tensor(1.9140, requires_grad=True)
# epoch 1400 loss = 171.20929169654846;
# mode_hat tensor(1.2305, requires_grad=True)
# ltscale_hat tensor(1.7699, requires_grad=True)
# ldfraw_hat tensor(1.9468, requires_grad=True)
# epoch 1500 loss = 178.40320110321045;
# mode_hat tensor(1.2613, requires_grad=True)
# ltscale_hat tensor(1.7726, requires_grad=True)
# ldfraw_hat tensor(1.9593, requires_grad=True)
# Final mean_losses: 182.87454816571466
# guidename amortized_laplace
# trueparams {'modal_effect': tensor(1.), 'df': tensor(3.), 't_scale': tensor(2.)}
# ldfraw_hat:
# 1.930368185043335
# lpsi:
# tensor([-7.9091, -6.7187, -8.2130, -8.1982, -8.1702, -8.0968, -8.3097, -8.2231,
#         -8.0977, -8.2138], requires_grad=True)
# ltscale_hat:
# 1.757524847984314
# mode_hat:
# 1.2016892433166504
# 0 1 ['amortized_laplace', 'amortized_deterministic_laplace']
#
#
#
#
#
#
#
#
#
#
# 0 1 ['amortized_laplace', 'amortized_deterministic_laplace'] {'modal_effect': tensor(1.), 'df': tensor(3.), 't_scale': tensor(2.)}
# generating data {'modal_effect': tensor(1.), 'df': tensor(3.), 't_scale': tensor(2.)}
# creating torch.Size([]) torch.Size([44]) torch.Size([]) torch.Size([44]) torch.Size([44])
# Not none - creating data.
# guidename amortized_deterministic_laplace
# trueparams {'modal_effect': tensor(1.), 'df': tensor(3.), 't_scale': tensor(2.)}
# esize torch.Size([44])
# epoch 0 loss = 202.43279647827148;
# mode_hat tensor(-0.0050, requires_grad=True)
# ltscale_hat tensor(0.0050, requires_grad=True)
# ldfraw_hat tensor(-0.0050, requires_grad=True)
# complaint -1880
# complaint -1900
# epoch 100 loss = 162.78398633003235;
# mode_hat tensor(-0.3883, requires_grad=True)
# ltscale_hat tensor(0.5050, requires_grad=True)
# ldfraw_hat tensor(-0.5000, requires_grad=True)
# complaint -1920
# complaint -1940
# complaint -1960
# complaint -1980
# epoch 200 loss = 118.44608211517334;
# mode_hat tensor(-0.5054, requires_grad=True)
# ltscale_hat tensor(1.0050, requires_grad=True)
# ldfraw_hat tensor(-0.9616, requires_grad=True)
# complaint -2000
# complaint -2020
# complaint -2040
# complaint -2060
# complaint -2080
# complaint -2100
# complaint -2120
# epoch 300 loss = 86.57882237434387;
# mode_hat tensor(-0.4159, requires_grad=True)
# ltscale_hat tensor(1.5046, requires_grad=True)
# ldfraw_hat tensor(-1.3623, requires_grad=True)
# complaint -2140
# complaint -2160
# complaint -2180
# complaint -2200
# complaint -2220
# complaint -2240
# epoch 400 loss = 62.072874784469604;
# mode_hat tensor(-0.1202, requires_grad=True)
# ltscale_hat tensor(2.0042, requires_grad=True)
# ldfraw_hat tensor(-0.8974, requires_grad=True)
# complaint -2260
# complaint -2280
# complaint -2300
# epoch 500 loss = 57.66342878341675;
# mode_hat tensor(0.2907, requires_grad=True)
# ltscale_hat tensor(2.4977, requires_grad=True)
# ldfraw_hat tensor(-0.3984, requires_grad=True)
# epoch 600 loss = 59.26319670677185;
# mode_hat tensor(0.5841, requires_grad=True)
# ltscale_hat tensor(2.7935, requires_grad=True)
# ldfraw_hat tensor(0.1059, requires_grad=True)
# epoch 700 loss = 51.45506834983826;
# mode_hat tensor(0.7263, requires_grad=True)
# ltscale_hat tensor(2.8069, requires_grad=True)
# ldfraw_hat tensor(0.6079, requires_grad=True)
# epoch 800 loss = 56.80392575263977;
# mode_hat tensor(0.7547, requires_grad=True)
# ltscale_hat tensor(2.8068, requires_grad=True)
# ldfraw_hat tensor(1.1057, requires_grad=True)
# epoch 900 loss = 58.11438012123108;
# mode_hat tensor(0.7800, requires_grad=True)
# ltscale_hat tensor(2.7733, requires_grad=True)
# ldfraw_hat tensor(1.5973, requires_grad=True)
# epoch 1000 loss = 58.99888372421265;
# mode_hat tensor(0.7958, requires_grad=True)
# ltscale_hat tensor(2.7844, requires_grad=True)
# ldfraw_hat tensor(2.0728, requires_grad=True)
# epoch 1100 loss = 70.70165777206421;
# mode_hat tensor(0.9016, requires_grad=True)
# ltscale_hat tensor(2.7791, requires_grad=True)
# ldfraw_hat tensor(2.2860, requires_grad=True)
# epoch 1200 loss = 46.91742658615112;
# mode_hat tensor(0.8207, requires_grad=True)
# ltscale_hat tensor(2.7785, requires_grad=True)
# ldfraw_hat tensor(2.2861, requires_grad=True)
# epoch 1300 loss = 53.46002435684204;
# mode_hat tensor(0.8438, requires_grad=True)
# ltscale_hat tensor(2.7675, requires_grad=True)
# ldfraw_hat tensor(2.2871, requires_grad=True)
# epoch 1400 loss = 51.86290097236633;
# mode_hat tensor(0.8662, requires_grad=True)
# ltscale_hat tensor(2.7711, requires_grad=True)
# ldfraw_hat tensor(2.2878, requires_grad=True)
# Final mean_losses: 57.605720068458034
# guidename amortized_deterministic_laplace
# trueparams {'modal_effect': tensor(1.), 'df': tensor(3.), 't_scale': tensor(2.)}
# ldfraw_hat:
# 2.2867355346679688
# lpsi:
# tensor([-7.0912, -6.2108, -6.1707, -6.1092, -6.2131, -6.1138, -6.1483, -6.1352,
#         -6.1526, -6.1429], requires_grad=True)
# ltscale_hat:
# 2.7749104499816895
# mode_hat:
# 0.848555862903595
# 0 1 ['amortized_laplace', 'amortized_deterministic_laplace']
# 0 1 ['amortized_laplace', 'amortized_deterministic_laplace'] {'modal_effect': tensor(1.), 'df': tensor(3.), 't_scale': tensor(-2.)}
# generating data {'modal_effect': tensor(1.), 'df': tensor(3.), 't_scale': tensor(-2.)}
# creating torch.Size([]) torch.Size([44]) torch.Size([]) torch.Size([44]) torch.Size([44])
# Not none - creating data.
# guidename amortized_laplace
# trueparams {'modal_effect': tensor(1.), 'df': tensor(3.), 't_scale': tensor(-2.)}
# esize torch.Size([44])
# epoch 0 loss = 115.45748162269592;
# mode_hat tensor(0.0050, requires_grad=True)
# ltscale_hat tensor(0.0050, requires_grad=True)
# ldfraw_hat tensor(0.0050, requires_grad=True)
# epoch 100 loss = 55.97200274467468;
# mode_hat tensor(0.5050, requires_grad=True)
# ltscale_hat tensor(-0.2655, requires_grad=True)
# ldfraw_hat tensor(0.5036, requires_grad=True)
# epoch 200 loss = 68.64994502067566;
# mode_hat tensor(0.9650, requires_grad=True)
# ltscale_hat tensor(-0.7651, requires_grad=True)
# ldfraw_hat tensor(0.9979, requires_grad=True)
# epoch 300 loss = 68.2776472568512;
# mode_hat tensor(0.9560, requires_grad=True)
# ltscale_hat tensor(-1.1976, requires_grad=True)
# ldfraw_hat tensor(1.4778, requires_grad=True)
# epoch 400 loss = 79.62868475914001;
# mode_hat tensor(0.9564, requires_grad=True)
# ltscale_hat tensor(-1.2605, requires_grad=True)
# ldfraw_hat tensor(1.8375, requires_grad=True)
# epoch 500 loss = 80.52010667324066;
# mode_hat tensor(0.9579, requires_grad=True)
# ltscale_hat tensor(-1.2390, requires_grad=True)
# ldfraw_hat tensor(2.0372, requires_grad=True)
# epoch 600 loss = 67.12156021595001;
# mode_hat tensor(0.9728, requires_grad=True)
# ltscale_hat tensor(-1.2125, requires_grad=True)
# ldfraw_hat tensor(2.0919, requires_grad=True)
# epoch 700 loss = 46.34604239463806;
# mode_hat tensor(0.9600, requires_grad=True)
# ltscale_hat tensor(-1.2057, requires_grad=True)
# ldfraw_hat tensor(2.0687, requires_grad=True)
# epoch 800 loss = 81.32077127695084;
# mode_hat tensor(0.9912, requires_grad=True)
# ltscale_hat tensor(-1.2303, requires_grad=True)
# ldfraw_hat tensor(2.1082, requires_grad=True)
# epoch 900 loss = 87.58461618423462;
# mode_hat tensor(0.9552, requires_grad=True)
# ltscale_hat tensor(-1.2239, requires_grad=True)
# ldfraw_hat tensor(2.0982, requires_grad=True)
# Final mean_losses: 75.00881755650668
# guidename amortized_laplace
# trueparams {'modal_effect': tensor(1.), 'df': tensor(3.), 't_scale': tensor(-2.)}
# ldfraw_hat:
# 2.1148786544799805
# lpsi:
# tensor([-5.1839, -7.8623, -8.2136, -8.1522, -8.1695, -8.2130, -8.0999, -8.1239,
#         -8.1766, -8.1542], requires_grad=True)
# ltscale_hat:
# -1.2415838241577148
# mode_hat:
# 0.9541477560997009
# 0 1 ['amortized_laplace', 'amortized_deterministic_laplace']
#
#
#
#
#
#
#
#
#
#
# 0 1 ['amortized_laplace', 'amortized_deterministic_laplace'] {'modal_effect': tensor(1.), 'df': tensor(3.), 't_scale': tensor(-2.)}
# generating data {'modal_effect': tensor(1.), 'df': tensor(3.), 't_scale': tensor(-2.)}
# creating torch.Size([]) torch.Size([44]) torch.Size([]) torch.Size([44]) torch.Size([44])
# Not none - creating data.
# guidename amortized_deterministic_laplace
# trueparams {'modal_effect': tensor(1.), 'df': tensor(3.), 't_scale': tensor(-2.)}
# esize torch.Size([44])
# epoch 0 loss = 53.977474212646484;
# mode_hat tensor(0.0050, requires_grad=True)
# ltscale_hat tensor(0.0050, requires_grad=True)
# ldfraw_hat tensor(0.0050, requires_grad=True)
# epoch 100 loss = 38.98843836784363;
# mode_hat tensor(0.5050, requires_grad=True)
# ltscale_hat tensor(0.3943, requires_grad=True)
# ldfraw_hat tensor(0.4994, requires_grad=True)
# epoch 200 loss = 34.62658667564392;
# mode_hat tensor(0.9750, requires_grad=True)
# ltscale_hat tensor(-0.0841, requires_grad=True)
# ldfraw_hat tensor(0.9946, requires_grad=True)
# epoch 300 loss = 14.443723917007446;
# mode_hat tensor(1.0316, requires_grad=True)
# ltscale_hat tensor(-0.1798, requires_grad=True)
# ldfraw_hat tensor(1.4877, requires_grad=True)
# epoch 400 loss = 28.007311582565308;
# mode_hat tensor(1.0190, requires_grad=True)
# ltscale_hat tensor(-0.1889, requires_grad=True)
# ldfraw_hat tensor(1.9661, requires_grad=True)
# epoch 500 loss = 30.06386160850525;
# mode_hat tensor(1.0196, requires_grad=True)
# ltscale_hat tensor(-0.1885, requires_grad=True)
# ldfraw_hat tensor(2.2188, requires_grad=True)
# epoch 600 loss = 27.0135281085968;
# mode_hat tensor(1.0009, requires_grad=True)
# ltscale_hat tensor(-0.1813, requires_grad=True)
# ldfraw_hat tensor(2.2195, requires_grad=True)
# epoch 700 loss = 22.423550844192505;
# mode_hat tensor(1.0160, requires_grad=True)
# ltscale_hat tensor(-0.1722, requires_grad=True)
# ldfraw_hat tensor(2.2176, requires_grad=True)
# epoch 800 loss = 20.309873819351196;
# mode_hat tensor(0.9861, requires_grad=True)
# ltscale_hat tensor(-0.1817, requires_grad=True)
# ldfraw_hat tensor(2.2225, requires_grad=True)
# Final mean_losses: 26.241010784359116
# guidename amortized_deterministic_laplace
# trueparams {'modal_effect': tensor(1.), 'df': tensor(3.), 't_scale': tensor(-2.)}
# ldfraw_hat:
# 2.2188711166381836
# lpsi:
# tensor([-7.9998, -8.2106, -7.7302, -7.6826, -7.7475, -7.6210, -7.6762, -7.6856,
#         -7.7443, -7.7281], requires_grad=True)
# ltscale_hat:
# -0.18953309953212738
# mode_hat:
# 1.0287024974822998
# 0 1 ['amortized_laplace', 'amortized_deterministic_laplace']
#
#
#
#
#
#
#
#
#
#
# 0 1 ['amortized_laplace', 'amortized_deterministic_laplace'] {'modal_effect': tensor(1.), 'df': tensor(-1.), 't_scale': tensor(2.)}
# generating data {'modal_effect': tensor(1.), 'df': tensor(-1.), 't_scale': tensor(2.)}
# creating torch.Size([]) torch.Size([44]) torch.Size([]) torch.Size([44]) torch.Size([44])
# Not none - creating data.
# guidename amortized_laplace
# trueparams {'modal_effect': tensor(1.), 'df': tensor(-1.), 't_scale': tensor(2.)}
# esize torch.Size([44])
# epoch 0 loss = 325.36020374298096;
# mode_hat tensor(0.0050, requires_grad=True)
# ltscale_hat tensor(0.0050, requires_grad=True)
# ldfraw_hat tensor(-0.0050, requires_grad=True)
# complaint -2320
# complaint -2340
# complaint -2360
# complaint -2380
# complaint -2400
# epoch 100 loss = 275.10515427589417;
# mode_hat tensor(-0.0192, requires_grad=True)
# ltscale_hat tensor(0.3863, requires_grad=True)
# ldfraw_hat tensor(-0.5050, requires_grad=True)
# complaint -2420
# complaint -2440
# complaint -2460
# complaint -2480
# complaint -2500
# complaint -2520
# complaint -2540
# complaint -2560
# complaint -2580
# complaint -2600
# complaint -2620
# complaint -2640
# complaint -2660
# epoch 200 loss = 257.80011010169983;
# mode_hat tensor(-0.0497, requires_grad=True)
# ltscale_hat tensor(0.6569, requires_grad=True)
# ldfraw_hat tensor(-0.9883, requires_grad=True)
# complaint -2680
# complaint -2700
# complaint -2720
# complaint -2740
# complaint -2760
# complaint -2780
# complaint -2800
# complaint -2820
# complaint -2840
# complaint -2860
# complaint -2880
# epoch 300 loss = 226.08890843391418;
# mode_hat tensor(-0.0906, requires_grad=True)
# ltscale_hat tensor(0.9895, requires_grad=True)
# ldfraw_hat tensor(-1.4607, requires_grad=True)
# complaint -2900
# complaint -2920
# complaint -2940
# complaint -2960
# complaint -2980
# complaint -3000
# complaint -3020
# complaint -3040
# complaint -3060
# epoch 400 loss = 199.9448275566101;
# mode_hat tensor(-0.0802, requires_grad=True)
# ltscale_hat tensor(1.3294, requires_grad=True)
# ldfraw_hat tensor(-1.9258, requires_grad=True)
# complaint -3080
# complaint -3100
# complaint -3120
# complaint -3140
# complaint -3160
# complaint -3180
# complaint -3200
# complaint -3220
# complaint -3240
# complaint -3260
# complaint -3280
# complaint -3300
# complaint -3320
# complaint -3340
# complaint -3360
# complaint -3380
# complaint -3400
# complaint -3420
# complaint -3440
# complaint -3460
# complaint -3480
# complaint -3500
# complaint -3520
# complaint -3540
# epoch 500 loss = 223.26311945915222;
# mode_hat tensor(-0.0683, requires_grad=True)
# ltscale_hat tensor(1.3629, requires_grad=True)
# ldfraw_hat tensor(-2.4047, requires_grad=True)
# complaint -3560
# complaint -3580
# complaint -3600
# complaint -3620
# complaint -3640
# complaint -3660
# complaint -3680
# complaint -3700
# complaint -3720
# complaint -3740
# complaint -3760
# complaint -3780
# complaint -3800
# complaint -3820
# epoch 600 loss = 216.32274222373962;
# mode_hat tensor(-0.0564, requires_grad=True)
# ltscale_hat tensor(1.5834, requires_grad=True)
# ldfraw_hat tensor(-2.8722, requires_grad=True)
# complaint -3840
# complaint -3860
# complaint -3880
# complaint -3900
# complaint -3920
# complaint -3940
# complaint -3960
# complaint -3980
# complaint -4000
# complaint -4020
# complaint -4040
# complaint -4060
# complaint -4080
# complaint -4100
# complaint -4120
# complaint -4140
# complaint -4160
# complaint -4180
# complaint -4200
# epoch 700 loss = 221.62988686561584;
# mode_hat tensor(-0.0397, requires_grad=True)
# ltscale_hat tensor(1.7109, requires_grad=True)
# ldfraw_hat tensor(-3.3142, requires_grad=True)
# complaint -4220
# complaint -4240
# epoch 800 loss = 204.8559226989746;
# mode_hat tensor(-0.0102, requires_grad=True)
# ltscale_hat tensor(1.9482, requires_grad=True)
# ldfraw_hat tensor(-2.9956, requires_grad=True)
# epoch 900 loss = 207.0123689174652;
# mode_hat tensor(0.0647, requires_grad=True)
# ltscale_hat tensor(1.9862, requires_grad=True)
# ldfraw_hat tensor(-2.4842, requires_grad=True)
# epoch 1000 loss = 216.21313452720642;
# mode_hat tensor(0.1140, requires_grad=True)
# ltscale_hat tensor(1.9749, requires_grad=True)
# ldfraw_hat tensor(-1.9766, requires_grad=True)
# epoch 1100 loss = 220.8438847064972;
# mode_hat tensor(0.1175, requires_grad=True)
# ltscale_hat tensor(1.9682, requires_grad=True)
# ldfraw_hat tensor(-1.4730, requires_grad=True)
# epoch 1200 loss = 196.8608009815216;
# mode_hat tensor(0.1960, requires_grad=True)
# ltscale_hat tensor(2.0008, requires_grad=True)
# ldfraw_hat tensor(-0.9733, requires_grad=True)
# complaint -4260
# complaint -4280
# epoch 1300 loss = 171.31793355941772;
# mode_hat tensor(0.1921, requires_grad=True)
# ltscale_hat tensor(1.9974, requires_grad=True)
# ldfraw_hat tensor(-0.6261, requires_grad=True)
# complaint -4300
# epoch 1400 loss = 187.85035800933838;
# mode_hat tensor(0.1941, requires_grad=True)
# ltscale_hat tensor(1.9976, requires_grad=True)
# ldfraw_hat tensor(-0.6554, requires_grad=True)
# complaint -4320
# complaint -4340
# complaint -4360
# complaint -4380
# complaint -4400
# complaint -4420
# epoch 1500 loss = 203.55644416809082;
# mode_hat tensor(0.2618, requires_grad=True)
# ltscale_hat tensor(2.0030, requires_grad=True)
# ldfraw_hat tensor(-0.5560, requires_grad=True)
# complaint -4440
# complaint -4460
# Final mean_losses: 207.80232050681684
# guidename amortized_laplace
# trueparams {'modal_effect': tensor(1.), 'df': tensor(-1.), 't_scale': tensor(2.)}
# ldfraw_hat:
# -0.5863735675811768
# lpsi:
# tensor([-7.7762, -5.8210, -7.5599, -7.7781, -7.7831, -7.7448, -7.8244, -7.9149,
#         -7.6165, -7.7380], requires_grad=True)
# ltscale_hat:
# 1.9972902536392212
# mode_hat:
# 0.34323540329933167
# 0 1 ['amortized_laplace', 'amortized_deterministic_laplace']
#
#
#
#
#
#
#
#
#
#
# 0 1 ['amortized_laplace', 'amortized_deterministic_laplace'] {'modal_effect': tensor(1.), 'df': tensor(-1.), 't_scale': tensor(2.)}
# generating data {'modal_effect': tensor(1.), 'df': tensor(-1.), 't_scale': tensor(2.)}
# creating torch.Size([]) torch.Size([44]) torch.Size([]) torch.Size([44]) torch.Size([44])
# Not none - creating data.
# guidename amortized_deterministic_laplace
# trueparams {'modal_effect': tensor(1.), 'df': tensor(-1.), 't_scale': tensor(2.)}
# esize torch.Size([44])
# epoch 0 loss = 222.65757369995117;
# mode_hat tensor(0.0050, requires_grad=True)
# ltscale_hat tensor(0.0050, requires_grad=True)
# ldfraw_hat tensor(-0.0050, requires_grad=True)
# complaint -4480
# epoch 100 loss = 161.43047332763672;
# mode_hat tensor(0.3859, requires_grad=True)
# ltscale_hat tensor(0.5050, requires_grad=True)
# ldfraw_hat tensor(-0.5045, requires_grad=True)
# complaint -4500
# complaint -4520
# complaint -4540
# complaint -4560
# complaint -4580
# complaint -4600
# complaint -4620
# epoch 200 loss = 125.88311576843262;
# mode_hat tensor(0.4690, requires_grad=True)
# ltscale_hat tensor(1.0050, requires_grad=True)
# ldfraw_hat tensor(-0.9721, requires_grad=True)
# complaint -4640
# complaint -4660
# complaint -4680
# complaint -4700
# complaint -4720
# epoch 300 loss = 99.306649684906;
# mode_hat tensor(0.6932, requires_grad=True)
# ltscale_hat tensor(1.5050, requires_grad=True)
# ldfraw_hat tensor(-1.4164, requires_grad=True)
# complaint -4740
# complaint -4760
# complaint -4780
# complaint -4800
# complaint -4820
# complaint -4840
# complaint -4860
# epoch 400 loss = 84.43835544586182;
# mode_hat tensor(0.7833, requires_grad=True)
# ltscale_hat tensor(1.9950, requires_grad=True)
# ldfraw_hat tensor(-1.3529, requires_grad=True)
# complaint -4880
# epoch 500 loss = 67.85657715797424;
# mode_hat tensor(0.9226, requires_grad=True)
# ltscale_hat tensor(2.4950, requires_grad=True)
# ldfraw_hat tensor(-0.8272, requires_grad=True)
# complaint -4900
# complaint -4920
# complaint -4940
# complaint -4960
# complaint -4980
# complaint -5000
# complaint -5020
# epoch 600 loss = 61.55451822280884;
# mode_hat tensor(0.9720, requires_grad=True)
# ltscale_hat tensor(2.9429, requires_grad=True)
# ldfraw_hat tensor(-0.3171, requires_grad=True)
# epoch 700 loss = 65.88210773468018;
# mode_hat tensor(0.9050, requires_grad=True)
# ltscale_hat tensor(3.0106, requires_grad=True)
# ldfraw_hat tensor(0.1875, requires_grad=True)
# epoch 800 loss = 61.33777928352356;
# mode_hat tensor(0.7621, requires_grad=True)
# ltscale_hat tensor(3.0344, requires_grad=True)
# ldfraw_hat tensor(0.6885, requires_grad=True)
# epoch 900 loss = 62.315152168273926;
# mode_hat tensor(0.6744, requires_grad=True)
# ltscale_hat tensor(3.0304, requires_grad=True)
# ldfraw_hat tensor(1.1848, requires_grad=True)
# epoch 1000 loss = 68.46026229858398;
# mode_hat tensor(0.5720, requires_grad=True)
# ltscale_hat tensor(3.0365, requires_grad=True)
# ldfraw_hat tensor(1.6732, requires_grad=True)
# epoch 1100 loss = 63.86900186538696;
# mode_hat tensor(0.5163, requires_grad=True)
# ltscale_hat tensor(3.0492, requires_grad=True)
# ldfraw_hat tensor(2.1301, requires_grad=True)
# complaint -5040
# epoch 1200 loss = 66.6175901889801;
# mode_hat tensor(0.4623, requires_grad=True)
# ltscale_hat tensor(3.0546, requires_grad=True)
# ldfraw_hat tensor(2.2046, requires_grad=True)
# complaint -5060
# epoch 1300 loss = 52.47042798995972;
# mode_hat tensor(0.4619, requires_grad=True)
# ltscale_hat tensor(3.0527, requires_grad=True)
# ldfraw_hat tensor(2.2044, requires_grad=True)
# Final mean_losses: 60.792331673846185
# guidename amortized_deterministic_laplace
# trueparams {'modal_effect': tensor(1.), 'df': tensor(-1.), 't_scale': tensor(2.)}
# ldfraw_hat:
# 2.204183578491211
# lpsi:
# tensor([-7.0004, -5.6903, -5.9117, -5.9825, -5.9598, -5.9306, -5.8800, -5.9697,
#         -5.8802, -5.9384], requires_grad=True)
# ltscale_hat:
# 3.050933599472046
# mode_hat:
# 0.42618972063064575
# 0 1 ['amortized_laplace', 'amortized_deterministic_laplace']
#
#
#
#
#
#
#
#
#
#
# 0 1 ['amortized_laplace', 'amortized_deterministic_laplace'] {'modal_effect': tensor(1.), 'df': tensor(-1.), 't_scale': tensor(-2.)}
# generating data {'modal_effect': tensor(1.), 'df': tensor(-1.), 't_scale': tensor(-2.)}
# creating torch.Size([]) torch.Size([44]) torch.Size([]) torch.Size([44]) torch.Size([44])
# Not none - creating data.
# guidename amortized_laplace
# trueparams {'modal_effect': tensor(1.), 'df': tensor(-1.), 't_scale': tensor(-2.)}
# esize torch.Size([44])
# epoch 0 loss = 111.47640371322632;
# mode_hat tensor(0.0050, requires_grad=True)
# ltscale_hat tensor(0.0050, requires_grad=True)
# ldfraw_hat tensor(0.0050, requires_grad=True)
# complaint -5080
# epoch 100 loss = 106.34911918640137;
# mode_hat tensor(0.4936, requires_grad=True)
# ltscale_hat tensor(-0.0548, requires_grad=True)
# ldfraw_hat tensor(0.5037, requires_grad=True)
# epoch 200 loss = 92.93335473537445;
# mode_hat tensor(0.9925, requires_grad=True)
# ltscale_hat tensor(-0.5447, requires_grad=True)
# ldfraw_hat tensor(0.9902, requires_grad=True)
# complaint -5100
# epoch 300 loss = 85.69016718864441;
# mode_hat tensor(1.1273, requires_grad=True)
# ltscale_hat tensor(-0.8857, requires_grad=True)
# ldfraw_hat tensor(1.4104, requires_grad=True)
# complaint -5120
# epoch 400 loss = 92.25089049339294;
# mode_hat tensor(1.0960, requires_grad=True)
# ltscale_hat tensor(-0.9411, requires_grad=True)
# ldfraw_hat tensor(1.4078, requires_grad=True)
# epoch 500 loss = 94.96286082267761;
# mode_hat tensor(1.1173, requires_grad=True)
# ltscale_hat tensor(-0.9479, requires_grad=True)
# ldfraw_hat tensor(1.3985, requires_grad=True)
# epoch 600 loss = 78.06539297103882;
# mode_hat tensor(1.1026, requires_grad=True)
# ltscale_hat tensor(-0.9377, requires_grad=True)
# ldfraw_hat tensor(1.3618, requires_grad=True)
# epoch 700 loss = 77.87641441822052;
# mode_hat tensor(1.0693, requires_grad=True)
# ltscale_hat tensor(-0.9655, requires_grad=True)
# ldfraw_hat tensor(1.3447, requires_grad=True)
# epoch 800 loss = 86.53065228462219;
# mode_hat tensor(1.1232, requires_grad=True)
# ltscale_hat tensor(-0.9542, requires_grad=True)
# ldfraw_hat tensor(1.3651, requires_grad=True)
# Final mean_losses: 80.99790954326755
# guidename amortized_laplace
# trueparams {'modal_effect': tensor(1.), 'df': tensor(-1.), 't_scale': tensor(-2.)}
# ldfraw_hat:
# 1.360681414604187
# lpsi:
# tensor([-5.3196, -7.2956, -7.8119, -7.7701, -7.8229, -7.7796, -7.8099, -7.8036,
#         -7.8062, -7.7462], requires_grad=True)
# ltscale_hat:
# -0.9594472050666809
# mode_hat:
# 1.0914980173110962
# 0 1 ['amortized_laplace', 'amortized_deterministic_laplace']
#
#
#
#
#
#
#
#
#
#
# 0 1 ['amortized_laplace', 'amortized_deterministic_laplace'] {'modal_effect': tensor(1.), 'df': tensor(-1.), 't_scale': tensor(-2.)}
# generating data {'modal_effect': tensor(1.), 'df': tensor(-1.), 't_scale': tensor(-2.)}
# creating torch.Size([]) torch.Size([44]) torch.Size([]) torch.Size([44]) torch.Size([44])
# Not none - creating data.
# guidename amortized_deterministic_laplace
# trueparams {'modal_effect': tensor(1.), 'df': tensor(-1.), 't_scale': tensor(-2.)}
# esize torch.Size([44])
# epoch 0 loss = 48.003787994384766;
# mode_hat tensor(0.0050, requires_grad=True)
# ltscale_hat tensor(0.0050, requires_grad=True)
# ldfraw_hat tensor(0.0050, requires_grad=True)
# epoch 100 loss = 41.53447985649109;
# mode_hat tensor(0.5049, requires_grad=True)
# ltscale_hat tensor(0.4687, requires_grad=True)
# ldfraw_hat tensor(0.5027, requires_grad=True)
# epoch 200 loss = 36.46633696556091;
# mode_hat tensor(0.9729, requires_grad=True)
# ltscale_hat tensor(0.1784, requires_grad=True)
# ldfraw_hat tensor(0.9981, requires_grad=True)
# epoch 300 loss = 36.64224457740784;
# mode_hat tensor(1.0544, requires_grad=True)
# ltscale_hat tensor(0.1013, requires_grad=True)
# ldfraw_hat tensor(1.4906, requires_grad=True)
# epoch 400 loss = 32.855103492736816;
# mode_hat tensor(1.0635, requires_grad=True)
# ltscale_hat tensor(0.0964, requires_grad=True)
# ldfraw_hat tensor(1.9694, requires_grad=True)
# epoch 500 loss = 20.07250189781189;
# mode_hat tensor(1.0564, requires_grad=True)
# ltscale_hat tensor(0.1065, requires_grad=True)
# ldfraw_hat tensor(2.2330, requires_grad=True)
# epoch 600 loss = 38.10846447944641;
# mode_hat tensor(1.0737, requires_grad=True)
# ltscale_hat tensor(0.1171, requires_grad=True)
# ldfraw_hat tensor(2.2308, requires_grad=True)
# epoch 700 loss = 29.326801776885986;
# mode_hat tensor(1.0601, requires_grad=True)
# ltscale_hat tensor(0.1092, requires_grad=True)
# ldfraw_hat tensor(2.2300, requires_grad=True)
# epoch 800 loss = 26.207401514053345;
# mode_hat tensor(1.0628, requires_grad=True)
# ltscale_hat tensor(0.0995, requires_grad=True)
# ldfraw_hat tensor(2.2334, requires_grad=True)
# epoch 900 loss = 25.162129163742065;
# mode_hat tensor(1.0514, requires_grad=True)
# ltscale_hat tensor(0.1135, requires_grad=True)
# ldfraw_hat tensor(2.2304, requires_grad=True)
# Final mean_losses: 29.533251512488874
# guidename amortized_deterministic_laplace
# trueparams {'modal_effect': tensor(1.), 'df': tensor(-1.), 't_scale': tensor(-2.)}
# ldfraw_hat:
# 2.230405807495117
# lpsi:
# tensor([-8.3939, -8.3192, -6.7639, -6.8596, -6.8589, -6.8536, -6.8646, -6.8686,
#         -6.9816, -6.8898], requires_grad=True)
# ltscale_hat:
# 0.11346855014562607
# mode_hat:
# 1.0513986349105835
# 0 1 ['amortized_laplace', 'amortized_deterministic_laplace']

# %%
#raise Exception()
from importlib import reload
import twobytwo #import *
reload(twobytwo)
from twobytwo import *
import cProfile as profile

if True:

    for aniter in range(1):
        for nparticles in [1,5]:
                    #
                    print(aniter,nparticles)
                    result = trainGuide(nparticles,filename="testresults/ei2_amortized_laplace_transparent_.csv")
                    print(aniter,nparticles)
                    for line in range(10):
                        print()
                    
else:
    plt.plot([getMLE(.01 + x/100,1.,0,1.) for x in range(500)])
# Out:
# Reloading cmult...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-23-fe707acf81bf> in <module>
#       2 #raise Exception()
#       3 from importlib import reload
# ----> 4 import twobytwo #import *
#       5 reload(twobytwo)
#       6 from twobytwo import *
#
# ~\Dropbox\eipython\eipython\twobytwo.py in <module>
#      32 import go_or_nogo
#      33 from cmult import CMult
# ---> 34 from vecdelta import VecDelta
#      35 import linearize
#      36 reload(linearize)
#
# ModuleNotFoundError: No module named 'vecdelta'

# %%
raise Exception()
from importlib import reload
import mlm #import *
reload(mlm)
from mlm import *
import cProfile as profile

if True:

    for aniter in range(1):
        for nparticles in [1,5]:
                    #
                    print(aniter,nparticles)
                    result = trainGuide(nparticles,filename="testresults/mlm7_amortized_laplace_transparent_.csv")
                    print(aniter,nparticles)
                    for line in range(10):
                        print()
                    
else:
    plt.plot([getMLE(.01 + x/100,1.,0,1.) for x in range(500)])
# Out:
# Reloading linearize.
# Reloading linearize.
# 0 1
# ec:tensor([0.0000, 0.5000, 0.0000])
# erc:tensor([[0., 1., 2.],
#         [2., 0., 0.]])
# y[0]:tensor([[3.3500e+02, 6.5100e+02, 5.0140e+03],
#         [8.0000e+00, 2.0000e+00, 0.0000e+00]])
# trueparams OrderedDict([('ec', tensor([0.0000, 0.5000, 0.0000])), ('erc', tensor([[0., 1., 2.],
#         [2., 0., 0.]])), ('eprc', tensor([[[ 0.2198,  0.0562,  0.3204],
#          [ 0.2206, -0.1079, -0.3713]],
#
#         [[ 0.2814,  0.1298,  0.2614],
#          [ 1.1511, -0.7344, -0.7933]],
#
#         [[ 0.6016,  0.0423, -0.6001],
#          [-0.0024, -0.1152, -0.1959]],
#
#         [[ 0.2716, -0.1976,  0.1028],
#          [-0.2252, -0.2865, -0.2777]],
#
#         [[-0.7656, -0.6171,  0.9099],
#          [-0.2758, -0.6627,  0.0943]],
#
#         [[-0.0345, -0.2475, -0.7391],
#          [ 1.2836, -0.2366,  0.1678]],
#
#         [[ 0.7546,  1.0410,  0.8534],
#          [ 1.1902, -0.5335,  0.5575]],
#
#         [[-0.0703,  0.4029,  0.1638],
#          [-0.3804, -0.7995,  0.0092]],
#
#         [[ 0.4209, -0.2000,  0.5197],
#          [ 0.1791, -0.0017, -0.2672]],
#
#         [[ 0.5843,  0.1973, -0.5225],
#          [-0.4783,  0.0168,  0.3550]],
#
#         [[-0.7676, -0.2063,  0.4832],
#          [ 0.8124, -1.3067, -0.8482]],
#
#         [[-0.1141,  0.1400,  0.0366],
#          [ 0.5567,  0.1411,  0.2171]],
#
#         [[ 0.2285, -0.4327,  0.3907],
#          [-0.4634,  0.1032, -0.1667]],
#
#         [[-0.2144,  0.1165,  0.4813],
#          [ 0.1746, -0.4607, -0.0281]],
#
#         [[-0.3508,  0.5183, -0.3018],
#          [-0.6394,  0.0620,  0.5824]],
#
#         [[ 0.4617,  0.6936,  0.6875],
#          [ 0.3298,  0.2383, -0.5082]],
#
#         [[ 0.3052,  0.2334,  0.9753],
#          [-0.5315,  0.5702, -0.0449]],
#
#         [[ 0.3649, -0.9227, -0.0510],
#          [-0.5168, -0.1563,  0.1229]],
#
#         [[ 0.1886,  0.5506, -0.5714],
#          [ 0.0188,  0.1443,  0.1933]],
#
#         [[-0.1005, -0.0590, -0.4147],
#          [-0.7036,  0.8134,  0.0861]],
#
#         [[-0.3521,  0.1574,  0.0787],
#          [ 0.1927,  0.2868,  0.4990]],
#
#         [[ 0.2718,  0.0394,  0.4992],
#          [-0.2494,  0.3806,  0.3092]],
#
#         [[-0.1497, -0.0939,  0.9579],
#          [ 0.3451, -0.1570, -0.5394]],
#
#         [[ 0.1204, -0.6981,  0.0568],
#          [ 0.5524, -0.6976,  0.2376]],
#
#         [[ 0.5405,  0.0657,  0.7868],
#          [ 0.3907,  0.4937, -0.7439]],
#
#         [[ 0.2933,  0.0791,  0.3334],
#          [-0.4972, -0.5947, -0.5980]],
#
#         [[ 0.6559, -0.1049,  0.3909],
#          [ 0.4948,  0.0858,  0.4380]],
#
#         [[-0.1435,  0.5108,  0.2193],
#          [-0.0054,  0.6692, -0.1397]],
#
#         [[-0.2759, -1.4445, -0.7550],
#          [ 0.5121,  0.0977, -0.3686]],
#
#         [[ 0.8501,  0.1731,  0.4856],
#          [ 0.7251, -0.0260, -0.3142]]])), ('corr', tensor([[ 0.0182, -0.0857,  0.1101],
#         [-0.1071,  0.0123, -0.0566]]))])
# epoch 0 loss = 96236.84943652153; logsdrchat = 1.9950000047683716;
#  erchat = tensor([[-0.0050, -0.0050,  0.0050],
#         [ 0.0050, -0.0050, -0.0050]], requires_grad=True)
#  corrhat = tensor([[-0.0050, -0.0050,  0.0050],
#         [-0.0050,  0.0050,  0.0050]], requires_grad=True)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-b7b3064739de> in <module>
#      11                     #
#      12                     print(aniter,nparticles)
# ---> 13                     result = trainGuide(nparticles,filename="testresults/mlm7_amortized_laplace_transparent_.csv")
#      14                     print(aniter,nparticles)
#      15                     for line in range(10):
#
# ~\Dropbox\eipython\eipython\mlm.py in trainGuide(nparticles, filename)
#     461                     #                 "norm_scale","gum_scale")]]
#     462     for i in range(3001):
# --> 463         loss = svi.step(processed_data, include_nuisance=True)
#     464         if len(losses)==0:
#     465             mean_losses.append(loss)
#
# ~\Anaconda3new\lib\site-packages\pyro\infer\svi.py in step(self, *args, **kwargs)
#      97         # get loss and compute gradients
#      98         with poutine.trace(param_only=True) as param_capture:
# ---> 99             loss = self.loss_and_grads(self.model, self.guide, *args, **kwargs)
#     100
#     101         params = set(site["value"].unconstrained()
#
# ~\Anaconda3new\lib\site-packages\pyro\infer\trace_elbo.py in loss_and_grads(self, model, guide, *args, **kwargs)
#     134             if trainable_params and getattr(surrogate_loss_particle, 'requires_grad', False):
#     135                 surrogate_loss_particle = surrogate_loss_particle / self.num_particles
# --> 136                 surrogate_loss_particle.backward(retain_graph=self.retain_graph)
#     137
#     138         warn_if_nan(loss, "loss")
#
# ~\Anaconda3new\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     105                 products. Defaults to ``False``.
#     106         """
# --> 107         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     108
#     109     def register_hook(self, hook):
#
# ~\Anaconda3new\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      91     Variable._execution_engine.run_backward(
#      92         tensors, grad_tensors, retain_graph, create_graph,
# ---> 93         allow_unreachable=True)  # allow_unreachable flag
#      94
#      95
#
# KeyboardInterrupt:

# %%
from importlib import reload
import twoT #import *
reload(twoT)
from twoT import *
import cProfile as profile

print("So...")
kwargs = dict(obs=ts(7.),df=ts(2.),sig=ts(.4))
kwargs = dict(obs=ts(4.),df=ts(5.),sig=ts(.4))
kwargs = dict(obs=ts(7.),df=ts(2.),sig=ts(.4))
ps = getTruePosteriors([.5,.95],-8,.1,[.01,.8,1.],**kwargs)


fig, ax = plt.subplots(figsize=(6, 6))
for p in ps:
    ax.fill([x for x,y in p], [y for x,y in p], fill=False)

#confidence_ellipse(torch.ones(2),torch.eye(2),ax,alpha=0.5, facecolor='pink', edgecolor='purple', zorder=0)
#print("hi")
plt.show()
# Out:
# So...
# max tensor([-6.8653], grad_fn=<AddBackward0>)
# complaint 9 loss tensor(-1.2117e-09, grad_fn=<NegBackward>)
# complaint 8 adjusted tensor([2.2284, 4.6784], grad_fn=<AddBackward0>) tensor([2.2284, 4.6784]) tensor(-7.7013, grad_fn=<AddBackward0>) tensor([-7.7014], grad_fn=<AddBackward0>)
# complaint 7 loss tensor(-6.2909e-08, grad_fn=<NegBackward>)
# complaint 6 adjusted tensor([2.2047, 4.7547], grad_fn=<AddBackward0>) tensor([2.2047, 4.7547]) tensor(-7.7011, grad_fn=<AddBackward0>) tensor([-7.7014], grad_fn=<AddBackward0>)
# complaint 5 loss tensor(-2.2016e-07, grad_fn=<NegBackward>)
# complaint 4 adjusted tensor([2.1704, 4.8204], grad_fn=<AddBackward0>) tensor([2.1704, 4.8204]) tensor(-7.7009, grad_fn=<AddBackward0>) tensor([-7.7014], grad_fn=<AddBackward0>)
# complaint 3 loss tensor(-4.7214e-07, grad_fn=<NegBackward>)
# complaint 2 adjusted tensor([2.1330, 4.8830], grad_fn=<AddBackward0>) tensor([2.1330, 4.8830]) tensor(-7.7007, grad_fn=<AddBackward0>) tensor([-7.7014], grad_fn=<AddBackward0>)
# complaint 1 loss tensor(-8.1392e-07, grad_fn=<NegBackward>)
# complaint 0 adjusted tensor([2.0940, 4.9439], grad_fn=<AddBackward0>) tensor([2.0940, 4.9440]) tensor(-7.7005, grad_fn=<AddBackward0>) tensor([-7.7014], grad_fn=<AddBackward0>)
# complaint 0
# complaint -20
# complaint -40
# complaint -60
# complaint -80
# complaint -100
# complaint -120
# complaint -140
# complaint -160
# complaint -180
# complaint -200
# complaint -220
# complaint -240
# complaint -260
# complaint -280
# complaint -300
# complaint -320
# complaint -340
# complaint -360
# complaint -380
# complaint -400
# complaint -420
# complaint -440
# complaint -460
# complaint -480
# complaint -500
# complaint -520
# complaint -540
# complaint -560
# complaint -580
# complaint -600
# complaint -620
# complaint -640
# complaint -660
# complaint -680
# complaint -700
# complaint -720
# complaint -740
# complaint -760
# complaint -780
# complaint -800
# complaint -820
# complaint -840
# complaint -860
# complaint -880
# complaint -900
# complaint -920
# complaint -940
# complaint -960
# complaint -980
# complaint -1000
# complaint -1020
# complaint -1040
# complaint -1060
# complaint -1080
# complaint -1100
# complaint -1120
# complaint -1140
# complaint -1160
# complaint -1180
# complaint -1200
# complaint -1220
# complaint -1240
# complaint -1260
# complaint -1280
# complaint -1300
# complaint -1320
# complaint -1340
# complaint -1360
# complaint -1380
# complaint -1400
# complaint -1420
# complaint -1440
# complaint -1460
# complaint -1480
# complaint -1500
# complaint -1520
# complaint -1540
# complaint -1560
# complaint -1580
# complaint -1600
# complaint -1620
# complaint -1640
# complaint -1660
# complaint -1680
# complaint -1700
# complaint -1720
# complaint -1740
# complaint -1760
# complaint -1780
# complaint -1800
# complaint -1820
# complaint -1840
# complaint -1860
# complaint -1880
# complaint -1900
# complaint -1920
# complaint -1940
# complaint -1960
# complaint -1980
# complaint -2000
# complaint -2020
# complaint -2040
# complaint -2060
# complaint -2080
# complaint -2100
# complaint -2120
# complaint -2140
# complaint -2160
# complaint -2180
# complaint -2200
# complaint -2220
# complaint -2240
# complaint -2260
# complaint -2280
# complaint -2300
# complaint -2320
# complaint -2340
# complaint -2360
# complaint -2380
# complaint -2400
# complaint -2420
# complaint -2440
# complaint -2460
# complaint -2480
# complaint -2500
# complaint -2520
# complaint -2540
# complaint -2560
# complaint -2580
# complaint -2600
# complaint -2620
# complaint -2640
# complaint -2660
# complaint -2680
# complaint -2700
# complaint -2720
# complaint -2740
# complaint -2760
# complaint -2780
# complaint -2800
# complaint -2820
# complaint -2840
# complaint -2860
# complaint -2880
# complaint -2900
# complaint -2920
# complaint -2940
# complaint -2960
# complaint -2980
# complaint -3000
# complaint -3020
# complaint -3040
# complaint -3060
# complaint -3080
# complaint -3100
# complaint -3120
# complaint -3140
# complaint -3160
# complaint -3180
# complaint -3200
# complaint -3220
# complaint -3240
# complaint -3260
# complaint -3280
# complaint -3300
# complaint -3320
# complaint -3340
# complaint -3360
# complaint -3380
# complaint -3400
# complaint -3420
# complaint -3440
# complaint -3460
# complaint -3480
# complaint -3500
# complaint -3520
# complaint -3540
# complaint -3560
# complaint -3580
# complaint -3600
# complaint -3620
# complaint -3640
# complaint -3660
# complaint -3680
# complaint -3700
# complaint -3720
# complaint -3740
# complaint -3760
# complaint -3780
# complaint -3800
# complaint -3820
# complaint -3840
# complaint -3860
# complaint -3880
# complaint -3900
# complaint -3920
